# %%
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException

driver = webdriver.Chrome('/Users/naljeong/chromedriver/chromedriver')
driver.set_window_size(1800, 1000)
driver.maximize_window()
driver.get('https://search.naver.com/search.naver?sm=tab_hty.top&where=post&query=%EC%9D%B8%ED%85%8C%EC%9D%B4%ED%81%AC+-%EC%97%94%EC%A7%84+-%EC%9E%A5%EC%B0%A9+-%ED%81%AC%EB%A6%AC%EB%8B%9D+-%ED%81%B4%EB%A6%AC%EB%8B%9D+-%ED%9D%A1%EA%B8%B0+-RTA&oquery=%EC%9D%B8%ED%85%8C%EC%9D%B4%ED%81%AC+-%EC%97%94%EC%A7%84+-%EC%83%B5%EC%9D%B8%ED%85%8C%EC%9D%B4%ED%81%AC+-%EC%9E%A5%EC%B0%A9+-%ED%81%AC%EB%A6%AC%EB%8B%9D+-%ED%81%B4%EB%A6%AC%EB%8B%9D+-%ED%9D%A1%EA%B8%B0+-RTA&tqi=T0N22lpySDossv%2BgWqRssssstid-426222')

driver.maximize_window()

# %%
while True:
    
    post_links = driver.find_elements_by_css_selector('#elThumbnailResultArea > li > dl > dt > a')


    for i in post_links:
        try:

            i.click()
            driver.switch_to_window(driver.window_handles[1])
            time.sleep(3)
            driver.switch_to.frame(driver.find_element_by_css_selector('#mainFrame'))
            maintext = driver.find_element_by_css_selector('div.se_doc_viewer > div.se_component_wrap.sect_dsc.__se_component_area')
            sentences = maintext.text.strip()
            print(sentences)
            driver.close()
            driver.switch_to_window(driver.window_handles[0])
        except NoSuchElementException:
            driver.close()
            driver.switch_to_window(driver.window_handles[0])
            pass

        if i ==4:
            driver.execute_script("window.scrollTo(0,document.body.scrollHeight);")
        
        print('--------------------------')
        
    nextbutton = driver.find_element_by_css_selector('#main_pack > div.paging > a.next')
    nextbutton.click()
# Out:
# 안녕하세요 와와자매 에요!!
#
# 오늘은 요새 체중조절, 식단조절을 하느라 애쓰는 와와자매에게
# 아침식사 대용으로 먹기 완~전!!좋은 식품을 소개해 드리려고 해요!
# 아침에 밥으로 든든하게 식사하는 것도 좋지만, 출근 전 준비하느라 시간도 촉박하고..
# 요새 체중조절을 하다보니 밥을 좀 덜 먹게 되는게 사실이더라구요..!
#
# 그래서 밥 대용으로 먹을만한 쉐이크나 이것저것 찾아보고 먹어봤는데
# 맛도 별로인건 둘째치고.. 보틀을 씻어서 재사용 해야하다보니 아침에 먹고
# 바로 설거지를 안해놓으면 점심에나 저녁에는 못먹고.. 그런 경우가 너무 많았어요 ㅠ ㅠ
#
# 이런 저희 와와자매에게 딱 맞는 식품을 찾게 되었는데 바로~
#
# '인테이크 모닝귀리' 에요!!
# 아마 간편식에 관심을 갖으셨던 분들은 인테이크 에 대해서 한번씩은 들어보셨을 것 같아요~
#
# 저는 올리브영에서 처음 보고 알게 되었는데, 다양한 간편식을 판매하는 곳 이더라구요 ^0^
# 인테이크의 많은 간편식 중 저희 와와자매 둘다 마음에 든 식품인 모닝귀리!
#
# 모닝귀리는 따로 계량을 해서 섞어먹지 않아도 되게끔 이렇게 개별 보틀에 적당량이 들어있는게 너무 좋아요!
# 휴대하기도 좋고 보틀 설거지를 따로 안해도 되는게 저희 와와자매는 특히 너무 좋았어요 ㅋㅋㅋㅋㅋㅋㅋ
#
# 그리고 가격이 일단.. 지금 50% 할인 중 이라 1,700원 이에요
# 타사 귀리우유랑 거의 두배 정도 가격차이가 나더라구요 ㅠㅠ!!!(할인가 기준)
# 모닝 귀리 *1개입 - 인테이크
# 식사를 연구하다, 인테이크
# bit.ly
# (↑↑↑구매정보는 링크 참고 해 주세요↑↑↑)
# 그리고 다른 간편식 종류도 많이 있었지만, 저희 두 자매는 곡물음료를 좋아하기도 하고
#
# 귀리에 들어있는 베타글루칸 이라는 식이섬유가
# 우유를 만나면 25배나 불어나서 포만감이 오~래 유지된다고 해서
# 인테이크의 모닝귀리를 먹어보기로 했어요~!
# 100% 청정지역 캐나다산 귀리로 만들어진 인테이크 모닝귀리는
# 타임지에서 선정한 10대 슈퍼푸드인 귀리가 무려 99.8% 나 들어있답니다~!
#
# 그리고 저지방 우유와 먹으면 칼로리도 288 칼로리로 가볍게 마시기 좋아요!
# 용기에 섭취법도 나와있어요
#
# 사실 저는 처음에 섭취법을 제대로 안읽어보고 먹어서 ㅠ ㅠ 엄청 오래 흔들어 먹었는데
# 다음날 섭취법을 확인하고 다시 제대로 먹어보니 엄청 빠르게 잘 섞이더라구요!!(이것 또한 신세계..)
#
# 그리고 유통기간은 약 1년정도로 보관도 길게 할수 있답니다
# 마시기 위해 뚜껑을 열어보니 입구부분도 변질위험 없이 꼼꼼하게 덮혀있었어요~!
# 중간 캡을 벗겨보니 통귀리도 중간중간 보이고 귀리 분말이 많이 보이네요~
# 냄새도 맡아봤는데 미숫가루향..? 율무차향..? 그런 향이에요!
#
# 미숫가루 율무차 둘다 넘흐 좋음..ㅋ 없어서 못먹음ㅋ 와와자매 취향저격..♡
# 이제 우유랑 섞어서 먹어볼까요 >_<
#
# 오늘은 집에 저지방우유가 없어서 그냥 일반 우유로 먹었어요..ㅋ
# 섭취법 부분 점선표시 만큼 우유를 부어주면 된답니당
#
# 이게 별거 아닌것 같지만 ㅠ ㅠ
# 전에 쉐이크 먹을때 보틀에 표시가 안되어 있어서 눈대중으로 대충 부어서 먹고
# 컵에 따로 타먹을때도 대충 부어서 먹고 그랬는데..
# 이렇게 용기에 표시가 딱 되어있으니까 너무너무 편하고 좋았어요
# 점선까지 우유를 부어주고~
# 뚜껑을 잘 닫고
# 흔들어주기!
# (왜 때문에 병이 흐물거려 보이죠...?ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ볼때마다 너무 웃김)
#
# 원래 뒤집어서 바닥의 가루를 먼저 쳐줘야 하는데 저는 모르고 그냥 흔들었어요 ㅠ ㅠㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 그래서 이렇게 됨..ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# (우유 붓고 뒤집어서 바닥 쳐주면 이런 떡짐 전혀 없이 완전 깨끗하게 섞인답니당!)
# 바닥에 떡진거 없어지도록 열심히 흔들어 줬어요~!
# 쨘....! 동동 떠있는 통귀리가 보여요
#
# 그리고 우유 섞은 후 바로 먹으면 바삭바삭한 귀리
# 우유 섞은 후 1분 뒤에 먹으면 부드러운 귀리로 먹을수 있다는 사실~!
#
# ...은 홈페이지에 나와있으니 참고해주세요..ㅎㅎ
# 맛은 꿀맛ㅋ 순삭..ㅋ
# 정말 미숫가루 같은 맛이에요~!
#
# 한입 먹으면 통귀리가 입안 가득 들어와서 바삭바삭 씹힌답니다
# 우유 붓기 전에는 많지 않은 줄 알았는데, 먹다보니까 진짜 많이 씹히더라구요
#
# 통귀리를 씹으면서 먹다보니까 그냥 꿀떡꿀떡 마시던 쉐이크에 비해서
# 훨~씬 포만감이 많이 느껴지고 뭔가 식사를 하는듯한 든든한 기분이였어요
# 다 먹고나서 식혜처럼 바닥에 통귀리가 많이 남아있을줄 알았는데,
# 인테이크 만의 모닝귀리 특허기술로 통귀리가 우유위에 동동 떠서 깨끗하게 마실수 있었답니다!
#
#
#
# 그리고 다음날 아침엔 우유가 다 떨어져서
# 두유에도 타먹어 봤어요!!
# 두유에 타서 먹으니까 좀 더 걸죽하고 고소함이 배가 되더라구요~!
# 결론적으론 우유나 두유나 둘다 맛 맛있어요 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ헤헤
#
# 근데 어제는 아빠랑 나눠 마셔서 다 먹었는데
# 아침에는 혼자 먹으니까 배가 너무.. 불러서 혼자 다 못먹겠더라구요 ㅋㅋㅋㅋ
# 그래서 반 조금 덜되게 남겨놨다가 점심먹기 전에 남은거 먹었어요..
#
# 포만감은 진짜 좋은듯 해요!!
# 어제 아빠도 한입 맛보시라고 드렸더니 고소하고 좋다면서ㅋㅋㅋㅋㅋㅋ
# 이제 아침에 이거 먹고 출근해야겠다고 더 주문하라고 하셨어요..ㅋㅋㅋㅋㅋㅋㅋ
#
# 남녀노소 아침식사대용으로 간편하게 먹기 좋은 인테이크 귀리우유..!
#
# 포만감 뿐 아니라 가성비도 너무 좋고 개별보틀로 휴대성, 간편함 까지
# 귀리우유 중 유명한 이유가 있더라구요~!
# 모닝 귀리 *1개입 - 인테이크
# 식사를 연구하다, 인테이크
# bit.ly
# 지금 요기 인테이크 홈페이지에서 50% 할인가 로 완전 저렴하게 구매하실 수 있으니,
#
# 가성비 갑 '인테이크 모닝귀리', '인테이크 귀리우유' 먹고
# 간편하게, 건강하게 식단조절 합시당 ^0^
#
# (와와자매를 포함한 다이어터 분들 화이팅..ㅋ)
#
# 그럼 이만 빠빠잇!
# --------------------------
# 뿌듯
#
# 집에서 간단히 먹을 간편식을 찾다가 요즘 핫한 인테이크를 시켜보았다.
# 이렇게 떼샷이 된 이유는 텐바이텐에서 인테이크 기획 세트를 66% 할인된 가격으로 팔고 있기 때문이다.
# 거기에 수프 세트랑 채소 주스만 더했을 뿐인데 이런 떼샷이 ㅎㄷㄷ
# 아무튼 한동안은 든든한 밥 같은 간식이 되어 줄 것 같다.
#
# http://www.10x10.co.kr/shopping/category_prd.asp?itemid=2020759&pEtr=87531
# 텐바이텐 10X10 : [인테이크X텐바이텐] SEE YOU LATER_ver 2
# 찜브랜드 INTAKE 브랜드샵 [인테이크X텐바이텐] SEE YOU LATER_ver 2 판매가 78,700원 할인판매가 26,900원 [66%] 마일리지 269 Point 배송구분 업체조건배송 배송비 안내 원산지 한국 주문수량 ea 옵션선택 품절된 옵션 재입고 알림 받기
# www.10x10.co.kr
# 우선 한 개씩 간단한 후기를 적어보면(별 5개 만점)
#
# 1. 모닝 채소 ★★★☆☆
# - 하루 권장량의 채소가 들어가 있는 주스
# - 100% 20가지 채소 + 물로만 만들어짐
# - 싱겁고 약간의 녹즙의 슴슴함을 예상했는데 야쿠르트 하루 야채보다 더 달았음
# - 목넘김이 좋고 냉장고에 시원하게 두고 마시면 좋음
# - 재구매 의사는 모르겠음. 확실한 매력 포인트가 없음
#
#
# 2. 모닝 수프 채소 ★★☆☆☆
# - 쌀알을 넣었음에도 위장을 터치하는 정도의 포만감
# - 맛은 밍밍하지 않고 나름 진함
# - 겨울에 먹으면 따뜻해서 더 좋을 것 같음
# - 불편한 점은 컵 안에 물 눈금선이 없어서 물 붓기가 힘들었음
# - 재구매 의사 없음
#
# 눈금선을 밖에 저런 식으로 해둬서 잘 안 보였다. 안에 눈금선 표시를 하는 게 물양 조절 하기에 편할 듯
# 네. 쌀알이 있었습니다. 없는 것보다 있는게 훨 낫습죠
# 3. 모닝 죽 꿀 고구마★★★☆☆
# - 인테이크를 처음 접하게 된 계기로 작년에 올리브 영에서 세일할 때 단호박죽이랑 꿀 고구마죽을 2+1으로 사 먹었다.
# - 별 기대 안 했는데 의외로 맛있어서 놀랐다.
# - 그때는 호박죽이 압승이었고, 고구마는 맛이 좀 별로였는데, 이 제품은 개량 후 제품이라 그런지 맛있었다.
# - 재구매 의사 있음
#
# 4. 모닝 귀리☆☆☆☆☆
# - 개인 취향으로 원래 미숫가루를 안 좋아한다.
# - 모닝 귀리는 신기하게 우유를 부어서 탔는데도 예전에 할머니가 맹물에 미숫가루만 타서 나에게 몸에 좋다고 먹였던 기억을 소환했다. (그 후로 미숫가루는 내게서 멀어졌다)
# - 그래서일까. 이건 6개 왔는데 고맙지가 않네. 이제 하나 먹었으니 5개 남았네.
# - 거기다가 섞을 때도 페트병에 쓰인 대로 반드시 페트병을 뒤집어서 가루를 바닥에서 떼어낸 후에 우유를 넣어야 한다.
# - 그냥 부었더니 암만 팔로 흔들어도 페트병 바닥에 붙은 가루는 떨어지지 않아서 수저로 바닥을 긁어야 했다.
# - 재구매 의사 없음
#
# 5. 곤약 젤리 청포도 ★★★★☆
# - 인테이크 제품 중에서 best 2임
# - 곤약 젤리 먹어보는 게 처음이라서 맛있다고 하는 건지 모르는 게 함정
# - 냉장고에 시원하게 해서 먹으니 꿀떡꿀떡 잘 넘어가고 안심되는 간식이라 좋음
# - 하루에 3~4개는 그냥 먹음
# - 모닝 귀리 줄 테니 곤약 젤리로 바꾸고 싶음
# - 재구매 의사 매우 있음
# --------------------------
# 요즘 정말핫한 인테이크귀리우유 저도 먹어봤어요.
# 저 사실 귀리우유 한참 핫하게 나올때 마트에 가서 귀리를 한포대 사왔거든요
# 신랑이랑 신나서 볶아서 우유에 타먹자고 사왔는데
# 물에 불리고 볶는 과정이 정말 오래걸리고 귀찮고 보관도 쉽지 않더라구요.
# 근데 완전 획기적인 인테이크 귀리우유를 발견!
#
# 이건 역시 대박... 완전 편하고 맛도 더 맛있는 제품이 있네요.
# 진작 알았으면 생으로된 귀리를 사지 않았을텐데......
#
# 어쨋든 직접 유명한귀리우유를 먹어보니 넘나리 좋네여!
# 영양가가 높고 칼로리가 낮아서 곡물의 왕으로 불리는 귀리를
# 더 맛있고 쉽게 먹을수 있는 모닝귀리 정말 좋았어요.
#
#
# 식단조절할때 진짜 좋다고 해서 솔깃했는데
# 먹어보니 왜인지 알겠어요.
# 포만감이 진짜 최고라서 밥먹은것만큼 배가 빵빵하고
# 쉽게 배가 꺼지지 않는다는 장점이 있어요.
#
#
# 통안에 갈은 귀리와 통 귀리가 들어있고
# 여기에 우유만 한팩 타서 먹으면 되니까
# 간편하고 먹기도 좋았어요.
# 게다가 아침대용으로 출근때 가져가기에도 완전 굿
# 칼로리도 낮아서 식단조절에도 아주 도움이 된답니다.
#
# 유통기한도 넉넉해서 좋아요.
# 제가 직접 볶은 귀리는 조금 지나니 곰팡이가 생겨서
# 다 못먹고 버리곤 했었는데ㅠㅠ
# 모닝귀리를 진작에 알았어야했어요ㅎㅎ
#
#
#
# 전 불규칙한 식사를 하다보니 자꾸 폭식하게되서
# 아침대용겸 식단조절용으로 먹고 있어요.
# 요거 먹으면 포만감이 꽤 오래가서 점심지나서까지도
# 배가 별로 안고프니 한꺼번에 몰아먹는 습관을 고치기에 좋아요.
#
#
# 한번 더 밀봉처리되어있어서
# 위생적이고 보관도 편해요.
#
#
# 우유를 부어주면 간편하고 든든한 한끼 완성
# 100% 청정지역 캐나다산 귀리로 만들어
# 더 신선하고 맛있어요.
# 귀리분말 70.8% 통귀리 29% 탈지분유 0.2%로 만들어졌어요.
#
#
# 뚜껑을 닫아주고 거꾸로 뒤집어서 바닥에 탁탁 쳐주면
# 아래 가루들이 떨어지면서 금방 잘 섞여요.
# 몇번 흔들어서 섞어주면 돼요.
# 생각보다 가루가 우유에 잘녹아요.
#
#
# 냄새가 약긴 미숫가루 냄새랑 비슷해요
# 먹어보니 맛도 고소한 미숫가루 맛이 나더라구요.
#
#
# 넘 맛있어서 신나게 먹다가
# 급 내용물을 자세히 보려고 컵에 따라봤어요
#
#
# 귀리 통으로 된 알갱이도 많이 보이는데
# 바삭바삭하니 잘씹히고 맛있어서 좋았어요.
# 귀리 직접 볶았을때는 너무 딱딱하고 질겨서 씹어먹기 힘들었었는데
# 모닝귀리는 우유에 탔는데도 바삭하게 잘 씹히고 맛있더라구요.
#
#
# 아무리 좋아도 맛없으면 꽝인데
# 인테이크귀리우유는 맛도 좋아서 더 맘에 쏙 들었어요.
# 아침대용으로 식단조절 용도로도
# 아주 좋은 귀리우유 한번 맛보세요.
#
#
# 인테이크귀리우유 모닝귀리는 타제품에 비해서
# 가격도 정말 좋아요.
# 몇개 찾아봤더니 생각보다 귀리우유들 가격이 비싸던데
# 합리적이고 가성비 좋은 제품이라서 더 추천하고싶어요.
#
# 지금 할인하고 있다고 하니 고고씽!
# 저도 더 쟁여놔야겠어요.
# 모닝 귀리 *1개입 - 인테이크
# 식사를 연구하다, 인테이크
# bit.ly
# --------------------------
# 식사대용 인테이크 밀스 : 그레인, 코코넛, 소이
# 아침을 자주 챙겨먹던 나는.... 회사 가까운 곳으로 이사를 했음에도 불구하고 아침을 해먹지 않고 있다. 초코우유를 먹다가 요즘에는 덴마크로 바꾸었는데 덴마크를 먹으면 배는 안고픈데 점심때까지 배가 부른게 함정. 게다가 위가 약해서 우유나 그런 걸 먹으면 속이 쓰린 느낌도 종종나서 매일 먹는게 좋지 않을 것 같다는 생각이 들었다.
# 일단 아침대용으로 겟 하긴 했지만, 저녁도 대충먹는 나는 우유를 타서 저녁에 먹어보기로 했다. 일단 나는 미숫가루를 엄청 좋아하는데 항상 [미숫가루 + 우유 + 꿀] 이러한 조합으로 먹었다. 사실..맛없으면 어쩌나 하는 걱정 때문에 여기다가도 꿀을 넣을 각오를 하고 있었음. 저녁이라서 우유랑 먹으면 정말 배도 많이 부를 것 같아서 도전!
# 성분!
# 일단 크기는 이정도. 생각보다 크다. 500ml우유를 넣으니까 꽤 많이 들어갔음. 물이 300ml이상은 들어가는 것 같다. 쉐킷쉐킷. 가루가 꽤 많이 들어서 힘차게 흔들어 줘야함...출근길 내내 흔드니까 잘 섞였는데 그냥 집에서 대충섞으니까 미숫가루 느낌 물씬났음. 잘 섞어주면 진득하니 먹을 수있다....
# [부메랑으로 찍었는데 움짤이 아니라 동영상으로 저장이 되었...]
# 구매처 -  https://goo.gl/bwESGL
# 밀스 3.1 소이 보틀형 *7개 - 인테이크
# 식사를 연구하다, 인테이크
# goo.gl
# 먹는 방법이 옆면에 상세하게 나와있다. 사실 먹는 방법이 어디있나...그냥 넣고 흔들면 됨
# 식감을 위해 컵에 따라 보았다. 사실 바로 먹을 수 있게 나온 제품이라 편리하긴 했다. 근데..진짜 너무 맛잇.... 내가 집에서 일단 먹은건 그레인이었는데, 엄청 고소하고 달달한 맛도 나고... 저 위에 둥둥 떠있는건 그레인 알갱이 같은데 약간 바삭하니 씨리얼이 씹히는 느낌이났다. 누룽지 먹는 느낌? 그래서 그냥 후루룩 마시는것보다 훨 나은 듯. 저녁으로 먹었는데...배가 너무 불러서 같이 사가지고 온 과자도 못먹었다. 진짜 포만감 정도가 아니라 배가 무지 부름.. 물 넣어서 먹으면 좀 덜하려나..??
# 맛있어서 다음날 아침으로 도전 – 아침은 [밀스 코코넛] !
# 아침에 나오면서 물을 붓고 걸어가면서 열심히 흔들었다.
# 자리에 도착해서 물 마시듯 마시니! 굿굿 ! 고소한 냄새에 아침으로 딱인 것 같다. 사실 다 먹으면 점심을 못먹을 수도 있을 것 같아 반 정도 먹고 냉장고에 놔뒀다. 맛있어... 출근길 지하철에서 먹기도 딱인 것 같다.
# 사무실에서 딱!
# --------------------------
# 최근 오래간만에 친구들을 만났는데, 친구들이 모이면 한 번씩 꼭 나오는 주제가 다이어트ㅋㅋ
#
# 살집이 있는 편이 아닌데도 불구하고 콤플렉스 극복을 위해서, 건강상의 이유 등등을 위해
# 종강하면 다이어트할 거야~ 이번엔 뱃살 꼭 뺄 거야~ 항상 그런 이야기가 나온다.
#
# 게다가 여름쯤 되면 방송 매체에서도 다이어트를 주제로 참 많이 이야기를 하는데,
# 사실 다이어트를 해본 입장에서, 체중 감량보다 유지하는 것이 더더욱 힘들다고 생각한다.
#
# 그리고 개인적으로 유지 기간에서 식단 조절의 가장 중요한 것 2가지를 고르자면,
# 규칙적인 식습관 그리고 충분한 영양소 섭취를 가장 중요하다고 생각한다.
# 하지만 이게 말처럼 쉽지 않다는 걸 너무너무 잘 알고 있는데,
# 직장생활을 하거나 학교생활을 하다 보면 즉석으로 끼니를 거르기도 비일비재이고
# 무엇보다 영양소는 무슨 아침에 빵 한 쪼가리라도 먹으면 다행이다 ㅋㅋ
#
# 그래서 이번에 장만해본 인테이크에서 출시한 귀리 우유10개!!
#
# 마지막에도 다시 한번 언급하겠지만, 지금 인테이크에서 귀리우유인 모닝귀리를 50% 할인하고 있는데,
# 6개를 한꺼번에 주문하면 기존 가격보다 좀 더 저렴한 가격으로 구매할 수 있다.
#
# 위처럼 생긴 상자를 열어보면 하얀색 상자에 모닝귀리가 6개가 담겨있다.
#
# 무엇보다 벌크 형식으로 되어있으면 나눠 담다가 자꾸 용량 초과하거나 덜먹거나 하는데,
# 보틀 형식으로 되어있어서 용량을 신경 쓸 필요도 없고 쉐이크 통을 따로 들고 다닐 필요도 없어서
# 바쁜 학생이나 직장인들에게 너무 좋을 것 같다는 생각이 들었다.
# 인테이크 모닝귀리 보틀의 외관!!
#
# 요즘 귀리가 곡물의 왕이라는 타이틀까지 얻으면서 주목받고 있는데,
# 세계 10대 슈퍼푸드로 선정될 정도로 단백질과 식이섬유도 많이 포함되어있다.
#
# 인테이크의 모닝귀리의 성분 중 99.8%는 청정지역 캐나다산 귀리로 구성되어 있고,
# 나머지 0.2%는 탈지 분유로 이루어져 있기 때문에 영양이 가득 포함되어 있다.
# 뒷면에 명시되어있는 인테이크 모닝귀리의 원재료명과 함량, 그리고 칼로리가 명시되어 있는데
# 귀리우유의 총 열량은 208kcal로, 저지방 우유와 함께 먹으면 300칼로리도 채 되지 않는다.
#
# 보관방법은 고온다습, 직사광선을 피하여 서늘한 곳에 보관!! 나는 실온 보관이 너무 좋다.
#
# 섭취방법은 우유를 표시선까지 따른 뒤 용기를 뒤집어 툭툭 친 뒤
# 모닝귀리 내용물과 우유를 잘 흔들어 천천히 마시면 된다.
#
# 그리고 유통기한은 제조일자 기준으로 1년으로, 매우 넉넉하기 때문에 천천히 먹어도 좋다ㅎㅎ
#
# 게다가 모닝귀리 외관이 깔끔한 흰색 케이스로 깔끔하게 나와서 들고 다니는데도 너무 이쁘고
# 가볍고, 들고 다니기 좋은 크기라서 휴대성이 좋은 부분도 너무 만족스러웠다.
# 뚜껑 부분을 열어보면 입구 부분에 안전 캡이 꼼꼼히 싸여있어서
# 변질 위험도 방지되고, 위생적으로도 안심!!
# 특히 나는 꼭 저지방/일반 우유와 함께 먹었는데, 귀리의 성분 중 베타글루칸이라는 식이섬유가 있는데,
# 이게 우유와 만나면 끈적이는 상태가 되면서 약 25배로 늘어나, 포만감이 오래간다고 한다!!
# 처음 귀리우유에 저지방 우유 붓다가 삐끗해서 실패 ㅋㅋㅋ
# 핸드폰 화면 보면서 동영상 찍으면서 우유 붓기가 이렇게 힘들답니다ㅠㅠ
# 재시도!! 이렇게 저지방 우유를 귀리우유 보틀에 쭉 부어서 뒤집어서 바닥에 있는 가루를 툭툭 떼낸 뒤,
# 흔들어 먹으면 되는데, 진짜 단맛도 거의 안 나고, 깔끔한 미숫가루? 되직한 우유 같은 맛이다.
#
# 무엇보다 내용물을 보면 통귀리가 넉넉하게 포함되어 있기 때문에
# 천천히 꼭꼭 씹으면서 먹으면 오독오독하니 식감도 좋고 포만감도 더 오래간다.
# 워낙 통귀리가 많아서 훌훌 마실 수는 없겠지만
# 좀 더 부드럽게 먹고 싶으면 미리 섞어놓고 한 10분 정도 기다린 뒤에 먹으면 좋을 것 같다.
#
# 여담으로, 먹는동안 통귀리가 벽에 달라붙거나 가라앉지 않고 떠있어서 신기했는데,
# 인테이크 모닝귀리는 귀리의 성분은 유지하고, 향, 식감을 향상시키는 안정화 처리 공법을 적용하여
# 일반적으로 덩어리 성분이 있는 쉐이크를 먹을 때 불편한 부분을 개선하였다!!
#
# 나는 보통 출근길에 급하게 아침을 먹지 못하게 되면 아침 대용으로 먹기도 하고
# 갑작스러운 야근이 잡혔을 때, 항상 사 먹곤 했던 저녁을, 모닝귀리로 대체해서 먹기도 했다.
#
# 그리고 이건 개인적인 팁인데, 오랫동안 먹다 보면 바닥에 되직하게 뭉치기 때문에
# 꼭꼭 용기를 뒤집어 가면서 먹어야 마지막까지 깔끔하게 먹을 수 있다.ㅋㅋㅋ
# 모닝 귀리 *1개입 - 인테이크
# 식사를 연구하다, 인테이크
# bit.ly
# 다이어트를 다짐하고 있는 분이나, 유지기에 있으신 분들은 그리고 관심 있으신 분들은
# 위 링크를 통해 인테이크의 모닝귀리에 대한 더 자세한 정보와 리얼 후기를 확인할 수 있다.
#
# 특히, 인테이크 사이트에서 할인쿠폰과, 친구 초대 등 다양한 혜택뿐 아니라
# 인테이크 모닝귀리는 지금 50% 할인을 진행하고 있는 중이라서 가성비도 너무너무 좋아서 강추!!
#
# 식단 조절은 해야 하는데 시간이 없으신 분이나 관심 있으신 분은 꼭꼭 쟁여놓아도 좋을 듯하다!!
# --------------------------
# --------------------------
# 우리 둘째 돌잔치가 한달 남은 돌준맘 소녀감성주부입니다
#
# 요즘 과다한 폭식으로 뱃살이 늘어 스파 갔다 수영복 입고 깜놀했어요
# 저는 아직 둘째 낳기전인 임산부인줄요 ㅠㅠ
#
#  돌잔치가 이제 한달 밖에 안남았으니 최선을 다하자~!!!
# 굴욕 사진을 남길 순 없다 ㅎㄷㄷ;;;;
#
# 그래서 어제부터 식단조절에 들어갔습니다.
# 돌잔치 준비 프로젝트 1. 식단조절 가성비좋은 모닝귀리 / 인테이크 귀리우유
# 지금 제게 가장 필요한것 바로 식단조절
#
# 거창한 식단조절이 아닌 지금 먹는 음식의 반으로 주리고
# 가성비 좋은 모닝귀리/ 인테이크 귀리우유로 대체
#
# 오늘부터 귀리우유로 식단을 바꿨어요
# 인테이크 모닝귀리 50g (208kcal)
#
# 요즘 방송에서 핫한 귀리우유 간편하게 모닝귀리로 시작해요
#
# 귀리우유는 귀리가루에 우유를 타서 먹는건데요~!!
# 저는 모닝귀리에 저지방 우유로 시작 합니다.
# 인테이크모닝귀리는 분말뿐 아니라 통귀리가 들어 있어 식감도 좋고 포만감을 더 느끼게 해주어
# 식단조절 하는 육아맘에게도 딱 좋더라구요
#
# 요즘 방송으로 유명해진 귀리우유
# 많이 챙겨 드시더라구요~!!
#
# 콜레스테롤 0% 건강한 귀리
# 섭취방법도 보기 쉽게 표시 되어 있어요~
# 표시선 까지 우유를 붓고 뚜껑을 닫은 후 위/아래 , 좌우/우로 흔들어주면
# 간편하게 끝~!!
#
# 전 저지방우유를 선택했어요
# 이왕이면 조금이라도 더 식단조절 도움이 될까해서요~^^
# 우리 큰애 늦잠자서 아침 못먹고 갈때 아침식사대용으로도 주니 좋더라구요
#
# 좌우/위아래 잘 흔들어 마시면 끝~!!
#
#
# 매일 아침에 모닝귀리우유와 바나나1개 삶은계란1개로 아점 먹고 육아하면 든든하고 오랫동안 배가 고프지 않더라구요~!!
# 든단하게 먹고 육아시작~!!!
# 엄마 아침 먹었다~!!!
# 오늘도 신나게 놀아보세~♬
#
# 귀리우유라도 다같은 귀리우유 아니죠~!
#
#
# 모닝귀리가 특별한 이유~!!
# - 진짜 귀리로 만든 귀리우유
# - 100% 청정지역 캐나다산 귀로 만들어 더욱 신선하고 맛있어요
# - 귀리99.8% 함유
# - 통귀리가 들어있어 고소함이 2배 포만감 up
#
# 귀리효능
# 1. 다이어트와 피부미용에 도움 : 단백질과 필수아미노산이 풍부한 귀리는 칼로리는 낮고 포만감이 높으며, 수용성 식이섬유인 베타클루칸이 몸 속 지방을 흡수해 몸 밖으로 배출 시켜주고, 염증생성억제와 피부 진정, 수분 공급에도 탁월한 성분이 함유되어 피부미용에도 도움이 된다.
# 2. 풍부한 식이섬유 함유로 변비 예방 : 불포화 지방산이 함유, 현미보다 8배 많은 식이섬유로 변비 예방
# 3. 항암작용 및 혈관 질환 예방 : 수용성 식이섬유인 베타굴루칸이 체내 노폐물을 분해 독을 없애 면역 기능이 향상됨으로 암세포 증식 억제 도움. 칼륨 함량이 높아 나트륨을 배출시키고 혈압 상승 억제해 고혈압, 동맥경화, 싱근경색 혈관질환예방에 도움이 됩니다.
# 4. 골다공증 , 빈혈 예방 : 귀리는 철분과 칼슘이 풍부해 골다공증과 빈혈 예방에 큰도움이 돼 성장기 어린이들 뼈를 튼튼하게 해줍니다.
# 효능이 좋은 귀리를 섭취하는 방법중 제일 간편하게 먹을 수 있는 귀리우유가 최고인거 같아요~!
# http://bit.ly/2kxCgUy
# 모닝 귀리 *1개입 - 인테이크
# 식사를 연구하다, 인테이크
# bit.ly
# 할인 이벤트 중이니~!!
# 육아맘 아침거르지 마시고 건강하게 귀리우유로 아침 챙겨드시고 화이팅해요~!!!
# --------------------------
# --------------------------
# 요즘 정말 핫하다는 귀리
# 회사동료분이 귀리먹고 묵은 뱃살이 들어갔다고 하셔서 ㅋㅋ 저도 한번 먹어볼 생각을 하며 찾아보았는데, 귀리를 막 볶고 그래야 된다고 들었는데. 이렇게 다 볶아서 분말과 함께 우유만 타먹으면 되는 요런 아이가 있더라구요!!
#
#
#
#
# 요렇게 예쁘게 10개 패키지를 받았어요
# 동글동글한 통에 들어있는 귀리들
# 우유만 넣으면 아침 대용으로 한끼 가능한 아이
# 이름도 모닝귀리 예요~!!
#
#
#
# 고운 분말과 함께 귀리알갱이가 들어가 있어요~
# 사이즈도 한손에 꼭 들어가는게
# 일단 너무 귀여운것!
#
#
# 제가 식단조절을 하긴 해야하는데
# 아무래도 굶는건 이제 못하겠고
# 포만감을 채워줄수 있는 아이를 찾고 있었는데
# 요아이가 정말 엄청 불어난대요 뱃속에서
# 그리고 뱃속 지방들이랑 합쳐져 몸밖으로 배출시키는 역활을 한다고! 먹기만 해도 빠진다니..
# 방송에서도 익히 보던 효과!
#
#
#
# 저도 한번 믿고 먹어보나봐요~
# 칼로리는 208칼로리
# 택도 없는 한끼 칼로리지만 ㅋ
# 이게 지방을 잡아서 같이 몸밖으로 내보내 준다니
# 열심히 먹어보겠어요
#
#
#
# 먹는방법은 정말 간단했어요
# 요렇게 우유를 저 선까지 따라 흔들어 마시면 끝!
#
#
#
#
# 고운 귀리 분말과
# 귀리알갱이들이 같이 들어있어요
#
#
#
# 아침 출근길
# 가방에 쏙 들어가는 요 아이를 챙겨 출근했어요~
# 날씨 좋던날 이 날씨.. 이제 정말 미룰수 없다!
# 겨울동안 묵은 지방 빼내야대 ㅋㅋ 하.. ㅋㅋ
#
#
#
#
# 출근해서 제조해본 귀리
# 준비물은 우유!
#
#
#
# 우유를 선까지 맞춰넣고
#
#
# 쉐이킹 쉐이킹!
#
#
#
# 뒤를 톡톡 때려주면서 흔들어야 잘 섞여요~
# 맛은 생각보다 맹맛이예요 ㅋㅋ
# 미숫가루 생각하면 안되요 ㅎㅎ
# 뭔가 꿀넣어서 먹고 싶단 생각도 들고 ㅋ
#
# 참고로 바로 드시면 알갱이가 딱딱한대
# 한 30분 정도 두었다가 마시면 좀더 부드러워요~
#
#
# 일단 10세트 주문하고
# 한 3개 먹어봤는데
# 후기대로 화장실 잘가요 ㅋㅋㅋ
# 변비약도 아니고 이거원 ㅋㅋ
# 확실히 포만감도 있는거 같아요.
# 저도 묵은 지방좀 싹 씻겨내려갔으면 좋겠네요~
#
#
#
# 가격도 지금 50프로 할인행사중이라 저렴하게 구입할수 있어요~ 인테이크 제품 이예요~
# 전 여기 모닝죽이 유명해서 알고 있던 곳이었거든요. 요런 집이라면 믿고 먹어도 될거같아요~
# 저도 한번 꾸준히 식단조절용으로 먹어보려구요~
# 저희 회사에서도 다들 귀리찾아보고 ㅋㅋ
# 진짜 주위에 귀리로 효과보신분들이 계셔서 저도 열심히 한번 먹어보겠습니다!!
#
#
# 모닝 귀리 *1개입 - 인테이크
# 식사를 연구하다, 인테이크
# bit.ly
# --------------------------
# 저번에 응급실을 한번 갔다왔더니....
# (아픈데 기다리는 시간이 넘 끔찍했음)
# 속을 달래주기위해 한번씩 죽을 먹는것도 괞찮겠다라는 생각이 들더라구요
# 그래서 또 간편하게 먹을수 있는
# 죽을 검색했습니다 ㅎㅎㅎ
# 검색을 해보니 인테이크에서
# 모닝죽도 나왔네요
# ( 밀스만 먹어봤었는데 )
# 거기다 평들도 엄청 좋고~
# 이리저리 돌아다니다
# 결국 인테이크 앱을 깔고 회원가입까지해서
# 모닝죽을 주문했어요
#
#
#
#
#
# 총 6가지맛이 있는데
# 전 단호박,꿀고구마,단팥,검은콩
# 4가지맛으로 주문했어요
# 나머지 2가지는 귀리,우유도 있어요
#
#
#
#
#
#
#
#
# 한박스당 총7개의 모닝죽이 담겨져 왔어요
#
#
#
#
#
#
#
#
# 웬만하면 사이트가입을 잘안하는데요
# 가입을하면 또 혜택이 있다고하니 ㅋㅋㅋ
# (혜택이 있다고해도 잘안해요~
# 쿠폰이나 적립금 준다고 해놓고는
# 행사나 이벤트기간에는 적용불가라는
# 사이트들이 넘 많더라는 ㅠ ㅠ)
#
# 인테이크에서는 회원가입하면
# 밀스,모닝죽,그래놀라 중 한가지를
# 무료로 주고
# 플친을하면 바로쓸수 있는
# 적립금도 천원준다길래
# 가입했어요
#
#
#
#
#
#
#
# 마침 행사기간이라 모닝죽
# 4세트를 29900원
# 회원가입하면 적립금 300원
# 플친하면 적립금 1000원
# 밀스3개 7400원이 무료
# 3만원이상 무료배송이지만 회원가입시
# 한번은 무료배송인것 같더라구요
# 총28600원에 구입했어요~~~
#
#
#
#
#
#
#
# 검은콩
#
# 음 근데 검은콩이 딸랑 5%라니;;;;;
# 130g에 칼로리가 90정도면 아침 간단한 식사로 괞찮은듯한네요
# 다만 맛이....
# 다른분들은 건강한 맛이라는데요
# 건간한맛을 내기에는 5%로는 좀 부족한듯요
#
#
#
#
#
#
#
#
# 단호박
#
# 단호박이 22%로가 들어 있다는데
# 첨 나왔을때는 2배정도가
# 더 들었다는것 같아요
# 4가지 먹어본 모닝죽에서
# 그나마 젤 나았어요
#
#
#
#
#
#
#
#
#
# 꿀고구마
#
# 무려 35%의 고구마가 들어 있다는데
# 고구맛은 거의 안나고
# 느끼한맛만 나요
# 다른분들 고구마 넘 맛나다고들 하셨는데 ㅠ
# 전 진짜 느끼해서...
# 딸아이도 느끼하다고 다시는
# 자기한테 이런거 먹어보라 하지 말라네요
#
#
#
#
#
#
#
#
# 단팥
#
# 기존에 먹던 단팥죽을 생각하시면 안됩니다
# 4가지맛중에서 가장 달아요
# 밑에 총내용량을 보시면 아시겠지만
# 당류가 12g 에요
#
#
#
#
#
#
#
#
#
#
#
#
#
# 단팥죽을 한번 그릇에 담아봤는데요
# 쌀알갱이들이 들어 있어요
#
#
# 책에도 개취가 잇듯이
# 입맛에도 개취가 있습니다
# 검색해보고 다들 맛나다고해서
# 구입을했지만
# 제입맛에는 완전 아니였어요
# 넘 달고 느끼했어요
# 그래도 꼽자고 한다면
# 단호박이 그 중에 젤 나았네요
#
#
#
#
#
#
#
# 밀스 3병은 회원가입을 해서
# 무료로 받은 거에요~
# 아직 먹어보지는 않아서
# 맛이 어떤지는
# 알지 못해요
# --------------------------
# 일요일 아침 우리집 밥상
# 짜짜짜짜 짜아아아파게티
# 농땡 짜빠게띠 아니고
# ㅋㅋㅋㅋㅋ
# 곤약밥 바라바라밥!
#
#
#
#
# 갈치구이 장조림 멸치볶음
# 황태북어콩나물국
#
#
#
#
# 햇반 아니고 ㅋㅋㅋㅋ
# 햇반을 가장한 인테이크 곤약현미밥
# 신기하당 이런게 다있네
#
#
#
#
#
# 곤약은 97%가 수분으로
# 구성되어 있어서 칼로리가 매우 적어
# 식이조절 하는데 좋은 음식으로 이미 저명하다
# 그런 곤약밥이 간단하게 햇반으로 나왔당
#
#
#
# 이렇게 주말 아침은 간단하게
# 빵 같은걸로 먹는데 오늘은
# 우리오빠 조금 먹는다길래
# 곤약밥 으로 준비해봤당
#
#
# 정말 다이어트제품 세계는
# 무궁무진함을 느껴본다 ㅋㅋㅋㅋ
#
#
#
# 일단 우리집 먹을꺼 창고에는
# 이렇게 불량주부를 보이는 ㅋㅋㅋㅋ
# 짜짜로땡 그리고 햇반 등이 쌓여있다
# ㅋㅋㅋㅋㅋ
#
#
# 주말엔 짜짜짜짜짜짜로땡
# 햇반 해래래햇반!!!!
#
#
#
#
# 인테이크에서 곤약밥 으로 햇반이 나왔다
#
#
# 곤약백미밥 :: 149칼로리
# 곤약현미밥 :: 149칼로리
#
#
#
#
# 일반 햇반과 곤약밥 을 비교해보았다
# 일단 크기는 작은햇반 정도 된다
#
#
#
#
# 이렇게 옆에서 보면 확실히 작다
# 양 줄이거나 혼밥하는 여성들에게
# 좋은 사이즈이다
#
#
# 그리고 우리오빠도 식단조절 한다고
# 이거 하나먹으니까 배고푸긴 하디만
# 그래도 아침으로는 잘 냠냠 하였당
#
#
#
#
# 곤약현미밥 곤약밥 은
# 칼로리가 낮지만 97%가 수분으로 이루어져
# 있기 때문에 먹을때 꼭 이렇게 나처럼
# 다른 영양소들이 풍부한 음식과 먹어줘야한다
#
#
#
#
#
# 단백질 탄수화물 지방 비타민 등
# 곤약에 부족한 영양소가 들어있는 음식과 함께
# 함께 섭취하여야 좋다
# 그래야 건강하게 식단조절이 가능하다
#
#
#
#
# 오빠가 갈치를 발라주길 기다리는
# 어미새와 아기새 ㅋㅋㅋㅋㅋ
# 결혼하니 조쿠나 ㅋㅋㅋ
#
#
#
# 인테이크 곤약밥은
# 한통에 칼로리가 낮다 147칼로리
#
#
# 곤약 자체가 수분이 풍부하게 함유되어있어
# 몸속 노폐물 및 독소배출에 도움을 준다
#
#
#
#
# 일단 곤약백미밥 곤약현미밥
# 전자레인지 돌리기전 모습이다
# 일반 햇반이랑 비슷하다
#
#
# 먹는방법은 전자레인지 돌리거나
# 끓는물에 넣으면 된다
# 일반 햇반이랑 똑같다
#
#
#
# 우린 이렇게 전자레인지에 돌려줬다
# 혼밥족이나 나같이 식구가 적은 곳은
# 햇반이 오히려 더 싸게 먹히는거 같다
#
#
# 쌀밥 우리는 거의거의 안먹어서
# 주말에는 이렇게 간단히 먹고
# 주중에는 아기만 밥먹는다 ㅋㅋㅋ
#
#
#
# 전자레인지에서 출몰한
# 따끈따끈한 곤약현미밥!!!
#
#
# 곤약현미밥 식감은 일반 즉석밥이랑 비슷하다
# 특별하게 다른건 없었당
#
# 곤약밥 100퍼센트는 좀 먹기 힘들수도
# 있는데 백미 현미랑 섞어 있어서
# 아기도 오빠도 잘 먹었다
#
#
#
# 그리고 백미곤약밥
# 일반 백미에 곤약쌀 섞은거다
# 큰 별다른거 없다 ㅋㅋㅋㅋ
# 식단조절 위한 저칼로리 밥이다!
# 곤약은 식이조절 에도 좋고
# 변비개선 및 장건강에도 좋다
#
#
# 다량의 글루코난만성분과 수분을 함유하고있어
# 장운동을 원활하게해주므로
# 장기능을 강화시켜주고 변비에 좋다
#
#
#
#
# 풍부한 수분을 지닌 곤약은
# 독소배출을 도와 피부미용에도 정말 좋다
#
#
# 특히 곤약의 세라미드성분이 피부에
# 수분공급을 해주어
# 탱탱하고 윤기나게 가꿔준다
#
#
# 내가 밥차리고 있으니까
# 배고푸다고 다다다닥
# 달려오는 우리아기 동영상
# ㅋㅋㅋㅋ
# 인테이크 곤약밥 곤약현미밥 후기
#
# 식단조절 식이조절에 관심은 많은데
# 나는 진짜 밥순이다
# 밥을 진짜 많이 먹는다 ㅠㅠ
# 밥양은 죽어도 줄이기가 힘들다 하는 사람들은
#
#
# 너무 자기의지로 힘든 사람들은
# 이 제품이 도움이 되지않을까 싶다!!
# 더구나 햇반처럼 전자레인지 돌리면 괜찮으니까
# 편리할거 같다
#
#
# http://bit.ly/2sxnphs
# 인테이크
# 식사를 연구하다, 인테이크
# bit.ly
# --------------------------
# 안녕하세요 와와자매 에요~!
# 와와자매가 이번에 위블 사이트 내 인테이크 곡물귀리 베스트리뷰로 뽑혔답니당!!
# 베스트리뷰 당첨으로 인테이크 홈페이지 포인트 50,000원 득템..ㅠㅠ!!!! 감사합니당
#
# 신난 와와자매는 뭘 골라야 알차게 고를까 기대하며 인테이크 홈페이지로 ㄱㄱ!
# 인테이크
# 식사를 연구하다, 인테이크
# www.shopintake.com
# 지난번에 리뷰 작성하면서 홈페이지를 둘러보다보니
# 먹어보고 싶었던게 너무 많았어서..ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
#
# 열심히 고르고 고르기~!
# 그렇게 고르고 주문한 품목들 이에요!
#
# 이번에는 지난번에 만족스러워서 재구매를 하고싶었던 모닝귀리 를 포함해서
# 다이어트로 식단조절 하면서 입이 심심할때 먹을만한 것들로 주문을 해봤어요
#
# [인테이크] 맛있는 곤약젤리 망고 (10개입세트) 11,900
# [인테이크] 맛있는 곤약젤리 복숭아 (10개입세트)11,900
# [인테이크] 밀스 드링크 딸기 (5개) 10,000
# [인테이크] 일렉트로 자몽맛(발포비타민) 6,500
# [인테이크] 모닝귀리 (6개입세트) 9,900
#
# 요렇게 다 해서 50,000원 정도?! 됐답니다
# 이렇게나 많이 시켰는데 인테이크 자체 할인이 있어서 인지 저렴한 편이였어요~!
#
#
# 배송은 이틀? 만에 금방 왔고
# 뽁뽁이에 꼼꼼히 싸여서 터지거나 한것 없이 조심히 도착했답니다 ^_____^
# 실제 갯수들이 많아서 두개씩만 세워뒀어요
# (사실 이 포스팅 작성 전에 이미 먹기도 했고요...ㅋ)
#
# 다양한 인테이크의 식사대용 식품과 간식으로 먹을수 있는 식품들!
#
# 하나하나 볼께요
# [인테이크] 모닝귀리 (6개입세트) 9,900
#
# 우유를 부어 아침대용으로 간편하게 먹을 수 있는 귀리우유 랍니다
# 귀리분말에 통귀리도 많이 들어있고 무엇보다 포만감이 좋고 맛도 좋고
# 개별 보틀로 되어 있어서 휴대, 간편하게 먹기 좋아서 재구매를 하게 되었어요~!
#
# (↓↓모닝귀리는 지난번 리뷰에 자세히 쓰여있으니 자세한 설명은 링크 참고해주세용↓↓)
# 180610 :: [인테이크] 아침대용으로 가성비 좋은 '인테이크 모닝귀리우유' 와와자매 / 강력추천
# 안녕하세요 와와자매 에요!! 오늘은 요새 체중조절, 식단조절을 하느라 애쓰는 와와자매에게 아침식사 대용...
# blog.naver.com
#
# [인테이크] 밀스 드링크 딸기 (5개) 10,000
# (냉장고에서 넣어둔거 꺼내와서 물기 촉촉 비주얼 이에요..ㅋㅋㅋㅋㅋ)
#
# 인테이크 밀스 시리즈는 파우더로 타먹는 쉐이크타입이나 밀스브레드, 밀스칩 등 다양하더라구요
# 그 중 쉐이크는 집에 있기도 하고.. 빵이나 칩은 맛있으면 한번에 다 먹을것 같아서 ㅠ ㅠ..
# 물배라도 채우자 하면서 ㅋㅋㅋㅋㅋㅋ드링크로 골랐어요 ㅋㅋㅋㅋㅋ
#
# 그리고 구매 전 후기를 보니 맛에 대한 평가가 좋아서 더 기대가 되었답니다~
# 바로 마시는 액상형 밀스 드링크!
#
# 파우더를 타거나 흔들거나 할일 없이 먹으니까 확실히 더 좋더라구요
#
# 단, 밀스드링크에는 고농축 우유단백질이 2배 함유되어 있어서 (인테이크 제품 대비)
# 소화기능이 약한 분들은 섭취를 조금 덜 해야한다고 합니당
#
# 실제로 와와동생도 빈속에 먹었는데 속쓰림이 있어서 왜지..? 했는데 이런 이유가 있었네요
# 그 뒤로 점심이나 저녁으로 먹으니까 괜찮았어요!
# (홈페이지에는 천천히 먹어도 괜찮다고 나와있네요~)
# 용량은 300ml이고 영양정보도 참고하세요~!
#
# 밀스드링크 한개 섭취로 하루 섭취해야할 단백질과 식이섬유의 1/3 을 섭취할수 있다고 해요
#
# 유통기한은 제조일로부터 3개월 이던데 8/24까지라서 아직 넉넉하네요 ^____^
# 밀스드링크 딸기맛은 딸기우유 맛일까 했는데 먹어보니
# 딸기우유에 요거트가 살짝 섞인 맛 이였어요
#
# 알고보니 요거트드링크로 유명한 덴마크 브랜드와 인테이크의 콜라보 제품 이더라구요!
# ㅋㅋㅋㅋㅋㅋㅋ괜히 알고 먹으니까 요거트 맛이 더 느껴지는 느낌..!ㅋㅋㅋㅋㅋㅋㅋㅋ
#
# 색도 궁금해서 뚜껑 뜯어봤는데 분홍색도 흰색도 아닌 살색 이더라구요 ㅋㅋㅋㅋㅋㅋ잉?..
#
# 암튼 딸기요거트 좋아하시는 분들은 좋아하실거에요!!!
# ...그게 바로 저 ㅋ
#
# 먹으면 생각보다 배도 오래 부르더라구요!
# 위장장애 없으신 분들께는 추천추천 이에요~!
# 다음은
# [인테이크] 맛있는 곤약젤리 망고 (10개입세트) 11,900
# [인테이크] 맛있는 곤약젤리 복숭아 (10개입세트)11,900
# 에요!
#
# 원래 정상가가 30,000원 인데 할인행사도 하고 있어서 저렴하게 구매했어요
# 맛은 망고, 복숭아, 요구르트 맛 이렇게 있었는데
# 오늘 보니 망고는 없어지고 청포도가 생겨있네요ㅠㅠ! 청포도도 맛있을듯..!
#
# 그리고 요새 곤약젤리가 정말 핫 한데 인테이크의 곤약젤리도 150g에 4칼로리 더라구요~
# 저는 곤약젤리는 다 저칼로리 인줄 알고 편의점에서 파는거 한번 먹었다가 ㅋㅋㅋㅋㅋㅋㅋㅋ
# 100칼로리가 넘길래 당황했다는..ㅡㅡㅋ
# 유통기한은 완전 넉넉쓰..! 거의 1년정도 되나봐요
#
# 인테이크의 곤약젤리 식감은 생각보다 말랑말랑 한 편이고
# 맛은 딱 망고젤리 맛 인데 많이 달달 하더라구요
#
# 저칼로리 곤약젤리 먹어본 것 중에 제일 달달했던것 같아요
# 단맛 좋아하시는 분들은 좋아하실 것 같아요!!
# (그게 바로 와와언니 ㅋ..ㅋㅋㅋㅋㅋㅋㅋ)
# 복숭아젤리도 말랑말랑한건 비슷한 편 이에요
#
# 복숭아맛은 2프로 복숭아맛 인데 간혹 어떤거는 조금 인공적인 향이 난다고 해야할까요 ㅠㅠ...??
# 다 그렇지는 않은데 한두개씩 그런게 들어있는 것 같아요..!
# 못먹을 정도는 아니니까 예민하신 분들은 참고하세요~!
# 다음은
# [인테이크] 일렉트로 자몽맛(발포비타민) 6,500
# 입니다!
#
# 인테이크 일렉트로 는 비타민 B공급을 위한 발포형 타블렛 이에요
# 그리고 비타민 B뿐만 아니라 미네랄이나 아미노산도 함유되어 있어요~
# 섭취방법은 물 500ml에 완전히 녹여서 먹으면 된다고 합니당
#
# 유통기간은 바닥에 적혀있는데... 사진을 찍은것 같은데 지금보니 없네요 ㅠㅠ
# 아무튼 1년정도 남아있었어요 넉넉 하답니닷!
# 사실 와와동생은 비타민제를 챙겨먹으면 속이 메스껍다 해야하나..?그럴때가 있더라구요..
# 그래서 이런 물에 타서 먹는 발포비타민은 어떤가 해서 주문해 봤어요
#
# 맛은 자몽맛, 레몬맛, 청포도맛 세가지가 있는데 저는 요새 꽂혀있는 자몽맛 >____<
# 자몽에이드 먹고싶을때 마다 이거로 대체해야지 하면서 골랐어요 ㅋㅋㅋㅋㅋㅋ
# 사실 오자마자 제일 먼저 먹어본것도 바로 이 일렉트로 에요 헤헤
# 발포비타민은 이렇게 물에 넣었을 때가 재밌어요 ㅋ_ㅋ
# 다 녹으면 자몽자몽 주황주황색!
#
# 원래 물 500ml에 먹는건데... 처음에 그렇게 먹어봤더니
# 너무 많이 밍밍하더라구요 ㅠㅠㅠ...
# 음료 들어있던 통에 물 넣어놓으면 그 향 배이는거 아시죠..? 딱 그런 맛...ㅠㅠㅋ
#
# 그래서...물 양을 줄여도 되나 모르겠긴 한데.. 일단 저는 맛을 위해 줄였어요..ㅋ
# 확실히 안밍밍하니까 맛있더라구요!!!!
# 그리고 그냥 먹어도 좋지만 이게 진짜 꿀맛이에요..
#
# 냉동실에 살짝 얼려서먹기!!!
#
# 이렇게 먹으면 하루에 세번 먹을수 있을 듯ㅋㅋㅋㅋㅋㅋㅋ
# 요새같이 더운 날 얼음음료로 먹으니까 아이스크림 생각도 안나고
# 물이라서 배는 차면서 달달하니까 입 심심하지도 않고 너무 좋더라구요..!!!
#
# 그리고 무엇보다도 속이 안쓰려요 ㅠㅠ! 너무 다행..!
#
#
# 이번엔 골고루 주문해서 이것저것 먹으면서 식단조절하니까
# 확실히 다른 군것질도 안하게되고 건강은 챙겨지는 것 같고 좋더라구요
#
# 저도 이번에 주문한 것들 다 먹고나면 다음엔 빵이나 칩? 쿠키 같은것도 주문해보려구요 ㅋㅋㅋㅋ
#
# 저처럼 여름철 다이어트로 간편식이나 저칼로리 간식 찾으시는 분들은
# 인테이크 한번 보시면 도움 많이 되실 것 같아요~!! 링크 남겨드릴게요!
# 인테이크
# 식사를 연구하다, 인테이크
# www.shopintake.com
#
#
# 구럼 이만 빠이룽~!
# --------------------------
# 건강한 아침밥 추천 인테이크
# 밀스라이트 스윗그레인
# 간편한 아침밥 밀스라이트 스윗그레인 원재료 및 함량
# 현미, 백태, 보리, 흑미, 참깨, 수수가 들어간 곡물믹스부터 분리대두단백, 과당, 치커리뿌리추출물, 혼합두유분말, 탈지분유, 폴리덱스트로스, 볶음콩가루, 과채가공품, 인테이크비타민미네랄밸런드, 난소화성말토덱스트린, 귀리식이섬유, 차전자피분말, 피쉬콜라겐, 효소처리스테비아, 히알루론산-KD, 알로에분말, 히비스커스추출분말, 흰강낭콩추출물분말, 키토산분말, 녹차추출분말 등이 들어간 제품으로 아침대용으로 매우 든든할 것 같아요.
# 원하는 맛으로 골라 1주일치로 주문 가능~!
# 카페라떼, 말차라떼, 벨벳카카오, 로얄밀크티, 스윗그레인 등 5가지 맛이 있어서 취항따라 고르면 되서 다양한 아침대용으로 즐길 수 있어요.
# 밀스 라이트 스윗그레인 1주일패키지(48gx7개)
# 인테이크
# 17,500원구매하기
# 고소한 맛이 부담없이 좋은 밀스라이트 스윗그레인~!
# 여름이 되니 아침에 배가 고파도 딱히 먹고 싶은 것이 없어서 그냥 굶고 마는 경우가 많은데요. 그렇게 되니 점심때 폭식을 하게 되더라구요. ㅠㅠ 이래선 안되겠다 생각해서 간단한 식사대용으로 주문한 밀스 라이트 스윗그레인~!
# 밀스라이트 보틀형 즐기는 법~!
# 보틀에 물을 적당량 기호대로 넣고 뒤집어 바닥에 가라앉은 분말을 떼어낸 후 흔들어주기~!
# 연한 맛을 선호하시면 물을 많이 넣고 용기를 뒤집어 바닥을 톡톡 쳐서 바닥에 묻어 있는 분말을 깔끔하게 떼어주어요.
# 그리고 마지막으로 내용물이 잘 섞이도록 쉐킷쉐킷하면 끝!!!
# 우유나 두유를 넣어 먹어도 좋은 밀스라이트~!
# 맛은 선식보다는 부드럽고 고소해서 미숫가루맛과 비슷했던 스윗그레인~! 고소하고 담백한 맛이 좋아 아침에 즐기니 더더욱 든든하고 부담없어 출근길 마시다보니 쏠랑쏠랑 다 마셔버린 아침대용으로 추천 드리는 밀스라이트 스윗그레인~! 마침 집에 우유가 똑 떨어져서 물에 타 마셨는데 그럼에도 불구하고 어쩜 이렇게 부드럽고 고소하지..??? 싶었다능~!! 탄수화물, 단백질은 물론 10종 비타민과 8종 미네랄까지 갖춰져 더욱 든든한 아침을 간편하게 즐길 수 있어서 간단한 아침밥으로도 좋고 식단조절에도 좋아 추천 드리는 인테이크 밀스라이트 스윗그레인이었습니다.
#   밀스 라이트 스윗그레인 1주일패키지(48gx7개)
# 인테이크
# 17,500원구매하기
# --------------------------
# --------------------------
# --------------------------
# 탄수화물중독 다이어트 곤약밥 추천
# @인테이크 곤약 즉석밥
#
# 내가 다이어트 식품 제품개발자였다면
# 제일 먼저 개발했을 것이 바로 #곤약현미햇반
#
# 근데 인테이크에서 먼저 열일해주셨다!!
#
# 현미(백미)와 곤약쌀을 1:1로 배합해
# 칼로리를 확 줄인 건강한 밥이 출시되었더라능!
#
#
#
#
#
#
# 식이섬유 풍부한 곤약과
# 밥맛을 해치지 않을 정도의 국내산 현미(백미)를
# 1:1 로 배합하면....
#
# 그 칼로리는 과연???
#
#
#
#
#
#
# 149kcal
#
#
#
#
# 이렇게 백미로 나와준 것도 고마운데..
#
#
#
#
#
# 곤약쌀 + 현미의 조합이라니????
# 다이어트하기에 최적의 탄수화물이 아닌가..!
#
# 이제 핑계댈 수도 없당...
#
#
# 양은 125g
#
# 고구마가 탄수화물 섭취로 좋다곤하지만
# 그건 일반인들에게나 통하는 얘기고..
# 나같은 고구마귀신인 사람에게
# 고구마100g만 먹기는 너무나도 힘들당..
#
#
#
#
# 게다가 한번 찔때마다 하나만 찔수도 없고
# 여러개 쪄놓다보면 보관상어려움도 있고...
#
# 소포장된 고구마를 사먹자니
# 너무 비싸고...
#
# 뭐 암튼 그렇게 고민하던 찰나
#
#
# 한끼 가볍게 먹을 수 있는,
# 상온에 보관도 가능한,
# 식단조절 최적의 아이템
# 인테이크 곤약현미밥 & 곤약백미밥
#
#
#
# 일반 즉석밥 소용량으로 나오는 것도 많지만
# 이게 제일 최저의 칼로리일 듯 하다.
#
# 지금 우리집에 쌓아놓고 먹는
# 140g짜리 흑미밥인가? 그것도 칼로리가 198인가 그런데...
#
# 이건 뭐 150kcal 도 안됨..
# 여기다가 브로콜리 약간, 닭가슴살만 뜯어먹어도 한끼 충분해보인다.
#
#
# 양은, 물론 적당히 적다 ㅎㅎㅎ
#
#
#
#
# 곤약현미밥
# 개봉!
# (렌지돌리기전)
#
# 전자렌지에 2분정도 돌려주면 된다.
#
#
# 브로콜리 잘라서 뜨거운물에 데치고
# 파프리까 씻어서 칼로 자르고
# 닭가슴살스테이크 렌지에 1분30초 돌리고
#
#
#
#
# 곤약현미밥
# 렌지에 2분 윙~~
#
#
#
#
#
# 살짝 투명한 곤약쌀이 보이지만
#
# 먹어본 맛은...??
#
# 어디가 곤약???????????ㅋㅋㅋㅋ
#
#
#
#
# 본격적인 식사타임이다.
#
# 한끼 제대로 챙겨먹기!
#
#
#
# 색감살려서 맛있게 먹으니
# 기분이 좋다.
#
#
#
#
# 개인적으로 즉석밥 용기채로 먹는 걸 안좋아해서
# 한 접시에 같이 담아서 먹었다.
#
#
#
# 지난번 사다놓은 저염명란젓도 꺼내고
# 엄마가 담가준 김치까지 꺼내어 맛있게 냠냠
#
#
#
#
# 이런게 행복이징...
#
#
#
#
# 밥도둑 명란젓 ...
# 저염이라서 안짜고 맛있어!!!
#
#
#
#
#
# 이틀 연속으로 밥 챙겨 먹는 중
# 오늘은 현미대신 백미로다
#
#
#
# 살~~짝 노르스름한 색깔의 곤약백미밥
# 색상이 비슷해서 그런지 곤약현미밥보다 곤약느낌이 더 안난다.
#
#
#
#
# 렌지 돌려서 한 스푼 떠보았다.
#
# 그냥..
#
# 그냥..
#
# 밥인데?
#
#
#
# 브로콜리 다먹고  양파가 몇개 있어서
# 양파 큰거 하나 굽굽
#
# 닭가슴살 150g 짜린데
# 밥이랑 같이 먹었더니 배불러서 50g정도는 남긴듯하다.
# 남은거 내일 먹어야징
#
#
# 탄수화물중독 밥순이 다이어터들을 위한 단비같은 아이템!
# 정량만 먹기 힘든 사람은
# 요런 즉석밥 탄수화물로 섭취하면 더 좋다. (물론 나얘기)
#
#
# 요즘 식단조절 안되고 해서
# 스트레스받고 빌빌거리고 있는데...
# 고구마대신 밥이라도 있어서 다행이다. (아님 빵 폭식했겠지..)
#
# 제발 목표를 가지고 다이어트에 임해야지!
#
#
#
# 상세정보는
# 인테이크에서 누끼 따옴!
#
#
# 난 개인적으로 달달한 백미밥보다 꼬수운 현미밥을 더 선호하는 편이라서
# 앞으로 추가로 구매할땐 아마 곤약현미밥만 구매할 듯 하다 :)
#
# 하지만 현미식감싫어하는 사람들은 곤약백미밥먹어도 괜춘.
# 왜냐면...
#
# 칼로리가 착하니깐!!!
#
# #탄수화물중독 #곤약밥 #식단조절 #식이조절 #즉석밥 #현미밥 #현미햇반#곤약햇반
# 인테이크
# 식사를 연구하다, 인테이크
# bit.ly
# --------------------------
# 요즘 정신없이 지내다보면 끼니 챙겨먹기가 여간 귀찮지 않은데.. 우연한 기회로 알게 된 인테이크 곤약즉석밥 시리즈가 내 꿀템이 되었다.
#
#   곤약백미밥과 곤약현미밥 이렇게 두가지가 있어 입맛대로 고르면 됨. 둘다 149칼로리로 저칼로리를 자랑하기 때문에 식이조절용으로도 상당히 좋다.
#
# 당류 0g, 탄수화물은 1일 필요 영양성분 대비 12%로 적은 편이어서 탄수화물 중독인 사람들에게도 좋은 대안이 될 듯 하다.
# 나도 요즘 빡세게는 아니지만 최소한의 식이조절은 하려고 하는 중인데, 다이어트 한다고 매번 고구마나 닭가슴살만 먹으면 우울해지니깤ㅋㅋ 건강한 느낌으로 밥 한끼 먹고싶을 때 집어들게 되는 인테이크의 곤약즉석밥이다ㅎㅎ
#
# 1개는 전자렌지에서 2분이면 충분하다. 2개를 돌릴 때는 3분!
# 요렇게 곤약백미밥에 바삭한 김만 있어도
#
# 밥이 아주 꿀떡꿀떡 잘 넘어갈 것 같다. 그치만 난 좀 더 야무지게 차려먹고 싶으니까 ㅋㅋ 고추장불고기에 가지나물, 시금치나물, 아욱국까지 곁들여 한 끼 식사 든든히 했다.
#
# 곤약현미밥은 다소 꼬들한 식감인데 반해 곤약백미밥은 찰기가 있다. 조금 질은 듯한 밥을 선호하는 사람은 곤약백미밥을, 고두밥을 좋아하는 사람은 곤약현미밥을 선택하면 입에 맞을듯.
#
# 한 술 떠보자.
#
# 고추장돼지불고기를 곤약밥 위에 척 얹어서
#
# 냠냠.
# 맛있고 든든하지만 가벼운 한 끼 식사 완료!
#
#
# 곤약현미밥을 집어들었던 어느 날은
#
# 좀 더 라이트한 느낌으로~ 나물들에 김치, 소고기무국을 곤약현미밥에 곁들여서 먹었다.
#
# 이 날은 그릇에 따로 덜기 귀찮아서 곤약즉석밥 용기 그대로 놓고 먹었음 ㅋㅋㅋ
#
# 꼬들꼬들 구수한 곤약현미밥 한술에 달달한 멸치볶음을 얹어서 냠.
#
# 다른 반찬 크게 없이 요렇게만 먹어도 밥이 술술 들어간다. 곤약을 쌀에 섞어 밥을 지을 생각은 누가 처음 한걸까? 밥 한공기를 먹은 것처럼 배는 부르게, 그치만 칼로리는 절반으로~ 정말 좋은 아이디어라는 생각이 든다. 친구한테 소개해줬더니 자기 남편 체중조절해야하는데 당장 사먹여야겠다며ㅋㅋㅋㅋ
#
#   물론 식이조절에 좋겠다고 한 만큼, 밥공기 한가득 고봉밥의 양을 기대하면 노놉ㅋㅋ 그래도 반찬을 든든하게 잘 곁들여먹으면 부족하다 느껴지진 않는다.
#   밥하기 귀찮을 때, 시간 여유가 없어 빠르게 밥을 차려먹고 치워야 할 때, 다이어트 중이지만 부실하게 먹고싶지는 않을 때 넘나 좋을 인테이크의 곤약즉석밥 시리즈.. 추천!!
# 인테이크
# 식사를 연구하다, 인테이크
# bit.ly
# --------------------------
# --------------------------
# --------------------------
# --------------------------
# 인테이크 3분카레 버터치킨커리
# 자취생이나 혼자 사는 분들의 오랜 친구.
# 바쁠 때 간단하게 한끼 해먹기 좋은 것이 3분 카레인데요.
# 저도 혼자서 밥을 먹을 때가 많아서 자주 사먹고 있습니다.
#
# 직접 카레를 해먹거나 밖에서 사먹는 것도 맛있지만, 역시 카레는 인스턴트 3분 카레가 최고죠.
# 오늘은 인테이크에서 나온 버터치킨커리를 먹어봤습니다.
# 인테이크 버터치킨커리와 한끼 백미밥.
# 간단하게 한끼 때우기 정말 좋은 조합이죠.
# 전자렌지에 돌려서 먹으면 그냥 끝이니까요.
#
# 인테이크 버터치킨커리는 인도식 프리미엄커리입니다.
# 닭다리살이 들어가 있고, 버터도 조금 들어가 있어요.
# 버터의 고소한 맛이 일품인 치킨커리입니다.
#
# 유통기한은 2020년 5월 8일까지로 넉넉합니다.
# 용량은 한팩당 120g.
# 일반적으로 많이 찾아볼 수 있는 오뚜기 3분카레가 200g인데 인테이크 커리는 120g이라 양이 조금 적습니다.
#
# 먹는 방법은 일반 인스턴트 카레와 동일합니다.
# 끓는 물 이용시 봉지 채로 넣고 3분, 전자렌지 조리시에는 랩 씌우고 2분.
# 전자렌지 조리시에는 당연히 개봉해서 넣어야 합니다.
# 안그러면 터져요.
# 커리 칼로리는 185kcal입니다.
# 양이 좀 적어서 그런지 칼로리도 낮은 편이네요.
# 남성 분들 사이즈에는 조금 모자라다 느낄 수도 있을 것 같습니다.
# 추청쌀이 들어갔다는 한끼 백미밥.
# 용량은 210g입니다.
# 전자렌지에 돌려도 되지만 끓는 물에 넣어서 먹는게 더 맛있는 것 같아서 물에 끓여먹었어요.
# 찍어먹을 빵과 버터치킨커리.
# 난 종류긴 한데, 약간 간이 된 빵입니다.
# 원래는 난을 사오려고 했는데, 다 떨어졌길래 이거라도 먹자 싶어서 사왔습니다.
# 좀 이쁘게 잘라보라고 했더니 이렇게 잘라놨네요.
# 뭐 찍어먹기에는 좋으니 그냥 먹습니다.
# 원래 뚝배기보단 장맛이죠.
# 건더기는 사진에 보는 것처럼 적당히 들어있습니다.
# 함량 비율로 보면 고기 함량이 높긴하지만, 전체적인 양이 작아서 체감이 잘 안되네요.
# 커리 향이 상당히 좋아요.
# 맵지도 않고, 부드러워서 밥이 땡기는 냄새입니다.
# 빵에 찍어먹어보니 달달한 맛의 빵에 고소한 카레가 겹쳐져서 그런지 맛이 좀 애매하더라구요.
# 물론 달달한 거 좋아하는 저는 맛있게 먹었습니다.
# 하지만 다음부터 달달한 빵은 카레에 찍어먹지 않는 걸로!
# 카레에 찍어먹을 때는 역시 아무 간이 안되어 있는 빵이 좋은 것 같아요.
# 함께 받은 백미밥에 먹어봤습니다.
# 집에 감자가 남아 있어서, 남은 감자도 함께 넣어서 먹었어요.
# 빵에다 찍어먹을 때보다 밥이랑 먹을 때가 더 맛있었어요.
# 역시 카레는 밥입니다.
#
# 백미밥은 약간 찰기가 있는 편이에요.
# 튼실한 감자와 닭다리 살.
# 닭다리살이 상당히 부드럽습니다.
# 비계도 안붙어있어서 먹기도 좋구요.
# 아쉬운건 양이 좀 적다는 것.
#
# 맛에 대해 총평을 하자면, 가볍게 먹기 좋은 부담없는 맛.
# 살짝 매콤한 맛이 있어서 먹은 후에도 깔끔합니다.
#
# 개인적으로 매운 맛을 싫어해서 매운 맛이 조금만 더 약했으면 좋았겠지만, 요즘은 매운게 대세니 어쩔 수 없죠.
# 그래도 버터가 들어가서 그런지 자극적인 매운 맛은 아닙니다.
# http://bit.ly/2KUIfOG
# 부드러운 맛의 카레를 먹어보고 싶다면 버터치킨커리를 먹어봐도 괜찮을 것 같습니다.
#
# 인테이크 버터치킨커리 리뷰 끝.
# --------------------------
# --------------------------
# --------------------------
# --------------------------
# --------------------------
# 칼기상인 아드님 덕분에 아침 기상시간은 정말 빠른데
# 저의 아침은 항상 대충대충.. 굶는 날이 더 많죠.
# 아들 끼니만 겨우겨우 챙겨주는 편인데요.
# 이대로는 안되겠다 싶어서 간단한아침식사로 모닝바게트 먹기로 했어요.
#
# 인테이크 모닝바게트
# 전 개인적으로 바게트를 참 좋아해요.
# 약간 씹는 맛이 있는 딱딱한 빵을 좋아하는 스타일인데
# 가지고 다니면서 먹을 수 있다니요.
# 정말 저의 취저 ㅋㅋㅋ
# 박스에 유통기한 표시도 되어 있고요.
# 1박스당 14봉, 그리고 칼로리 표시도 다 되어 있어요.
# 두둥~
# 좌우 7개씩 14개가 들어있고요.
# 바게트를 한번에 먹는게 아니라 1봉지씩 소분되어 있어서
# 간식으로 먹기에도 좋고,
# 간단한아침식사로도 좋은 것 같아요.
# 특히 전 그동안 커피만 하나 마셨었는데 함께 먹으면 든든할 것 같고요 ㅋ
#   유기농통밀 함유된 인테이크 모닝바게트,
# 바삭바삭하다는 걸 증명할 깨짐 ㅋㅋㅋㅋ
# 정말 바삭해서 잘 부서질 수 있으니 조심해야해요.
# 그리고 고소하고 담백한 맛이에요.
#
# 이거 신기하게... 자꾸 먹게 돼요..
# 간단한아침식사 맞냐며 ㅋㅋㅋ
# 몇 개나 먹는건지 ㅋㅋㅋ
#   1봉지당 15g이고 76kcal라서
# 부담되지 않죠?
# 거기다 통밀을 밀과 황금비율 2:1로 반죽해서 구웠기 때문에
# 고소하고 담백해요.
# 유기농통밀이라서 안심할 수 있고요.
# 아이도 함께 먹었어요.
# 이끌리듯 관심갖는 아드님 ㅋ
# 통밀이 왜 좋은지 아시나요?
# 통밀은 껍질에 섬유질(식이섬유)을 다량 함유하고 있어요.
# 바게트는 퍽퍽한 편인데
# 모닝바게트는 약간 과자 같기도 하면서 담백하더라고요.
# 본격 먹방 준비 ㅋㅋㅋ
# 엄마 먹고 싶은데 ㅠㅠ
#
# 전 주로 아침, 점심을 아점으로 해결하거나
# 아점저..로 해결할 때 많고,
# 커피를 좋아해서 커피는 하루 3잔씩 마시는 경우도 있거든요.
# 완전 저를 위한 간단한아침식사에요.
#
# 마가린, 버터, 소량의 소금을 넣었고
# 설탕을 넣지 않아서 더 마음에 들어요.
# 가로 8cm * 세로 5cm 정도로 작죠?
# 가지고다니면서 먹기 딱 좋은 사이즈라서
# 양이 적은 분들도 2개쯤 먹을 수 있죠?^^
# 아침에 커피나 우유 등과 함께 먹어도 좋고요.
# 여기에 잼이나 버터를 발라 먹어도 되는데요.
# 전 원래 그냥 먹는 것 좋아해서 그냥 커피와 먹었는데
# 먹다 보니까 몇 봉지를...(솔직히 3봉지;;) 까게 되어
# 마지막엔 잼을 발라서 먹어봤는데
# 와!!!! 맛있...어요 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 욕심 많은 아드님도 벌써 양손에 한 조각씩 들고
# 맛을 음미 중이에요.
# 요즘 아무리 아이를 대충 먹인다고 하지만
# 그래도 설탕 많이 들어간 음식은 고민이 많이 되거든요.
# 근데 인테이크 모닝바게트는 그런 걱정 없어서 좋아요.
# 그리고 사이즈도 아이가 먹어도 좋을 크기!
# 두께 1cm 정도고 크기도 부담스럽지 않아요.
# 자극적이지 않기 때문에 평소에 자극적인 맛을 꺼려하셨던 분들께도
# 추천하고 싶은 아침대용품!
#   칼로리가 낮기 때문에 14봉, 1박스를 다 먹어도 1092kal ㅋ
# 맛이 제 타입이고 중독성 있지만 모닝바게트 라는 단어에서 오는
# 뭔가 식이조절을 해야할 것 같고 막 ㅋㅋㅋㅋ
# 그래서 요 며칠 간단한아침식사 용으로만 먹고 있어요 :)
#
#   모닝바게트 *14개입 - 인테이크
# 식사를 연구하다, 인테이크
# bit.ly
# --------------------------
# --------------------------
# 아우디 A8 입고 모습
# 아우디 A8 3.7 콰트로 06년식입니다.
# 좌) 인테이크 탈거한 모습 , 우) 교환 예정 인테이크
# 인테이크만 탈거 해서 바로 부착해버립니다.
# EGR 밸브 교환
# 부착 중 EGR 밸브의 문제가 확인되었기에
# 다른 부품으로 갈아드립니다.
# 이렇게 완료되었지만 발전기와 스캐너에 나오는 문제들을
# 해결해야 합니다.
# 상) 부착 예정 발전기, 하) 탈착한 발전기
# 먼저 발전기를 교환해주고
# 탈거 중인 경음기(혼)
# 경음기(혼) 소리가 나쁘기에 확인해줍니다.
# 단품 테스트
# 좌) 중고 혼 우) 기존 혼
# 탈거하여 단품 테스트를 진행한 결과
# 경음기(혼) 한 개가 고장이기 때문에 서비스로 교환!
# 전구의 필라멘트가 끊어져 있기에 새 전구로 교환!
# 이렇게 서비스까지 다 하면 끝입니다.
# 백천상사
# 수입차 엔진 전문 수리, 수입자 중고 부품, 구입 상담
# www.bcmotors.co.kr
# 백천상사
# 원동기 전문정비, 수입자동차부품, 자동차엔진, 보링 수출, 수입.
# map.naver.com
# --------------------------
# 식사대용쉐이크 인테이크 밀스
# 요즘 다시 일을 시작하면서 아침마다 전쟁이에요~
# 아침밥을 안먹으면 오전 내내 기운이 없어서 꼭 챙겨먹긴 해야하는데
# 일찍 일어나서 밥까지 차려 먹을만큼 부지런하진 않고 ㅜㅜ
# 그래서 간단하게 먹을 식사대용쉐이크를 구매해봤는데요~
# 인테이크 밀스라는 브랜드에요~
# 올리브영에서도 취급하는 브랜드인만큼
# 믿고 먹을 수 있는 회사 제품인것 같더라구요~
# 현미와 땅콩, 맵쌀, 퀴노아, 바질씨드, 7종유산균 등
# 영양성분 하나는 정말 골고루 알차게도 들어갔더라구요~
# 완전 초건강식으로 영양소 골고루 섭취할 수 있는
# 식단으로 드시는 분이 아니라면 오히려 실제로 식사하는 것보다
# 훨씬 건강에 좋을듯 해요 진짜루ㅋㅋ
# 한 상자에 8보틀이 들어있답니다~
# 첨에 비싸다는 생각을 안하진 않았지만
# 음료처럼 생각하니 비싸게 느껴지는거지
# 정말 밥한끼라고 사먹는 값이라고 생각하면
# 충분히 합리적인 가격이고도 남죠~~!
# 보틀 디자인도 너무나 맘에 듭니다ㅎㅎ
# 한 보틀에 95g의 곡물 파우더가 들어있어요~
# 그런데 요즘에는 보틀형뿐만 아니라
# 개인의 필요에 따라 편하게 섭취할 수 있도록
#  파우치형, 벌크형까지도 패키지를 늘렸더라 구여!
# 근데 저는 아침에 가지고 나가서 운전하면서도 마시고
# 할려다보니 보틀형이 젤 간편하고 좋을것 같아서
# 보틀로 구매했어요ㅎㅎ
# 보틀에다가 물만 정량 부어서 흔들면서 나가면
# 외출시에도 간편하게 식사를 해결할 수 있다니 넘 좋죠!
# 원래는 물을 넣는건데 가끔씩 넘 배고플때면
# 우유로 대체해서 먹기도 하는데요~
# 생각보다 굉장히 걸쭉~~해서
# 괜히 물에 섞어 먹으라는게 아니구나 라는 생각이 들긴 해요ㅋㅋ
# 우유랑 섞으면 약간 죽st,,??ㅋㅋㅋㅋ근데 확실히 더 배부르긴 함!!
# 요렇게 물 붓는 선이 표시 되어 있어서
# 따로 ml를 측정하지 않아도 된다는 점이 참 편해요~
# 보통 ml단위가 써져 있는 전용 쉐이커를 이용해야 하는데
# 보틀 자체가 쉐이커 역활을 해주니ㅎㅎ
# 점선에 맞춰서 우유를 적당량 부어주고요~~
# 이렇게 바닥부분까지 완벽히 섞어주기 위해선
# 뒤집어서 톡톡 쳐주고 격렬하게 흔들어 줘야 합니다ㅋㅋ
# 생각보다 바닥까지 완전히 섞기가 힘들어서
# 흔들다가 살이 빠지는건 아닐까라는 생각이 들기도 해요 ㅋㅋㅋ
# 짜잔~땅콩분태가 엄청 많이 들어가있어서
# 씹는 식감까지도 놓치지 않은 식사대용쉐이크에요~
# 전 오히려 그래서 더 좋은데 사람에 따라 호불호가
# 갈릴 수 있을 것 같아요~ 홈페이지 보니 씹히는 땅콩까지
# 파우더로 갈아버린 쉐이크도 있는데 취향에 따라
# 선택하시면 될 듯 하네요:)
# --------------------------
# --------------------------
# --------------------------
# --------------------------
# --------------------------
# --------------------------
# 가성비좋은 인테이크귀리우유
# <모닝귀리>
# 아침에 집에서 또는
# 회사에서 한병씩 잘 타먹고있는
# 인테이크 '모닝귀리'
#
# 나 요즘 건강하면서 맛있고
# 몸에 좋은거 잘 챙겨 먹기 시작했다리 -
#
#
# 우유만 부어 바로먹는
# 영양가득 유명한귀리우유!
# 모닝귀리 페이스북에서
# 엄청 자주봤는데,
# 드디어 내가 먹어보네 !
#
# http://bit.ly/2kxCgUy
# 모닝 귀리 *1개입 - 인테이크
# 식사를 연구하다, 인테이크
# bit.ly
# 지금 인테이크 홈페이지에서
# 한병에 3,400원짜리 모인귀리가
# 할인해서 1,700원에 판매되고 있다.
#
# 지금 사면 핵이득 -
#
# 슈퍼푸드 진짜 귀리 -
# 타임지에서 발표한 세계 10대
# 슈퍼푸드로 선정된 귀리는
# 단백질과 식이섬유가 풍부한 식품이라고 한다.
#
#
#
# 청정지역 캐나다산 귀리로 만든
# 유명한귀리우유 !
#
# 귀리분말 70.8%
# 통귀리 29%
# 탈지 분유 0.2%
#
# 귀리가 총 99.8% 함유되어
# 포만감이 좋아 식단조절에 도움이되는
# 모닝귀리!
#
#
#
# 귀리의 식이섬유 성분인 베타글루칸이
# 우유와 만나면 끈적이는 상태가 되어서
# 약 25배로 불어난다고.
#
# 그래서 포만감 굳 - 가성비 굳 !
#
# 양도 진짜 많아!
#
# 편하게 우유만 쪼르르 부어주면
# 간단하게 포만감드는 영양만점
# 귀리우유 완성 !
#
# 고소하고 담백한 귀리분말이랑
# 씹는 맛을 더해주는 통귀리가 귣귣 -
#
# 우유넣고 흔들어뒀다가
# 조금 뒤인 출근길에 먹어보니,
#
# 통귀리가 불어서
# 더 말랑 말랑 - 마치 보리밥 먹을때
# 보리 씹는것 처럼 식감이 더 좋았음.
#
# 통귀리가 약간 불때까지
# 기다렸다가 먹으면 식감이 더더더 좋다는 점 !
#
#
# 아빠한테 한병 타드렸더니,
# 아빠 진짜 좋아하셨다.
#
#
# 그래서 아빠가 당장 12개 더 주문해달라고해서
# 주말에 주문했더니 지금 배송중.
# ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 아마 오늘 집에 도착할듯.
# 급할때 먹으면 얼마나 좋노 -
#
# 아빠가 말하는 급할때가 언제인지 모르겠지만,
# 아무튼 아빠입맛에도 쏙 들었나보다.
#
# 단맛이 별로 안나서
# 입에 부대끼거나, 당 걱정은 1도 안해도 되니까
# 부모님 건강에도 좋은 한끼가 될듯.
#
# 내 모닝귀리 6병이
# 어느순간 2병으로 줄어든거 보면.
# ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 우유를  200ml 채워서
# 쉨킷 쉨킷 - 흔들어주면 된다.
#
# 용기 바닥에 귀리분말과 통귀리가
# 가라앉아서 잘 안섞어질 때에는
# 용기바닥을 통통 쳐주면 금새 잘 섞인다.
# 밑바닥을 콩콩- 해주면
# 분말 가루들이 호로로록 떨어지는걸
# 눈으로 확인 할 수 있지.
#
# 아주 딱 좋아 좋아 -
# 뚜껑 열자마자 나는 꼬순내 !
# 미숫가루 종류들 원래 즐겨먹는 편이 아닌데
#
# 아침에 빈속으로 출근하는 일이 많아서 그런지
# 이제는 간편하면서 속이 편안해지는
# 그런 아침밥을 찾게되는듯.
#
#
# 먹으면서 죄책감도 안들고,
# 몸에 좋고, 맛있고 건강하고 !
#
#
# 오늘 아침에도 출근길에
# 한병 챙겨서 출근하면서 홀짝 홀짝 -
# 회사에서도 야금 야금 다마셨네 !
#
# 군것질 생각도 안나고 배도 부르고
# 정말 좋으다.
#
# 이걸로 건강한 식단조절과
# 건강한 포만감을 가져보아용.
#
# 가성비좋은 모닝귀리 추천 -
# --------------------------
# 간편한 한끼로 건강도챙기고, 영양도 챙긴다.
# 인테이크 즉석 곤약밥
# 다이어트를 하면서 탄수화물 제한식을 하고는 있지만(말로만ㅠ) 밥 양을 줄이니 배고픔도 느껴지고
# 왠지 허전하며 자주 헛헛한 느낌이 찾아오는지,,,. 이 느낌 아시려나..
#  그리하여 포만감이 있어 다이어트 시 추천되는 방법중 하나인 곤약밥을 먹어보기로 했어요.
# 곤약쌀로 밥을 따로 지으려면 일이 하나 더 늘어나는 느낌인데 제 맘을 어찌 알았느지 즉석 곤약밥 제품이 있더군요.
# 곤약쌀로 더욱 가벼운 149kcal즉석밥 인테이크 한끼 곤약밥이에요.
# 한끼 곤약밥은 곤약과 쌀을 일대일 비율로 섞어 밥을 지은 딱 밥맛에 가까운 곤약밥이랍니다.
#
# 한끼 곤약밥은 곤약과 쌀을 일대일 비율로 섞어 만들어 일반 밥과 크게 맛의 차이가 없다는 게 큰 장점인데요.
# 거기다 즉석밥이라 간편하기 까지 합니다.
#
#
# 일반 밥맛처럼 먹고 싶을 땐 백미밥을.
#
# 좀 더 건강을 챙기고 싶다면 곤약 현미밥을 선택할 수 있도록 제품의 종류도 두가지에요.
# 살균처리한 제품이기에 상온 보관이 가능하고,
# 먹을 때는 간단히 전자레인지에 돌리거나 뜨거운 물에 데워주면 되는데요.
#
# 세상 편한 인테이크 한끼 즉석 곤약밥으로 한끼 차려 먹어볼게요.
# 즉석밥 데우는 법은 모르는 분들 없으실 거에요.
# 요래요래 살짝 개봉을 하고요.
#
# 간단하게 전자렌지를 이용해보렵니다.
#
# 전자렌지 1개는 2분, 2개는 3분 돌려줍니다.
# 금새 뚝딱 곤약밥 완성이요.
# 곤약쌀은 곤약을 쌀알 모양으로 만든 것인데요.  쌀과 섞어 밥을 지어놓으니
# 어느것이 곤약이고, 어느것이 쌀인지 분간이 안되지요.
#
# 곤약이 백미와 현미에 비해 혈당지수가 현저히 낮은 식품이라서
# 혈당조절이나, 다이어트, 탄수화물중독 조절을 위한 분들의 식단조절, 식이조절로 그만일 듯 하구요.
# 식사 패턴이 불규칙하거나 가볍고 간편한 식사를 원할 때에도 권장할 만 한 것 같아요.
#
# http://bit.ly/2sxnphs
# 그래도 뭐니뭐니 해도 우선 밥맛이 좋아야 겠죠.
# 곤약백미밥은 갓지은 밥처럼 찰기가 있고, 부드럽구요.  백미밥 특유의 밥맛이 납니다.
# 현미 곤약밥은 현미의 고소한 향이 나구요. 쌀알이 톡톡 씹히는 식감이 좋습니다.
# 일반 즉석밥과 크게 맛의 차이가 나지 않는 다는게 다행이네요.
#
# 간단하게 반찬만 꺼내서 한끼 곤약밥과 함께 밥상차리기 끝.
# 아이는 백미, 저는 현미로.
#
# 이른 저녁 간단하게 먹었어요. 대신 아이는 좋아하는 순두부 찌개 하나 더 추가 해줬답니다.^^
# 아이도 그저 즉석밥이려니 하고 잘 먹는군요.
# 밥맛이 좋아요. ^^ 칼로리걱정없이 냠냠.
# 밥은 먹고 싶은데
# 칼로리, 탄수화물 때문에 걱정이신가요?
# 부담없는 한끼, 간편한 한끼, 인테이크 한끼 즉석 곤약밥으로
# 칼로리 걱정없는 식단 만들어보세요. ^^
#
# 인테이크
# 식사를 연구하다, 인테이크
# bit.ly
# --------------------------
# 케케 요즘 제가 즐겨 먹는 인테이크의 밀스3.1 스타터키트를 소개해드려용!
# 간편하게 마시는 한 끼 제품으로 유명한 밀스 3.1
# 저는 처음에 편의점에서 접하게 되어 먹어봤었는데!
# 출근하느라 바쁜 아침에 아침식사대용으로 너무 딱 좋더라구요!!
# 밀스3.1은 요렇게 세가지맛으로 구성되어 있어요.
# 밀스 소이, 밀스 코코넛, 밀스 그레인
# 세가지 다 맛본 결과 각각의 맛을 알려드리겠숩니당ㅋㅋㅋ
# 밀스3.1은 이 사진처럼 보틀형도 있구요!
# 사진에는 없는 파우치형과 대용량 벌크형도 있어요!
# 몇번 드셔보구 본인에게 맞는 스타일을 찾으시면 좋을것같아용 ㅋㅋ
# 각각 영양정보가 살짝씩 달라요! 칼로리는 세가지 맛 전부 동일하게 400칼로리구요!
# 밀스3.1의 장점이 이거죵!
# 낮은 칼로리로 영양소를 골고루 섭취할 수 있으며 간편하게 한끼를 해결할 수 있다는 부분!!
# 아주~~칭찬해~~~~~!!!!!!!!!!!!!!!
# 섭취방법이랑 물 넣는 라인이 표시되어있어요!
# 저는 물 타서 먹어보기도 했고 우유 타서 먹어보기도 했는데! 우유 따라 마시는게 더 맛있더라구용 ㅋㅋㅋ
# 더 고소하다고 해야할까! ㅋㅋㅋㅋㅋ
#
# 그리고 진하게 선 까지 따르면 엄청 되직해요!
# 저는 약간 물처럼 마시는걸 선호하는 편이라서 우유 가득 따라줍니당ㅋㅋㅋㅋㅋ
# 연하게 라인보다 훨씬 더 많이요!ㅋㅋㅋㅋ
#
# 흔들어서 섞어주는건 가루가 생각보다 잘 풀리지 않아요 ㅠ ㅠ
# 그래서 젓가락이나 빨대같은걸로 휘휘 섞어서 풀어주는게 좋을것 같아용^^
# 가루를 들여다볼게요!ㅋㅋㅋㅋ
# 왼쪽은 밀스 소이 ! 오른쪽은 밀스 그레인이에요!
# 밀스 코코넛은 그레인처럼 씹히는 견과류나 그레인종류가 들어있구요!
# 밀스 소이는 씹히는것이 없어용 ㅎㅎ 가루만 있답니다!
# 저는 두가지 다 좋아요!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# 물에 타주면 요렇게 그레인들이 동동 떠다닙니다!
# 후루룩 마셔서 씹어먹는 재미가 있어요 ㅋㅋㅋㅋ
# 출근하는길 가볍게 한끼 !
# 가방에도 쏙 들어가는 작고 가벼운 사이즈라서 편리해요 ㅋㅋㅋ
# 버스나 지하철 안에서는 뚜껑 꼬옥 잠가두면 되니까 흐르거나 쏟을일도 없구요!
# 흔들어서 섞어주면 생각보다 잘 섞이지 않으니 많이 많이 흔들어주세용!!!!!!!!!
# 제일 좋은건 진짜 젓가락이나 빨대로 휘저어 주는것이구용!ㅋㅋㅋ
# 저는 보통 요렇게 가득가득 우유 담아서 마십니당ㅋㅋ
# 진~~~~~~~~~짜 배불러요!ㅋㅋㅋㅋ
# 반 정도 마시면 진짜 완전 대박 배부릅니다 ㅋㅋㅋㅋㅋㅋㅋㅋ
# 다 못마시면 사무실에서도 야금야금 점심시간 전까지 마실 수 있어용 ㅋㅋㅋㅋ
#
# 간편하게마시는식사 로 인테이크 밀스3.1 완전 대추천이에용!!^^
# https://goo.gl/bwESGL
# 밀스 3.1 소이 보틀형 *7개 - 인테이크
# 식사를 연구하다, 인테이크
# goo.gl
# --------------------------
# 안녕하세요 매드엔젤입니다.
# #아침식사대용 #마시는한끼 #인테이크 #밀스라이트
# 스타터키트를 6일간 먹어봤어요.
# 일단 간단평가 맛있다. 배부르다.
# 속이편하다. 화장실도 잘갔다!
# 완전만족 ㅠ_ㅠㅋ 진짜 맛있는데
# 울님들 보기에도 그리보일지
# 그럼 후기 들어갑니다 슈웅~
#
#
# 간편하게 마시는 한끼 든든한 밀스
# 밀스라이트 스타터키트 3종셋트
# 카페라떼, 벨벳카카오, 말차라떼
# 세가지 종류가 하나씩 들어있습니다.
#
# 고단백, 고식이섬유,
# 비타민10종, 미네랄8종
# 거기에 여자라면 좋아하는 성분
# 히알루론산, 콜라겐 알로에등+_+까지
# 이렇게 함유된 #식사대용 쉐이크예요.
#
# 라이트라서 칼로리도 가벼운 175kcal
#
#
# 하나하나씩 살펴보면
#
#
# 인테이크 식사대용 밀스라이트 카페라떼
# 세부적인 성분이나 영양성분 확인하세요
# 각  보틀마다 유통기한 표기되어있고
# 간편하게 물이나 우유, 두유만 넣어주고
# 잘 흔들어서 만들어먹는 식사대용 쉐이크
#
# 그런의미에서 뜨거운물은 안돼요 ㅋ
#
#
#
# 인테이크 식사대용 밀스라이트 말차라떼
# 식사대용으로 먹을수 있는 쉐이크 답게
# 영양성분 함유량이 높아요.
# 거기에 간편하게 넣어다닐수 있는 크기
# 마시고 씻어서 분리수거하기도 편하죠.
# 무엇보다도 맛있어요 진짜 으앙.
#
# 맛 순위를 따진다면
# 초코라떼 > 말차라떼 >카페라떼
#
# 제 개인적인 순위는
# 말차라떼=초코라떼>카페라떼
#
#
#
#
# 인테이크 식사대용 밀스라이트 벨벳카카오
#
# 아.. 진짜 초코맛 가득한 느낌이면서도
# 콩가루의 고소함이 느껴지는ㅋㅋ
# 초코 좋아하시는 애기입맛인 호랭이가
# 너무 잘먹을것 같아서 먹다가 한참 웃었던;
#
# 기본 성분이나 보틀상태는 깨끗하고 깔끔
# 한끼로 가방에 넣어다니면서
# 편의점에서  흰우유 하나 사서 타먹거나
# 생수 한병 사서 타먹어도 좋을 그런 ^^
#
#
# 자 그럼 어찌먹느냐. 설명드릴께요.
#
#
#
#
# 생수 기준으로 생각하시면 연하게  선까지
# 넣어서 드시면 되어요
# 우유를 타서 드신다면 그냥 고민하지말고
# 보틀 넥 부위까지 우유를 다넣으세요 ㅋ
# 그래도 달콤하고 고소하고 담백하고~
# 맛이 제대로 느껴집니다.
#
# 저는 생수말고 우유에 타서 먹어서
# 기본 섭취되는 칼로리라 300kcal
# 정도로 되도록 마셨어요 ^^
#
#
# 알갱이가 녹을수 있는 시간을 좀주고
# 쉐킷쉐킷을 여러번 해주세요.
#
#
#
#
#
#
# 우유나 물을 붙어서는 꺼꾸로 뒤집어서
# 몇번 쳐줘서 가루가 내려가게한다음
# 그 다음에 쉐킷쉐킷해주세요.
# 너무 배고프다고 막 대충 흔들고먹으면
# 바닥에 가루가 남아서 붙어있어요.
#
#
#
#
# 벨벳 카카오도. 마찬가지로 우유를
# 끝까지 다 부어준다음에
# (쉐킷쉐킷할 여유만 좀 남겨주시고..)
# 클리어 + _+
# 진짜 정말 다 맛있.
# 개인적으로 커피는 달달한거 잘안먹어서
# 취향차이가 나는거지만 세개다 맛있어요
#
#
# 식사대용 쉐이크 흔들기 쉐킷쉐킷, 이게뭐라고 무한반복하고있는가.
#
# 맛있는 쉐킷쉐킷 흔들기 영상 동영상으로 고고싱 ㅋ
#
# 혹시나 몰라 구매페이지도 남겨봅니다.
#
# 밀스 라이트 스타터 키트 *3개입 - 인테이크
# 식사를 연구하다, 인테이크
# www.shopintake.com
#
#
#
# 저는 그럼 점심 밀스라이트하러 갑니닷~
# 다들 맛있는 식사하세요 ^^
#
#
# 이 글은 위블을 통해 업체에서
# 제품 또는 서비스를 제공받아 작성된 글 입니다.
# --------------------------
# --------------------------
# --------------------------
# --------------------------
# 안녕하세요.
# 제가 밥먹는걸 가끔 귀찮아하기도하고
# 밤에는 배가고프면 밥을 먹기에는
# 부담스러워서 찾게 되는
# 든든하면서 식사대용의 선식을 좋아해요!
# 다른제품도 먹어봤는데 인테이크게
# 제일 맛있어서 반해버렸습니다.
#
#
#
# 인테이크
# INTAKE
# 밀스 라이트
# MEALS LIGHT
# 50g 175칼로리
# 카페라떼/ 벨벳 카카오/ 말차라떼
#
# 열량이 175Kcal로 먹고나면
# 금방 배고플것 같지만 전혀 안그래요!
# 두유 섞어 마셨더니 세네시간은 가네요.
# 비타민10종과 미네랄 8종 지방은0g
# 건강한 성분조합으로 먹을수록 내몸은 튼튼!
#
# 병으로 편리하게 나와
# 먹는방법은 간단합니다.
# 병에 점선에 맞춰
# 물이나 우유 200ml를 넣어 흔들어 마시면끝!
#
# 탄수화물 63% 단백질 37% 지방0%
#
# 비타민과 미네랄 영양의 조합이 참 좋지요!
# 굳이 영양제 안챙겨 먹어도 될정도에요!
# 콜라겐 히알루론산 알로에등
# 다양한 원료가 있어
# 출퇴근길, 수업중 쉬는 시간 편하게 먹을 수 있는 가벼운 한끼 식사에요.
#
#
#
# 밀스 라이트 카페라떼
# 로스팅한 원두향이 물씬나는 진한 커피로 만든라떼의 부드러움과 달콤한 바닐라향이 어우러진 카페라떼입니다.
# 개인적으로 카페라떼가 가장 맛있었어요. 미숫가루같으면서도 커피우유같고 향이 너무 좋아서 카페라떼만 먹고싶네용.
#
#
# 밀스라이트 벨벳 카카오
# 네덜란드와 독일의 카카오로 부드럽고 달콤한 카카오 본래의 맛을 구현
# 카페라떼 다음으로 가장 맛있었던 카카오! 분말형태이다보니 초코우유보다는 걸쭉한데 초콜릿향이 고급져요.
# 허쉬초콜릿우유 느낌이라 단게 땡기는 날에 찾게되네요.
#
#
# 밀스라이트 말차라떼
# 국내산 말차와 녹차가루의 산뜻함에
# 오곡분말의 고소함을 더한 라떼
# 녹차라떼 좋아하시는 분들에게 추천하는 맛입니다. 녹차특유의 씁쓸함과 향이 은은하게 느껴져서 맛있어요.
#
#
# 먹는법이야 너무 간단하죠.
# 선식이나 식사대용식을 좋아하는
# 저는 베지밀도 사놨어용.
# 두유 하나 다 넣고 쉐킷쉐킷 흔들어 섞으면됩니다.
# 흔드는동안 팔뚝살도 다이어트!
#
#  그리고 다시 뚜껑을 열어 열심히 마시면
# 속 든든 배고픔 사라짐!
#
# 다른 브랜드도 먹어봤는데
# 거짓말아니고 인테이크 밀스라이트가
# 가장 맛있어요.
# 그동안 실패를 많이해서 그런지 첫모금 먹자마자 동공이 확 커지는 맛이었어요!
# 그런데 부작용은..
# 너무 맛있어서 밥먹고 또 생각나서 먹게됨요.. 다이어트는 저멀리..캬캬
# 장점은 매운거먹은 날 밀스라이트먹고자면 다음날 변기위에서 덜 고통스러워욬ㅋㅋ
#
# 냉장고에 고이 모셔놓은 밀스라이트!
# 인테이크의 곤약젤리는 복숭아 청포도 다 먹고 아껴먹을려고 레몬은 고이 남겨놨어영.
# 역시 다이어트 대용식으로는
# 인테이크가 짱인것 같아요!
# https://bit.ly/2HQlf5w
# 밀스 라이트 카페라떼 * 7개입 - 인테이크
# 식사를 연구하다, 인테이크
# bit.ly
# 이 글은 위블을 통해 업체에서
# 제품 또는 서비스를 제공받아 작성된 글 입니다.
# --------------------------
# 인테이크 식사대용 밀스브레드
# 내가 처음 인테이크를 접한 건 밀스 3.1 그레인이었다.
# 남편이 페이스북에서 밀스 그레인이란 걸 보고 재미있는것 같다면서
# 이벤트로 신청을 하게 되면서이다.
# 처음 봤을 땐 미숫가루랑 다른게 모 있어 그랬는데,
# 비타민도 듬뿍~미네랄도 듬뿍이라
# 정말 식사대용으로 괜찮은 것 같았다.
#
# 이번에 인테이크에서 또 다른 신제품이 나왔다길래 도전해보았다.
# 구매를 아래 링크에서 가능하다.
# https://bit.ly/2H3hWnL
# 밀스 브레드 *7팩 - 인테이크
# 식사를 연구하다, 인테이크
# bit.ly
#
# 밀스브레드는 빵 형태로 만든 든든한 한끼식사라고 한다.
# 총 400칼로리, 100g,
# 고단백 (1일 기준치의 31%), 고식이섬유 (1일 기준치의 36%). 7종의 비타민, 7종의 미네랄이 들어있다.
# 성분은 계란이 25%, 밀가루가 22.9%, 설탕, 버터 등등이다.
# 다른것보다 버터가 들어가서 좀 더 신경쓴 느낌이다.
# 1박스에 총 7개가 들어있다.
# 하루에 1개씩 아침대용을 먹으면 딱 1주일치 분량인 것 같다.
# 1개씩 파우치형으로 포장되어 휴대성이 좋아보인다.
# 포장을 뜯자마자 어디선가 꾸리꾸리한 냄새가 난다.
# 실험실에서 자주 맡았던 Yeast extract 냄새와 비슷하다.
# 순간 내가 잘못된 선택을 한걸까? 라는 생각이 들기 시작했다.
# 생긴것도 좀 못생긴듯하다.
# 초보베이커가 만든 핸드메이드 느낌이다.
# 생긴것도 참 발효하다 망한 떡진 질감의 빵같다.
# 근데, 집에서 만들면 떡지게 만들어도 묘하게 맛있다.
# 밀스브레드도 약간 집에서 만든 홈메이드 느낌이 난다.
# 비주얼은 핸드메이드같이 투박하고 처음 먹었을때는 이게 모야 이랬는데
# 한입두입 먹다보니 은근히 고소한 맛이 느껴지면서 꽤 먹을만하다고 느껴진다.
# 따뜻한 커피와 함께 아침으로 먹으면 더욱 고소할 것 같다.
#
# 보관도 실온에 그냥 보관하면 되는지라 편할 것 같다.
# 아침을 잘 챙겨먹지 않는 남편을 챙겨주면 좋을 것 같다.
# --------------------------
# INTAKE 모닝바게트
# [인테이크]
#
#
#
#
#
#
#
# 아침을 잘 안먹고,
# 바삭한식감이 좋으니 그냥...
# 아침마다 빵, 과자를 먹기에,
# 몸에 좋은 건강한 과자(?) 간식(?) 을 찾았다.
# 내 몸을 생각하고, 아기를 생각해서
#
# 식이섬유 풍부한
# 유기농 통밀로 만튼
# 간편한 모닝바게트
# No 합성보존료, No 설탕
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1박스 14봉지 들어있고,
# 1봉지에 2조각 정도.
# 1봉지
# 76kcal
# 당류 0g
# 지방 4g (7%)
# 포화지방 2g (13%)
#
#
#
#
#
#
#
#
#
#
#
#
#
# 바쁜오전이나, 가방에 넣어다니며,
# 간단하게 먹기 좋은 한봉지.
#
# 바삭한 바게트 좋아하는데,
# 하나 사면, 한번에 먹기도 힘들고
# 보관도 힘들었는데,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 낱개로 소량포장되어 있고,
# 딱! 먹을만큼만 먹을 수 있어서 좋다.
#
#
#
#
#
#
#
#
#
#
#
#
#
# 주말, 소소하게 바게트랑 브런치TIME
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 딱 먹기좋은 크기로 바삭바삭
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 내가 좋아하는 래핑카우 치즈 하나 올려
# 쓱쓱- 발라 먹으면...
# ╰(*´︶`*)╯♡
#
#
#
#
#
#
#
#
#
#
#
#
#
# 이런 통밀크래커 같은거 너무 좋아해서
# 미주라토스트 완전애정하는데,
# 같은 통밀 이지만, 미주라토스트랑은 다른맛!
#
# 미주라는 “고소 담백” 이라면
# 모닝바게트는 “고소,짭잘,담백”
#
# 그래서, 미주라는 스프레드나 치즈없이
# 3개이상은 조금 질리기도 하던데,
# 이거는 짭짤한 맛 이 있어서
# 치즈, 스프레드 없이 이것만 먹어도 맛있다.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 인절미 스프레드 올려 먹으니
# 짭짤, 고소함도 2배!!
# 참 잘 어울리더라능 :-D
# 딸기잼, 누텔라 등등 안아울리는게 없어.
#
# 무엇보다 낱개포장이 너무 마음에 든다.
# 외출할때도, 간식으로 한봉지...
# 바쁜 아침에 그냥 한봉지들고 나가면 끝!!
# 굳이 발라먹지 않아도 짭짤 담백해 맛있다.
# --------------------------
# 로라입니다 :D
#
# 오늘은 아침 대용으로 먹기 좋은 간편식 인테이크 모닝죽 포스팅 가져왔어요!
# 저는 위메프에서 특가 할 때 구입했어요~
#
# 저는 사실 아침 잘 챙겨 먹는 편이 아니라서ㅋㅋㅋㅋㅋ
# 오빠 아침에 출근하면서 급하게 나갈 때 갖고 가라고 주문해준 건데,
# 질릴까 봐 종류별로 다 산 김에 포스팅을.. *'▽'*
#
#
#
#
# 따로 숟가락도 필요 없고, 데울 필요도(원하면 전자레인지 사용 가능), 부피도 많이 차지하지 않는 데다
# 냉장/냉동 필요 없는 실온 보관이라 보관도 용이한 정말 간편식!
#
# 다만 하나로는 좀 부족한 느낌이 들긴 하더라구요ㅋㅋ 두 개는 먹어줘야...
#
#
#
#
# 전 그냥 맛보는 겸 꿀고구마 하나만 먹어봤는데
# 되게 맛있어 보였는데 솔직히 엄청 맛있진 않더라구요ㅋㅋㅋㅋㅋ
# '죽'이라고 했을 때 떠올리는 맛보다 좀 많이 달았어요! 약간 시큼한 달달함?
#
# 개인적으로는 맛보다는 간편함에 점수를 줘야 할 것 같아요ㅎㅎ...
#
#
#
#
# 다 먹어본 오빠에게 순위를 매겨달라고 하니
# 단호박 ≥ 단팥 > 우유 > 꿀고구마 > 검은콩 >>> 귀리 순이었어요!
#
# 주관적인 입맛이니 참고만 하셔요 ◕ܫ◕
# --------------------------
# --------------------------
# 인테이크에서 새로나온 이번 신상!
# 펀딩 성공하고 그디어 인테이크 홈페이지에도 풀렸길래
# 이거 10개 버터치킨커리 10개 주문따리~~~
#
# 맨날 집에서 혼자 밥먹을때 자꾸 맛없는 라면
# (사실 맛있러서 먹음ㅋㅋㅋㅋㅋ)만 먹게되서
# 이거있으면 안 먹는 밥도 먹고 라면보단 건강에 좋을 것 같아서~ 시켜버려따 ㅎ
#
#
#
# 인테이크 한끼
# 스파이시 비프 커리
# Spicy beef curry
#
# 매콤하고 깔끔한 일본식 커리
# 120g에 135칼로리~!
# 그리고 유통기한은 일년인 듯
#
#
#
#
# 맑은채종유후레시가 뭐임?
# 아무튼 국내산 호주산섞여있다.
# 한국에서 호주를 느낄 수 있는 주옥같은 찬스! 우스타소스도 들어있땅
#
#
#
#
# 나트륨 660이면 짱 많은 줄 알았는데
# 라면 보니까 거의 2000이네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 휴 다행이다 라면 대신 먹어두 되겠어
# 지방? 이딴건 상관 안 쓴다
# 어차피 먹는거 조금찌나 좀 더 찌나 귀찮아 ~!
#
# (여러분 질량 보존의 법칙을 믿어봐요
# 나는 이거 믿고 항상 음식 앞에서 나대는중)
#
#
#
#
#
#
# 전자레인지에 봉투빼고 돌리던가
# 끓는물에 끓이던가 인데
# 전자레인지에 튀면 개같을거같아서
# (랩 씌우면 요새 비닐 난리인데 낭비하는거같구 ㅋㅋ)
# 냄비에 투하해버려따.
# 빨리 끓으라고 양은냄비에 끓였는데 너무 작네??;;
# ㅋㅋㅋㅌㅌㅌㅌㅌ
#
#
#
#
# 뭔 상관이야 걍 구겨넣어서 끓임도ㅣ지~*,*
#
#
#
# 사진 찍을라구 내 평생 밥 제일 이쁘게 담아보았다.
# 이정도면 성공이라구 해주라...
#
#
#
#
# 뜨거운 스파이시비프카레 눈물을 머금으며 잡고
# 칼질하여 오픈하였다.
# 아래로 쏠려서 양이 더 없어보리누 ㅠ
#
#
#
#
# 그릇에 부뤄보기!!!!!!!!
#
#
#
#
# 오호오호~
# 인테이크가 자랑하는게 다른데보다 건더기많다고
# 얘기하길래 건더기만 건저보기로 한
# 일을 만들어서하는 나 ㅋ
#
# 우선 다른데보단 많아보이는데 사진보단ㅊ적어보임.
#
#
#
#
# 건더기만 건져서 밥 위에 올려봤다.
#
#
#
#
# 오 소스에 담겨있을때보다 은근 많은데?
# 근데 소스랑 섞여서 구분이 안되길래
#
#
#
# 일렬로 세워봄
# 몇개만 밥위에 ~
#
# 고기랑 양송이랑 감자건더기!
# 솔직히 패키지디자인 사진은 사기고
# 근데 다른데보다 건더기 양은 크고 많은듯
#
#
#
# 먹어보게또요
# 냄냠남
# 양념은 일본카레맛이나면서 약간 하이라이스맛? 도 나는듯 함
# 약간 우스타소스 맛 살짝 나는 아비꼬느낌....?
# (카레전문가는 아니라 이해점!)
# 아무튼 갠춘갠춘! 특유의 향도 살짝 있는것같은데
# 세지않았고 괜찮았다.
#
# 고기도 부드럽고 !!! 감자도 실하고 양송이도 괜찮도
# 건더기들도 합격
#
#
#
# 매운맛은 흠냐흠냐
# 매운거 좋아하는 나한테 하나두 안 매 윰 ㅠ
# 그래서 고추씨 좀 넣어먹었다 ㅋ
# 그 오뚜기 카레 약간매운맛 정도인듯.
# 그냥먹으면 안맵고 김치같은 거랑 같이 먹으면
# 매콤함 올라오는 그런 맛
# 다들 알져?,,,?ㅋㅋㅋㅋㅋㅋㅋㅋ
#
#
# 양은 적당했다.
# 많이먹는 사람들한텐 적을 수 도 있나?
# 나는 많이 먹지 않은 편 임!
# 간도 딱 괜찮은데 괜찮은데에서 짠 곳으로 한 발 들이민 정도니까 그냥 밥을 좀 더 드세용
# ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅌ
# 어니면 집에있는 야채나 과일 먹기하셈
#
#
#
# 양념이 묻얶으므로 재활용은 불가
# 스레기통으로 투하했다.
# 츅하해 너가 이 쓰레기봉투의 첫번째 입주 손님이야~
#
#
#
#
# 마지막은 일관성있게 강황물로 마무리했다 ^^ㅋㅋㅋㅋㅋ
# ㅋㅋㅌㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅌㅌㅋㅋㅌ
# 사람이 앞 뒤가 똑같아야죠 !
# 아무튼 라면대신 먹기 참 좋을 것 닽아서 합걱!!!
# 다음엔 무인양품 커리랑 맛이 똑같다는
# 버터치킨커리로 돌아오겠습니다
# 이 글이 구매에 도움이 되길 바라며 모두들 안녕~
#
# 한끼 스파이시비프커리 *10개입 - 인테이크
# 식사를 연구하다, 인테이크
# www.shopintake.com
# --------------------------
# --------------------------
# --------------------------
# INTAKE MEALS LIGHT
# 식사 거르지 마세요:) 식사대용 175kal 인테이크 밀스라이트
#
#
# 안녕하세요! 징입니다.
# 다들 맛점하시나요♡
# 저는 요즘 넘 바쁜 날들을 보내고 있어요ㅠㅠ
# 이럴 때 속 편하게 #마시는한끼 #인테이크 #밀스라이트 가 딱 이거든요. 특히 아침에는!!!
# 예전엔 그냥 굶었는데 이제 175kal로 맛있고 든든하게 챙겨 먹고 있습니다.
#
#
#
#
#
#
# 제가 먹은 건 스타터 키트에요.
# 많은 분들에게 시도해보라 권하고 싶네요..
# 보틀에 나오는 한끼대용 음료는 예전에 편의점에서 사 먹어봤는데
# 맛이 없어서 먹다가 버렸던 기억이 있어요.
# 근데 밀스라이트는 단맛도 살짝 느껴져서 선식 잘 못 드시는 분들도
# 출근길에 마시는 카페 음료처럼 쭉쭉 드실 수 있답니다!
#
#
#
#
#
#
#
#
# 카페라떼/말차라떼/벨벳카카오 세 가지 맛으로 구성되어 있어요.
# 일단 스타터 키트로 모두 맛본 뒤에 맘에 드는 맛 초이스하시면 좋을 듯!
#
#
#
#
#
#
# 마시기 전에 궁둥이를 톡톡 쳐서 가루가 보틀에서 떨어지게 두셔용
#
#
#
#
#
#
#
#
#
# 영양정보도 보시구용
# 밀스라이트는 지방이 0g인데 콜라겐, 히알루론산, 알로에, 등
# 몸에 좋은 원료로 이루어져 있어요.
# 일단 맛있으니까!!! 다이어트할 때 너무 좋을 것 같아요.
# 지방 0.. 그냥 말만 들어도 좋다 ^-^
#
#
#
#
#
#
# 연하게/진하게 선이 있으니 기호에 따라 맞춰 드십셔'-'
#
#
#
#
#
# 젤 처음 먹어본 건 말차라떼!
# 뚜껑을 딱 열면 진짜 가루 말차/녹차의 향이 혹 들어온답니다.
# 고소한것이.,b
# 일부러 우유를 넣어서 먹었어요!
# 진정한 말차라떼를 위해 ㅋㅋㅋ
#
#
#
#
#
#
# 우유나 물 붓기 전에 궁둥이 툭툭 쳐주는 거 잊지마시구!
# 말차라떼는 진짜 이 집 라떼 잘하네~하는 정도의 맛임..
# 완전 맘에 들어요.
# 나중에 다이어트하다 힘들 때도 애용할 듯 ♡
#
#
#
#
#
# 회사에서 선식 먹을 때 텀블러 씻는 거며 챙겨 다니는 게 좀 귀찮았는데 보틀형 먹어보니 넘 편해요!
#
#
#
#
#
# 오늘은  출근길에 물 넣고 카페라테를 진하게 마셔봤어요.
# 원래 아침마다 커피 마시는데
# 몸에 좋은 밀스라이트로 대체-!
# 벨벳 카카오도 진짜 카카오 초코우유 맛이었는데,
# 세 가지 맛 모두 진하고 익숙한 맛이어서
# 카페음료 중에서 비슷한 맛을 자꾸 찾게되요.
# 먹어보시면 공감하실 듯 ㅋㅋㅋㅋㅋ
# 건강합시다!!
#
# 밀스 라이트 카페라떼 * 7개입 - 인테이크
# 식사를 연구하다, 인테이크
# bit.ly
#
#
#
#
# 이 글은 위블을 통해 업체에서
# 제품 또는 서비스를 제공받아 작성된 글 입니다.
# --------------------------
# 이번 포스팅은
# 인테이크의 맛있는 곤약젤리 후기다!ㅎㅎ
#
#
# 인테이크 홈페이지에서 만나볼 수 있는 제품이고
# 나는 망고, 청포도, 복숭아, 사과 맛을
# 각각 두 개씩 받았다
#
#
# https://goo.gl/3kLHCe
# 인테이크
# 식사를 연구하다, 인테이크
# goo.gl
#
#
# 패키지가 예뻐서
# 맛도 기대됨
# 영양성분은 네 가지 맛 모두 동일하다
# 4kcal에 당류, 지방, 콜레스테롤 0%!!!!
#
#
#
# 홈페이지에서 4kal이 얼마나 낮은 수치인지
# 평소 다이어터들이 많이 먹는 음식과 비교를 해놓았는데
# 이거 보고 진짜 충격받았닼ㅋㅋㅋㅋ
#
# 간식으로 바나나 두 개씩 먹었는데
# 곤약 젤리 52개 먹은 거랑 동일하군 ^___^
#
#
# 식감은 이렇게 탱탱한 젤리 같다.
#
# 젤리뽀처럼 과일 맛이 나는데
# 내 기준 망고 맛이 제일 맛있었고
# 동생은 복숭아가 제일 맛있다고 했다!
#
# 사과랑 청포도도 맛있긴 함 ㅎ
#
#
# 냉장보관해서 먹으면 더 쫀득하게 먹을 수 있다고 하고,
# 내가 시원하게 먹는 것을 좋아하기도 해서
# 냉장고에 넣었다가 먹었당
#
#
#
# 양이 그리 많은 것 같지 않지만
# 밥 먹고 입이 심심할 때,
# 밤에 야식 땡길 때 먹기에는 딱 좋은 양이다!
#
# 무엇보다도 설거지거리가 안 생겨서 좋당
#
# 한 번은 밤에 공부하다가
# 급 허기진 상태에서 먹었는데
# 포만감이 생겨서 놀랐다!
#
# 라면 끓였으면
# 집에 냄새 다 배고
# 끓이는 거, 티비 보면서 먹는 거까지 해서
# 한 시간 후딱 잡아먹을 텐데
#
# 곤약 젤리 먹으니까 1분 만에 간식타임 끝난다 ㅎㅎ
# (단점인가,,,,,)
#
#
# 체험단으로 받은 상품이긴 하지만,
# 맛도 아주 좋았고
# 밤에 야식 먹는 거 방지하기에도 좋아서
# 추가로 구매할 계획이다!
# --------------------------
# 인테이크귀리우유 모닝귀리로 식단조절 해요
#
# 식단조절을 위해 매일매일 닭가슴살만 먹으니까
# 도저히 지쳐서 식단을 바꾸기로 마음먹은 댜니!
# 아침을 조금 더 간단하면서 포만감 높은 것으로
# 바꾸어서 먹고 있는 요즘이에요 :)
# 식단조절을 위해 선택한 제품은
# 인테이크귀리우유인
# '모닝귀리'라는 제품이에요!
# 요즘 핫한 귀리 제품들은 가격대가
# 조금 있는 편인데 모닝귀리는
# 진짜 귀리가 99.8% 함유되어 있음에도
# 타제품 대비 가성비가 좋다는게 대박!!
# 통귀리와 귀리분말로 되어있는 모닝귀리는
# 식이섬유와 단백질이 가득가득 들어있어서
# 영양가득하구 베타글루칸으로 포만감까지
# 느낄 수 있는 식이조절에 딱 맞는 제품이더라구용
# 거기다가 우유를 태워서 한통을 먹어도
# 칼로리도 낮고 무엇보다 포화지방이
# 일반식보다 높지 않아서 아침에 부담없이
# 먹을 수 있는 식단조절 귀리우유랍니다
# 식단조절하는 분들이 많이 먹는다는
# 귀리분말과 통귀리가 보여요@_@
#
# 인테이크귀리우유는 맛도 맛이지만
# 섭취방법이 간단해서 정말 좋아요~
# 용기 속에 우유를 200ml 부어주고
# 쉐킷쉐킷 흔들어주면 끝!!!
# 인테이크귀리우유 뚜껑을 열고
# 제가 한 번 먹어보도록 하겠습니닷!!
# 분말이 새지 않게 한 번 더 포장이
# 되어있어 잘 떼어내고 먹어용 ㅎㅎㅎ
# 흰우유나 물과 함께 섞어먹으면 되는데
# 저는 고소한 맛이 좋기 때문에
# 200ml 우유 한팩씩 모닝귀리 한통에 넣고
# 아침대용으로 마셔요 XD
# 차가운 우유를 넣으면 바닥에 있던
# 분말들이 붙어져 있어서
# 잘 흔들어서 섞어주어야 한답니다.
# 잘 섞어주면 모닝귀리 속 통귀리가 동동 떠있어요
# 마셔보면 미숫가루와 같은 고소한 맛이 나구
# 귀리가 입으로 쏙쏙 들어와서 씹을 수 있어요!
#
# 약간 걸죽한 느낌이 있고
# 씹을 수 있는 귀리가 있어서 더 맛있구
# 한 병 다 마시면 진짜 배가 부르답니다
# 간편하지만 포만감이 있구 맛과 영양이 있는
# '모닝귀리'는 현재 할인까지 하고 있어서
# 더욱 더 가성비 좋게 먹어볼 수 있어요!!
# 식이조절 원한다면 이 기회 놓치면 안되겠쥬?ㅋㅋ
# 아침대용으로 인테이크귀리우유를
# 한병씩 마셔주는데 점심시간까지
# 포만감이 유지되는게 굿굿 !!
# 제일 좋았던건 간편하게 먹을 수 있는데
# 영양도 듬뿍, 부담없이 꿀꺽 할 수 있다는것!
#
# 아침마다 바빠서 밥을 못챙겨먹거나
# 아침밥이 부담스럽다면 모닝귀리로
# 한 끼 든든하게 해결해보세요*_*
# 모닝 귀리 *1개입 - 인테이크
# 식사를 연구하다, 인테이크
# bit.ly
# --------------------------
# 베스파 s125 인테이크 파이프 정비기 입니다~
# 안녕하세요 모토클래식 주인장입니다~ 오늘은 s125 의 인테이크 파이프교체기를 올려볼까 합니다~ 생각보다 간단한 구조라서 준비물은 일자드라이버와 톡스30 이정도만 있으면 충분할것 같습니다~
#
#
#
#
#
# 간단하게 풀려버리기 때문에 안심하셔도 됩니다 ~ 베스파가 2008년식 인데도 관리를 잘하셔서 그런지 번떡 번떡 합니다~ 차주님의 정성 아니겠습니까~??!
#
#
#
#
# 인테이크 파이프를 교체하기전에 한컷~~!!!
# 이쁘게 들어가서 이쁨 많이 받거라 그래야 잘달리면서 즐기쥬~ 클래식한 디자인이라면 물론 s125가 제일 귀여우면서도
# 스포티한 스쿠터가 생각나시죠~?
#
#
#
#
# 교체하고 나서 안전하게 귀가하셨답니다~ 즐거운 베스파 라이프 하시고 또 들려주세요~ 감사합니다~~
#
#
#
# 수입 국산 오토바이전문
# 모토클래식
# 02)3142-2147
# 긴급/견인/출장//정비//보험//대차//렌트
#
# 50m
# © NAVER Corp.
# 모토클래식
# 서울특별시 마포구 연희로 47
#
# 상세보기
# --------------------------
# 식사대용 간편식
# 인테이크 밀스3.1
#
# 회사 다니는 동안 아침식사 대용으로
# 열심히 먹어온 인테이크 죽시리즈
# 인테이크 모닝죽 시리즈
#
#
# 맛도 좋고 편리해서 모닝죽을 애용했었는데
# 이번에는 인테이크에서
# 식사대용 간편식 밀스3.1을 출시했다.
#
# 밀스 3.1
#
#
# 포만감도 좋고 맛도 내스타일이라
# 벌크로 쟁여두고 먹을 예정 :)
#
#
#
# 맛은 총 3가지
# 소이 / 그레인 / 코코넛
#
# 3가지 모두 공통적으로
# 고소, 달달, 짭짤한 맛이 느껴지는데
# 그레인, 코코넛은 곡물이 씹혀서 식감까지 굿굿
#
#
# (참고로 소이맛은 땅콩 분태를 통으로 넣지 않고
# 갈아서 넣었기 때문에 씹히는 식감이 없다)
#
#
#
# 밀스3.1
#
# 인테이크 밀스 시리즈는 4년에 걸쳐
# 계속 진화해왔다.
#
# 그동안의 밀스들도 훌륭했지만
# 이번 3.1은 역대급인 듯
#
# 밀스3.1은 밀스3.0에 일부 함유되어 있던
# 동물성 원료를 전부 제외하고
# 100% 비건으로만 만들었다고 :)
#
#
# 먹는 방법도 매우 간단!
#
# 생수만 있으면 끝
#
#
# 나는 미숫가루+생수 조합은 비린 맛이 나고
# 목넘김이 힘들어 미숫가루+우유 조합을
# 선호한다.
#
#
# 미숫가루+우유파라 밀스+생수 조합을 걱정했는데
# 미숫가루+우유 조합보다 밀스3.1 + 생수 조합
# 목넘김이 더 우수하다! 더 부드럽고
#
#
# 물 붓는 표시선까지 넣어주면 되는데
# 연하게 선까지 넣어도 진하기에 가득 채워서 먹는 중
#
# 사이트에서 찾아보니 너무 진하면 물 340ml까지
# 넣으라고 안내가 되어 있다.
#
# 나야 뭐 더 많이 먹으면 좋지*.*
#
# 생수를 넣은 후 뒤집어서 톡톡 치면
# 바닥에 붙어 있던 가루들이 우수수 떨어짐
#
# 이 때, 톡톡 치기 전 먼저 흔들면
# 가루가 덩어리지기 때문에 안된다.
#
# 생수넣기-톡톡치기-흔들기 순
#
# 그리고 파우더 형태라 물을 넣고 흔들면
# 다시 액체 눈금선 양이 줄어든걸 볼 수 있다
#
# 나는 더 많이 먹고싶으니까
# 이 때 물을 더 넣어서 꽉 채워 먹음 ㅋㅋㅋ
#
#
# 밀스 3.1은 300ml용량인데
# 의외로 양이 많은 편
#
# 왼쪽에 있는 르쿠르제 머그가
# 시리얼 컵 사이즈인데도
# 밀스 반만 따라도 꽉 참 ㅋㅋㅋㅋ
#
#
# 곱디 고운 밀스-
#
# 꽃 배우러 다닐 때 체력 소모가 엄청나서
# 하나씩 들고 다니는 중!
# 밀스 3.1 소이 보틀형 *7개 - 인테이크
# 식사를 연구하다, 인테이크
# goo.gl
# --------------------------
# --------------------------
# 어제 헬스장에가서
# 오랜만에 인바디를 쟀다
#
# 헬스도 필라테스도 열심히 하고 있어
# 눈바디는 변화가 많이 보이는데
# 숫자는 어떻게 달라졌을까 궁금해서
# 인바디를 쟀는데
#
# 이게왠걸..
# 체중은 줄었는데 근육양은 거의 그대로네
# 정말
# 운동의욕을 잃을뻔 했는데
# 트레이너님이 단백질 잘 챙겨먹으라구..
#
#
# 김종국의 명언
# 운동은 운동후 챙겨먹는것 까지가 운동이라며
#
# 닭가슴살 열심히 챙겨먹고 있었는데
# 단백질 함량이 얼마 안된다 더라?
# 그래서
#
# 닭가슴살 말고
# 인테이크 밀스3.1로 바꿨다!
#
# 씹지않고 마시는 간편식사
# 인테이크 밀스3.1
# 400kcal의 마시는 식사다~
# 물만 넣으면 완성!
# 인테이크 밀스3.1
# 밀스 소이,밀스 그레인,밀스 코코넛
# 물 혹은 두유를 넣어 마시면 된다
# 두유를 넣어도 600칼로리가 되지 않는다.
# 단백질 뿐만 아니라
# 마그네슘,철분,칼륨,불포화지방산까지 정말 다양한 영양분이 가득하다~
# 뚜껑을 열고
# 물을 넣고
#
# 흔들어 주세요~!
# 물양으로 진하게 연하게 조절
# 물은 300mm가 들어 간다~
# 밀스그레인은 현미톡톡
# 씹는맛도 느낄 수가 있다!
#
# 물을 넣으면 밍밍할까?했는데
# 엄청 구수하고 진하다!
# 곡물의 신선함이 느껴진다고 할까
# 비린내도 없고
# 아침에 출근하면서 먹음 좋을것 같다!
#
# 밀스소이는 씹는맛 없이
# 밀크 코코넛은 씹히는 코코넛으로~
#
# 나는 개인적으로 코코넛이 가장 맛있는 듯!
#
# 운동하면서 마셔도 좋을것 같아~
#
# 지금 배고파서 한잔 마시는 중인데
# 배불러서 반이상 못마시겠다?!ㅋㅋ
#
# 영양을 충분히 충족해야 하는
# 수유중인 새언니도 하나줘야지~!!
# --------------------------
# --------------------------
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-2-030c92615948> in <module>()
#      10             driver.switch_to_window(driver.window_handles[1])
#      11             time.sleep(3)
# ---> 12             driver.switch_to.frame(driver.find_element_by_css_selector('#mainFrame'))
#      13             maintext = driver.find_element_by_css_selector('div.se_doc_viewer > div.se_component_wrap.sect_dsc.__se_component_area')
#      14             sentences = maintext.text.strip()
#
# /anaconda3/lib/python3.5/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_css_selector(self, css_selector)
#     589             element = driver.find_element_by_css_selector('#foo')
#     590         """
# --> 591         return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#     592
#     593     def find_elements_by_css_selector(self, css_selector):
#
# /anaconda3/lib/python3.5/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     955         return self.execute(Command.FIND_ELEMENT, {
#     956             'using': by,
# --> 957             'value': value})['value']
#     958
#     959     def find_elements(self, by=By.ID, value=None):
#
# /anaconda3/lib/python3.5/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     312         response = self.command_executor.execute(driver_command, params)
#     313         if response:
# --> 314             self.error_handler.check_response(response)
#     315             response['value'] = self._unwrap_value(
#     316                 response.get('value', None))
#
# /anaconda3/lib/python3.5/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchWindowException: Message: no such window: window was already closed
#   (Session info: chrome=67.0.3396.99)
#   (Driver info: chromedriver=2.38.552518 (183d19265345f54ce39cbb94cf81ba5f15905011),platform=Mac OS X 10.13.5 x86_64)
