# %% [markdown]
# ### 단어\_태그\_T/F(받침여부)_원단어의발음
# ### https://docs.google.com/spreadsheets/d/1-9blXKjtjeKZqsf4NzHeYJCrr49-nXeRF6D80udfcwY/edit#gid=4
# # 명사 NNG, 동사 VV, 형용사 VA

# %%
from konlpy.tag import Mecab
import pickle
import re
import sys
from gensim.models import TfidfModel
from gensim.models import Word2Vec
from gensim.corpora import Dictionary
from pprint import pprint
from collections import Counter
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
import mglearn
from pprint import pprint
import numpy as np
import gc
import copy
import pandas as pd


class SB_Word2Vec():    
    
    def __init__(self, morph_list):
        self.dct = Dictionary(morph_list)
        self.corpus = [self.dct.doc2bow(line) for line in morph_list]
        self.build_Word2Vec(morph_list)
    
    def make_Word2Vec(self, morph_list, size=50, window=2, min_count=10, iteration=100):
        self.em = Word2Vec(morph_list, size=size, window=window, min_count=min_count, iter=iteration)
        self.em_vocab = list(self.em.wv.vocab.keys())
        self.em_vocab_dic = {word:idx for idx, word in enumerate(self.em_vocab)}

    def make_Word2Sen_matrix(self): 
        vocab_size = len(self.em_vocab)
        self.sen_matrix = np.zeros((len(self.corpus), vocab_size))
        for idx, row in enumerate(self.sen_matrix):
            for idx2, frequency in self.corpus[idx]:
                    if self.dct[idx2] in self.em_vocab:
                        self.sen_matrix[idx][self.em_vocab_dic[self.dct[idx2]]] = frequency                
        self.sim_matrix = np.zeros((vocab_size, vocab_size))
        for idx, w1 in enumerate(self.em_vocab):
            for idx2, w2 in enumerate(self.em_vocab):
                self.sim_matrix[idx][idx2] =  self.em.wv.similarity(w1, w2)

        self.word2sen_matrix = np.dot(self.sim_matrix, np.transpose(self.sen_matrix))

        return self.word2sen_matrix

    def get_sim_sen(self, keyword, main_text, number=1):
        self.sim_sen_index = np.argsort(self.word2sen_matrix[self.em_vocab_dic[keyword]])
        self.most_sim_sen_index = np.argmax(self.word2sen_matrix[self.em_vocab_dic[keyword]])
        index_list = self.sim_sen_index.reshape((-1,)).tolist()
        index_list.reverse()
        
        for idx, i in enumerate(index_list[:number]):
            print(str(idx + 1))
            print(main_text[i])
        return index_list
    
    def build_Word2Vec(self, morph_list):
        self.make_Word2Vec(morph_list)
        self.make_Word2Sen_matrix()
        
        
class SB_LDA():

    def make_lda(self, morph_joined, ntopic=10, learning_method='batch', max_iter=25, random_state=0, n_words=20):        
        self.vect = CountVectorizer(max_features=10000, max_df=.15)
        self.X = self.vect.fit_transform(morph_joined)
        self.lda = LatentDirichletAllocation(n_components=ntopic, learning_method=learning_method, max_iter=max_iter, random_state=random_state)
        self.document_topics = self.lda.fit_transform(self.X)
        self.sorting = np.argsort(self.lda.components_, axis=1)[:, ::-1]
        self.feature_names = np.array(self.vect.get_feature_names())
        mglearn.tools.print_topics(topics=range(ntopic), feature_names=self.feature_names, sorting=self.sorting, topics_per_chunk=5, n_words=n_words)

    def related_doc(self, main_text_list, topic_index, number=10):
        category = np.argsort(self.document_topics[:, topic_index])[::-1]
        related_docs = []
        for i in category[:number]:
            print(i)
            print(main_text_list[i] + ".\n")
            related_docs.append((i, main_text_list[i]))
        return related_docs

class SB_Tfidf():    
    
    def __init__(self, list_morph_merged):
        self.list_morph_merged = list_morph_merged
        self.dct = Dictionary(self.list_morph_merged)
        self.corpus = [self.dct.doc2bow(line) for line in self.list_morph_merged]

    def get_tfidf(self):       
        self.model = TfidfModel(self.corpus)
        self.tfidf = []
        for i in self.corpus:
             self.tfidf.append(sorted(self.model[i], key = lambda x: x[1], reverse=True))
        self.tfidf_hangul = []
        for idx1, i in enumerate(self.tfidf):
            self.tfidf_hangul.append([(self.dct[j[0]], j[1]) for j in i])        
        
        return self.tfidf_hangul
    
def frequency(merged):
    word_count = Counter(merged)
    word_count2 = []
    for i in word_count:
        word_count2.append((i, word_count[i]))
    word_count2 = sorted(word_count2, key=lambda x: x[1], reverse = True)
    return word_count2




class Social_analysis():
    
    non_bmp_map = dict.fromkeys(range(0x10000, sys.maxunicode + 1), 0xfffd)
    syn_dic = {}
    del_list = []
    ngram_dic = {}
    
    def __init__(self):
        self.mecab = Mecab()
        try:
            self.load_dictionary()
        except:
            print('dictionary error')
    def load_dictionary(self, path='Data/custom_dic.csv'):
        dic_df = pd.read_csv(path, encoding='cp949')
        for i in range(len(dic_df)):
            self.ngram_dic[dic_df.loc[i,'key']] =  dic_df.loc[i, 'value']
    
    def insta_DB_to_table(self, DBname='intake', keyword='intake'):
        import pymssql
        import pandas.io.sql as pdsql
        import pandas as pd
        self.query = \
        """
        SELECT user_id, created_at, main_text, hashtags, comments, likes, current_url FROM instaPosting WHERE keyword = '{}'
        """.format(keyword)
        conn = pymssql.connect("intakedb.c63elkxbiwfc.us-east-2.rds.amazonaws.com:1433", "gh", "ghintake", DBname)
        self.df = pdsql.read_sql_query(self.query, con=conn)
        # df['main_text'] = df.main_text.apply(lambda x: x.replace('#',' ').translate(self.non_bmp_map))
        # df['created_at'] = df.created_at.apply(lambda x: x.strftime("%Y-%m-%d %H:%M:%S"))
        conn.close()
        self.raw_data = self.df.as_matrix()
    
    def shop_DB_to_table(self, DBname='intake', keyword='intake'):
        import pymssql
        import pandas.io.sql as pdsql
        import pandas as pd
        self.query = \
        """
        SELECT mall, corpName, productCode, date, id, productScore, recommScore, main_text FROM productReview WHERE corpName = '{}'
        """.format(keyword)
        conn = pymssql.connect("intakedb.c63elkxbiwfc.us-east-2.rds.amazonaws.com:1433", "gh", "ghintake", DBname)
        self.df = pdsql.read_sql_query(self.query, con=conn)
        # df['main_text'] = df.main_text.apply(lambda x: x.replace('#',' ').translate(self.non_bmp_map))
        # df['created_at'] = df.created_at.apply(lambda x: x.strftime("%Y-%m-%d %H:%M:%S"))
        conn.close()
        self.raw_data = self.df.as_matrix()       
        
    def blog_DB_to_table(self, DBname='intake', keyword='intake'):
        import pymssql
        import pandas.io.sql as pdsql
        import pandas as pd
        self.query = \
        """
        SELECT keyword, created_at, post_name, main_text, current_url FROM NaverBlogReview WHERE keyword = '{}'
        """.format(keyword)
        conn = pymssql.connect("intakedb.c63elkxbiwfc.us-east-2.rds.amazonaws.com:1433", "gh", "ghintake", DBname)
        self.df = pdsql.read_sql_query(self.query, con=conn)
        # df['main_text'] = df.main_text.apply(lambda x: x.replace('#',' ').translate(self.non_bmp_map))
        # df['created_at'] = df.created_at.apply(lambda x: x.strftime("%Y-%m-%d %H:%M:%S"))
        conn.close()
        self.raw_data = self.df.as_matrix()       
    
    def pickle_to_table(self, filename):
        with open(filename, 'rb') as f:
            data = pickle.load(f)
        data = data[1:]
        for idx, i in enumerate(data):
            data[idx][2] = i[2].replace('#', ' ').translate(self.non_bmp_map)
            data[idx][3] = '/'.join(i[3])
            data[idx][4] = '/'.join(i[4])
        self.raw_data = np.array(data)
  
    def hashtags_split(self, hashtags):        
        hashtags_split = []
        for i in hashtags:
            hashtags_split.append(i.split('/'))
        
        hashtags_list = []
        
        for i in hashtags_split:
            temp = []
            for j in i:
                if self.isHangul(j):
                    t_hashtags = j.translate(self.non_bmp_map)
                    temp.append(t_hashtags)
            hashtags_list.append(temp)
        self.hashtags_list = hashtags_list
        
        return hashtags_list

    
    def add_dictionary(self, *tokenized_list):
        origin_df = 1
        try:
            origin_df = pd.read_csv("C:\\mecab\\user-dic\\intake_dic.csv", encoding='utf-8', header=None)
        except:
            print('No default intake_dic')
        keyword_list = []
        for i in tokenized_list:
            if type(i) == list:
                for j in i:
                    j = j.split('_')
                    temp = [j[0],'' ,'' ,'' ,j[1],'*',j[2], j[3],'*','*','*','*','*']
                    keyword_list.append(temp)
            else:
                i = i.split('_')
                temp = [i[0],'','','',i[1],'*',i[2], i[3], '*','*','*','*','*']
                keyword_list.append(temp)


        keyword_df = pd.DataFrame(keyword_list)
        print(type(origin_df))
        if type(origin_df) != int:
            keyword_df = pd.concat((origin_df, keyword_df), ignore_index=True)
        else: 
            print('a')
            pass
        print(keyword_df.shape)

        keyword_df.to_csv("C:\\mecab\\user-dic\\intake_dic.csv", encoding='utf-8',index=None, header=False)    

        
    def ngram(self, parsed_list):
        ngram_list = []        
        adjustment = 0
        # 단어_tag의 리스트

        for idx in range(len(parsed_list)):
            idx2 = idx + adjustment

            if (idx2+self.ngram_size) > (len(parsed_list)):
                ngram_list.extend(parsed_list[idx2:])
                break
            n_filter = tuple(parsed_list[idx2: idx2 + self.ngram_size])
            key = ''.join([k.split('_')[0] for k in n_filter])
            if key in self.ngram_dic:
                ngram_list.append(self.ngram_dic[key])
                adjustment += (self.ngram_size - 1)
            else:
                ngram_list.append(n_filter[0])

        if self.ngram_size <= 2:
            return ngram_list
        else:
            self.ngram_size -= 1
            return self.ngram(ngram_list)       


    def morph_pos(self, text_list):
        
        morph_list = []
        
        for j in text_list:
            parsed = self.mecab.pos(j)
            temp = []
            for i in parsed:
                if self.isHangul(i[0]):
                    temp.append(i[0]+'_'+i[1])
                else: pass#print('{} 한글이 아님.'.format(i[0]))

            self.ngram_size = 5
            morph_list.append(self.ngram(temp))
        
        self.df['morph_list'] = morph_list
        return morph_list

    def filter_words(self, parsed_list):
        # 1차원 리스트를 받음.
        changed_list = list(map(lambda x: self.syn_dic.get(x, x) , parsed_list))
        deleted_list = list(filter(lambda x: x not in self.del_list, changed_list))
        return deleted_list
    
    def pos_extractor(self, parsed, exception_list=['맛', '밥', '물', '몸', '죽', '먹', '없', '있', '싫', '헬', '달']):

        noun_list = []
        adj_list = []
        verb_list = []
        nav_list = []
        for j in parsed:
            
            nav_temp = []
            n_temp = []
            adj_temp = []
            verb_temp = []
            
            for i in j:            
                i = i.split('_')
                if self.isHangul(i[0]):
                    if (len(i[0]) > 1) or (i[0] in exception_list):
                        if 'NN' in i[1]:
                            n_temp.append(i[0])
                            nav_temp.append(i[0])
                        elif 'VV'in i[1]:
                            adj_temp.append(i[0])
                            nav_temp.append(i[0])
                        elif 'VA' in i[1]:
                            verb_temp.append(i[0])
                            nav_temp.append(i[0])
                    else: pass
                        #print('{} 제외'.format(i[0]))
                else: pass#print('{} 한글이 아님.'.format(i[0]))

            nav_list.append(self.filter_words(nav_temp))
            noun_list.append(self.filter_words(n_temp))
            adj_list.append(self.filter_words(adj_temp))
            verb_list.append(self.filter_words(verb_temp))
            
            
        columns=['nav_list', 'noun_list', 'adj_list', 'verb_list']
        for i in  zip(columns, [nav_list, noun_list, adj_list, verb_list]):
            self.df[i[0]] = i[1]
            
        return [nav_list, noun_list, adj_list, verb_list] # tuple(map(lambda x: [j.split('_')[0] for j in x], [nav_list, noun_list, adj_list, verb_list]))

    
    def merge_list(self, tokenized_list):
        return [j for i in tokenized_list for j in i]

    
    def join_list(self, tokenized_list):
        joined_list = []
        for idx, i in enumerate(tokenized_list):
            joined_list.append(" ".join(i))
        return joined_list
 
    def split_list(self, untokenized_list):
        hashtag_splited = []
        for idx, i in enumerate(untokenized):
            hashtag_splited.append(i.split('/'))
            return hastag_splited
        
    '''    
    def join_underbar(self, morph_list):

        all_list = []
        post_list=[]
        for i in morph_list:
            for j in i:
                post_list.append(j[0]+'_'+j[1])
            all_list.append([(' , ').join(post_list)])
            post_list=[] 
        all_list=np.array(all_list)
        
        return all_list'''

    def word_substitute(self, dataset, sublist):
        dataset = copy.deepcopy(dataset)
        sub_book = dict()
        for i in sublist:
            for j in i['sub_words']:
                sub_book[j] = i['main']
        gc.collect()
        for n, i in enumerate(dataset):
            dataset[n] = [sub_book.get(item,item) for item in i]

        del sub_book
        gc.collect()

        return dataset
    
    def word_delete(self, dataset, del_list):
        dataset = copy.deepcopy(dataset)

        for n, line in enumerate(dataset):
             dataset[n] = [i for i in line if i not in del_list]

        return dataset

    
    def isHangul(self, text):
        encText = text
        hanCount = len(re.findall(u'[\u3130-\u318F\uAC00-\uD7A3]+', encText))
        return hanCount > 0
    
    def convert_list(self, *tokenized_list):
        input_length = len(tokenized_list)
        lists = [[] for i in range(input_length)]

        for idx, li in enumerate(tokenized_list):
            for j in li:
                lists[idx].append(['/'.join(j)])

        converted_array = np.array(lists[0])
        for idx in range(input_length):
            try:
                converted_array = np.concatenate((converted_array, lists[idx + 1]), axis=1)
            except Exception as e:
                print(e,'끝')

        return converted_array

    def make_df(self, start_array, converted_array, end_array, columns=['user_id', 'created_at', 'main_text', 'morph_list', 'nav_list', 'noun_list', 'adj_list', 'verb_list', 'hashtags', 'comments', 'likes', 'current_url']):         
        df = pd.DataFrame(np.hstack((start_array, converted_array, end_array)), index=None, columns=columns)
        return df
    
    # 키워드 리스트 중 하나라도 있는 경우
    def word_check_or(self, text, keywords):
        if any(word in text for word in keywords):
            return 1
        else: return 0

    # 키워드 리스트에 있는 단어가 모두 있는 경우
    def word_check_and(self, text, keywords):
        if all(word in text for word in keywords):
            return 1
        else:
            return 0


    def word_check(self, method, keywords, df, column_name = 'main_text',filter_TF=True):
        
        filter_TF = 1 if filter_TF == True else 0
        if method == 'and':
            df['flags'] = df[column_name].apply(lambda x: self.word_check_and(x, keywords))
            return df.loc[df['flags'] == filter_TF]

        elif method == 'or':
            df['flags'] = df[column_name].apply(lambda x: self.word_check_or(x, keywords))
            return df.loc[df['flags'] == filter_TF]
        
        else:
            print('Select method, and/or')

# %%
itkinsta = Social_analysis()
itkshop = Social_analysis()
itkblog = Social_analysis()
lnsinsta = Social_analysis()
lnsshop = Social_analysis()
lnsblog = Social_analysis()
pckinsta = Social_analysis()
pckshop = Social_analysis()
pckblog = Social_analysis()
kgcinsta = Social_analysis()
kgcshop = Social_analysis()
kgcblog = Social_analysis()

# %%
itkinsta.insta_DB_to_table(DBname = 'intake', keyword = 'intake')
itkshop.shop_DB_to_table('intake', 'intake')
itkblog.blog_DB_to_table('intake', 'intake')
lnsinsta.insta_DB_to_table(DBname = 'intake', keyword = 'labnosh')
lnsshop.shop_DB_to_table('intake', 'labnosh')
lnsblog.blog_DB_to_table('intake', 'labnosh')
pckinsta.insta_DB_to_table(DBname = 'intake', keyword = 'pck')
pckshop.shop_DB_to_table('intake', 'pck')
pckblog.blog_DB_to_table('intake', 'pck')
kgcshop.shop_DB_to_table('intake', 'kgc')
kgcblog.blog_DB_to_table('intake', 'kgc')

# %%
kgcshop.shop_DB_to_table('intake', 'kgc')

# %%
print(kgcshop.raw_data[0])
# Out:
# ['11ST' 'kgc' 30000 Timestamp('2017-09-26 00:00:00') 'gao***' 4 0
#  '교수님께드릴 선물 매번 요기서 주문해요~ 현대백화점에서가는거로 가구요 ㅜㅜ이번부터 우체국택배라 별하나빼요 기존처럼현대백화점서같이보내주지ㅜㅜ']

# %%
itkinsta.df = pd.DataFrame(itkinsta.raw_data, columns=['user_id', 'created_at', 'main_text', 'hashtags', 'comments', 'likes', 'current_url'])
itkshop.df = pd.DataFrame(itkshop.raw_data, columns=['mall', 'corpName', 'productCode', 'date', 'id', 'productScore', 'recommScore', 'main_text'])
itkblog.df = pd.DataFrame(itkblog.raw_data, columns=['keyword', 'created_at', 'post_name', 'main_text', 'current_url'])
itkinsta.df = pd.DataFrame(itkinsta.raw_data, columns=['user_id', 'created_at', 'main_text', 'hashtags', 'comments', 'likes', 'current_url'])
itkshop.df = pd.DataFrame(itkshop.raw_data, columns=['mall', 'corpName', 'productCode', 'date', 'id', 'productScore', 'recommScore', 'main_text'])
itkblog.df = pd.DataFrame(itkblog.raw_data, columns=['keyword', 'created_at', 'post_name', 'main_text', 'current_url'])
itkinsta.df = pd.DataFrame(itkinsta.raw_data, columns=['user_id', 'created_at', 'main_text', 'hashtags', 'comments', 'likes', 'current_url'])
itkshop.df = pd.DataFrame(itkshop.raw_data, columns=['mall', 'corpName', 'productCode', 'date', 'id', 'productScore', 'recommScore', 'main_text'])
itkblog.df = pd.DataFrame(itkblog.raw_data, columns=['keyword', 'created_at', 'post_name', 'main_text', 'current_url'])

# %% [markdown]
# intake.df.loc[intake.df["user_id"] == 'intakefoods']

# %%
intake.df = intake.word_check('or', ['자동차', '흡기', '배기','도어락'], intake.df, 'hashtags', False)
intake.df = intake.word_check('or', ['intakefoods', 'dameulstudio', '_.ddo2', '__scarlett.k', '0.8l_korea', 'jiseung86', 'untactmarket'], intake.df, 'user_id', False)

# %% [markdown]
# conver
#
# temp = df_new_intake.loc[df_new['main_text'].str.contains('맛') & df_new['main_text'].str.contains('모닝죽') & df_new['main_text'].str.contains('있')]['']
# temp.describe()

# %%
intake.modified = intake.df.as_matrix()
intake.morph_list = intake.morph_pos(intake.modified[:, 2])

# %%
intake.morph_list[0]
# Out:
# ['아침_NNG',
#  '식사_NNG',
#  '죽_MAG',
#  '모닝죽_NNG',
#  '단호박_NNG',
#  '인테이크_NNG',
#  '몇_MM',
#  '년_NNBC',
#  '째_XSN',
#  '먹_VV',
#  '는_ETM',
#  '모닝죽_NNG',
#  '아침_NNG',
#  '엔_JKB+JX',
#  '바쁘_VA',
#  '기_ETN',
#  '도_JX',
#  '하_VV',
#  '고_EC',
#  '입맛_NNG',
#  '도_JX',
#  '없_VA',
#  '는데_EC',
#  '요거_NP',
#  '하나_NR',
#  '면_NNG',
#  '아침_NNG',
#  '뚝딱_MAG',
#  '맛_NNG',
#  '은_JX',
#  '여러_MM',
#  '종류_NNG',
#  '가_JKS',
#  '있_VA',
#  '는데_EF',
#  '다_MAG',
#  '맛있_VA',
#  '는데_EC',
#  '굳이_MAG',
#  '고르_VV',
#  '자면_EC',
#  '단호박_NNG',
#  '이랑_JKB',
#  '새로_MAG',
#  '나온_VV+ETM',
#  '꿀고구마_NNG',
#  '가_JKS',
#  '맛있_VA',
#  '오_EC']

# %% [markdown]
# ## csv에 안쓰고 이런식으로도 추가 가능. 하지만 csv에 자동저장되진 않는다.

# %%
intake.ngram_dic['아침_NNG/식사_NNG/죽_MAG/모닝죽_NNG'] = '과연잘바뀔까요_NNG'

# %%
intake.ngram_dic
# Out:
# {'꿀_NNG/고구마_NNG': '꿀고구마_NNG',
#  '모닝_NNP/죽_NNG': '모닝죽_NNG',
#  '아침_NNG/식사_NNG/죽_MAG/모닝죽_NNG': '과연잘바뀔까요_NNG',
#  '인_VCP+ETM/테이크_NNG': '인테이크_NNG'}

# %%
intake.modified = intake.df.as_matrix()
intake.morph_list = intake.morph_pos(intake.modified[:, 2])
intake.morph_list[0]
# Out:
# ['아침_NNG',
#  '식사_NNG',
#  '죽_MAG',
#  '모닝죽_NNG',
#  '단호박_NNG',
#  '인테이크_NNG',
#  '몇_MM',
#  '년_NNBC',
#  '째_XSN',
#  '먹_VV',
#  '는_ETM',
#  '모닝죽_NNG',
#  '아침_NNG',
#  '엔_JKB+JX',
#  '바쁘_VA',
#  '기_ETN',
#  '도_JX',
#  '하_VV',
#  '고_EC',
#  '입맛_NNG',
#  '도_JX',
#  '없_VA',
#  '는데_EC',
#  '요거_NP',
#  '하나_NR',
#  '면_NNG',
#  '아침_NNG',
#  '뚝딱_MAG',
#  '맛_NNG',
#  '은_JX',
#  '여러_MM',
#  '종류_NNG',
#  '가_JKS',
#  '있_VA',
#  '는데_EF',
#  '다_MAG',
#  '맛있_VA',
#  '는데_EC',
#  '굳이_MAG',
#  '고르_VV',
#  '자면_EC',
#  '단호박_NNG',
#  '이랑_JKB',
#  '새로_MAG',
#  '나온_VV+ETM',
#  '꿀고구마_NNG',
#  '가_JKS',
#  '맛있_VA',
#  '오_EC']

# %%
intake.del_list = ['아침', '식사']
intake.syn_dic['인테이크'] = '랩노쉬'

# %%
intake.nav_list, intake.noun_list, intake.adj_list, intake.verb_list = intake.pos_extractor(intake.morph_list)

# %%
intake.df['main_text'][0]
# Out:
# 'lora.study 아침식사 죽 모닝죽 단호박 인테이크\n.\n몇년째 먹는 모닝죽\n아침엔 바쁘기도 하고 입맛도 없는데 요거하나면 아침뚝딱�\n맛은 여러종류가 있는데.. 다 맛있는데 굳이 고르자면 단호박이랑 새로 나온 꿀고구마가 맛있오�'

# %%
intake.noun_list[0]
# Out:
# ['모닝죽', '단호박', '랩노쉬', '모닝죽', '입맛', '맛', '종류', '단호박', '꿀고구마']

# %%
intake.nav_merged = intake.merge_list(intake.nav_list)

intake.nav_frequency = frequency(intake.nav_merged)

pprint(intake.nav_frequency)
# Out:
# [('랩노쉬', 5679),
#  ('다이어트', 4731),
#  ('먹', 4709),
#  ('식단', 2596),
#  ('스타그램', 1827),
#  ('밀스', 1775),
#  ('모닝죽', 1748),
#  ('맛', 1709),
#  ('운동', 1563),
#  ('그램', 1349),
#  ('맛있', 1207),
#  ('다이어터', 1202),
#  ('간식', 1128),
#  ('건강', 1049),
#  ('있', 962),
#  ('저녁', 832),
#  ('일상', 826),
#  ('대용', 819),
#  ('오늘', 763),
#  ('점심', 697),
#  ('일기', 673),
#  ('단호박', 579),
#  ('칼로리', 522),
#  ('없', 521),
#  ('두유', 517),
#  ('소이', 499),
#  ('우유', 474),
#  ('소통', 451),
#  ('고구마', 438),
#  ('선물', 415),
#  ('밥', 404),
#  ('젤리', 400),
#  ('데일리', 392),
#  ('조절', 370),
#  ('직장', 365),
#  ('곤약젤리', 351),
#  ('푸드', 347),
#  ('밀크', 344),
#  ('식품', 340),
#  ('물', 338),
#  ('견과', 336),
#  ('홍삼', 333),
#  ('하루', 328),
#  ('기록', 328),
#  ('맛스타', 321),
#  ('미래', 319),
#  ('파워', 319),
#  ('모닝', 309),
#  ('비타민', 304),
#  ('챙겨', 303),
#  ('여자', 297),
#  ('이벤트', 296),
#  ('한끼', 289),
#  ('밀스라이트', 284),
#  ('시간', 284),
#  ('몸', 268),
#  ('생각', 256),
#  ('마시', 254),
#  ('구매', 247),
#  ('쉐이크', 239),
#  ('후기', 238),
#  ('슈퍼', 238),
#  ('쿠키', 236),
#  ('가슴살', 230),
#  ('제품', 223),
#  ('달', 218),
#  ('시작', 216),
#  ('선식', 213),
#  ('가지', 213),
#  ('간편식', 212),
#  ('사과', 212),
#  ('딸기', 210),
#  ('느낌', 207),
#  ('헬', 206),
#  ('카페', 206),
#  ('부스트', 206),
#  ('아침밥', 204),
#  ('아몬드', 202),
#  ('영양', 199),
#  ('단백질', 198),
#  ('샐러드', 198),
#  ('죽', 194),
#  ('코코넛', 194),
#  ('출근', 193),
#  ('식이조절', 189),
#  ('과자', 188),
#  ('사진', 186),
#  ('커피', 180),
#  ('관리', 179),
#  ('프로', 179),
#  ('하프', 178),
#  ('커버', 174),
#  ('놀라', 171),
#  ('주말', 170),
#  ('음식', 170),
#  ('힘내', 170),
#  ('추천', 167),
#  ('괜찮', 165),
#  ('체중', 165),
#  ('스틱', 165),
#  ('아임', 161),
#  ('요리', 160),
#  ('계란', 159),
#  ('미숫가루', 158),
#  ('이번', 157),
#  ('인친', 157),
#  ('체험', 157),
#  ('주문', 156),
#  ('포만감', 154),
#  ('야식', 154),
#  ('미노리', 154),
#  ('단팥', 154),
#  ('그래', 154),
#  ('넛츠', 148),
#  ('해서', 146),
#  ('참여', 145),
#  ('사람', 144),
#  ('사랑', 144),
#  ('호박죽', 143),
#  ('오리지널', 143),
#  ('감사', 143),
#  ('단호', 142),
#  ('도시락', 141),
#  ('박죽', 141),
#  ('블랙', 140),
#  ('바나나', 138),
#  ('귀리', 137),
#  ('보내', 135),
#  ('유산균', 135),
#  ('박스', 134),
#  ('미래형', 134),
#  ('요거트', 133),
#  ('올리브', 133),
#  ('만들', 133),
#  ('육아', 132),
#  ('수프', 131),
#  ('그린', 130),
#  ('요즘', 129),
#  ('섭취', 126),
#  ('스무디', 125),
#  ('바쁜', 124),
#  ('엄마', 124),
#  ('아이', 122),
#  ('닥터', 121),
#  ('감량', 121),
#  ('스타', 120),
#  ('꿀맛', 120),
#  ('정도', 119),
#  ('행복', 119),
#  ('먹방', 117),
#  ('브리즈', 116),
#  ('준비', 115),
#  ('뷰티', 114),
#  ('신청', 114),
#  ('단팥죽', 114),
#  ('씨드', 114),
#  ('바이오', 113),
#  ('구미', 113),
#  ('가능', 112),
#  ('과일', 111),
#  ('대신', 108),
#  ('위해', 107),
#  ('핑크', 106),
#  ('기분', 105),
#  ('멀티', 105),
#  ('투어', 105),
#  ('친구', 104),
#  ('편하', 104),
#  ('라이트', 102),
#  ('영양제', 102),
#  ('입맛', 101),
#  ('세트', 101),
#  ('내일', 101),
#  ('현정', 101),
#  ('세상', 100),
#  ('당첨', 100),
#  ('자매', 100),
#  ('맛나', 100),
#  ('건강식', 98),
#  ('키트', 98),
#  ('고구', 98),
#  ('마죽', 97),
#  ('챙기', 96),
#  ('팔로우', 96),
#  ('귀찮', 95),
#  ('습관', 95),
#  ('환영', 94),
#  ('빈스', 94),
#  ('데이', 93),
#  ('힘들', 93),
#  ('그레인', 92),
#  ('필요', 92),
#  ('계정', 92),
#  ('때문', 92),
#  ('시리얼', 91),
#  ('스프', 91),
#  ('언니', 90),
#  ('네이버', 90),
#  ('다음', 89),
#  ('스타일', 89),
#  ('공복', 88),
#  ('다노', 88),
#  ('지방', 88),
#  ('여름', 88),
#  ('꿀고구마', 87),
#  ('스타터', 87),
#  ('보충', 86),
#  ('부담', 86),
#  ('기대', 86),
#  ('개선', 86),
#  ('독립', 84),
#  ('초코', 83),
#  ('호박', 83),
#  ('대용식', 83),
#  ('밀스드링크', 82),
#  ('살빼', 82),
#  ('음료', 82),
#  ('피로', 82),
#  ('유지어터', 81),
#  ('헬스', 81),
#  ('곤약', 81),
#  ('치즈', 80),
#  ('남자', 80),
#  ('회사', 80),
#  ('잇클린', 80),
#  ('오렌지', 80),
#  ('진행', 80),
#  ('오랜만', 80),
#  ('바디', 79),
#  ('검은콩', 79),
#  ('주부', 79),
#  ('등산', 79),
#  ('추석', 79),
#  ('복싱', 79),
#  ('영양소', 78),
#  ('러닝', 78),
#  ('스포츠', 78),
#  ('볶음', 78),
#  ('리터', 78),
#  ('타임', 77),
#  ('야채', 77),
#  ('걱정', 77),
#  ('수퍼', 77),
#  ('퇴근', 77),
#  ('심심', 77),
#  ('매거진', 77),
#  ('최고', 76),
#  ('탄수화물', 76),
#  ('마음', 76),
#  ('가볍', 75),
#  ('프립', 75),
#  ('맛집', 75),
#  ('구입', 74),
#  ('부탁', 74),
#  ('생활', 74),
#  ('토마토', 73),
#  ('컴포트', 73),
#  ('브레드', 73),
#  ('클린', 73),
#  ('완료', 73),
#  ('푸즈', 73),
#  ('카레', 72),
#  ('싫', 72),
#  ('동안', 72),
#  ('테이블', 72),
#  ('고민', 71),
#  ('퓨어', 71),
#  ('스터', 71),
#  ('요가', 71),
#  ('식단인증', 70),
#  ('오후', 70),
#  ('다니', 69),
#  ('토요일', 69),
#  ('크루', 69),
#  ('협찬', 69),
#  ('무료', 69),
#  ('다이어트식', 69),
#  ('감자', 68),
#  ('안녕', 68),
#  ('미니', 68),
#  ('개인', 68),
#  ('카카오', 67),
#  ('어제', 67),
#  ('주일', 67),
#  ('라떼', 67),
#  ('셀카', 67),
#  ('양말', 67),
#  ('방법', 67),
#  ('레몬', 67),
#  ('챌린지', 66),
#  ('위한', 66),
#  ('모르', 66),
#  ('월요일', 66),
#  ('프로젝트', 66),
#  ('휴먼', 66),
#  ('부족', 65),
#  ('이상', 65),
#  ('피곤', 65),
#  ('씹히', 65),
#  ('굿모닝', 65),
#  ('배송', 65),
#  ('봉지', 65),
#  ('바쁘', 64),
#  ('망고', 64),
#  ('금요일', 64),
#  ('조각', 64),
#  ('바질', 64),
#  ('첨가', 64),
#  ('문의', 64),
#  ('오트밀', 63),
#  ('가루', 63),
#  ('식감', 63),
#  ('향신료', 63),
#  ('세끼', 62),
#  ('들어가', 62),
#  ('에너지', 62),
#  ('해야', 62),
#  ('택배', 62),
#  ('태그', 62),
#  ('가격', 61),
#  ('도움', 61),
#  ('처음', 61),
#  ('덕분', 60),
#  ('흔들', 60),
#  ('마지막', 60),
#  ('미네랄', 60),
#  ('워터', 60),
#  ('날씨', 60),
#  ('라이프', 60),
#  ('팥죽', 60),
#  ('패키지', 60),
#  ('복숭아', 59),
#  ('저칼로리', 59),
#  ('프레시모닝', 58),
#  ('완전', 58),
#  ('다이어트칩', 58),
#  ('피드', 58),
#  ('셀피', 58),
#  ('필수', 58),
#  ('만든', 58),
#  ('광고', 58),
#  ('꿈꾸', 58),
#  ('필라테스', 57),
#  ('줌마', 57),
#  ('도착', 57),
#  ('해결', 57),
#  ('두부', 57),
#  ('만나', 56),
#  ('출근길', 56),
#  ('대박', 56),
#  ('작성', 56),
#  ('검색', 56),
#  ('기간', 56),
#  ('켈프', 56),
#  ('댓글', 56),
#  ('고소', 55),
#  ('와서', 55),
#  ('방울토마토', 55),
#  ('여행', 55),
#  ('포장', 55),
#  ('성공', 55),
#  ('링크', 55),
#  ('배부른', 55),
#  ('아해', 55),
#  ('오빠', 54),
#  ('메뉴', 54),
#  ('취향', 54),
#  ('그래도', 54),
#  ('사먹', 54),
#  ('곡물', 54),
#  ('베리', 54),
#  ('국내', 54),
#  ('예정', 53),
#  ('직장인', 53),
#  ('신혼', 53),
#  ('나루', 53),
#  ('한잔', 52),
#  ('정신', 52),
#  ('몸무게', 52),
#  ('인증', 52),
#  ('성분', 52),
#  ('통밀', 52),
#  ('채소', 51),
#  ('프로필', 51),
#  ('할인', 51),
#  ('남편', 51),
#  ('스타벅스', 50),
#  ('단맛', 50),
#  ('파우', 50),
#  ('펀딩', 50),
#  ('니스', 50),
#  ('자연', 50),
#  ('선팔', 50),
#  ('마켓', 50),
#  ('맛있는다이어트칩', 50),
#  ('기능', 50),
#  ('우엉', 50),
#  ('정모', 50),
#  ('현미', 49),
#  ('아들', 49),
#  ('아기', 49),
#  ('추가', 48),
#  ('건데', 48),
#  ('그룹', 48),
#  ('배고파', 48),
#  ('쇼핑', 48),
#  ('맛난', 48),
#  ('잡곡밥', 48),
#  ('트레이닝', 48),
#  ('치아', 48),
#  ('소백산', 48),
#  ('식이섬유', 47),
#  ('수업', 47),
#  ('걸로', 47),
#  ('신랑', 47),
#  ('자전거', 47),
#  ('렌즈', 46),
#  ('저지방', 46),
#  ('스트레칭', 46),
#  ('그릇', 46),
#  ('카페다이어트', 46),
#  ('효과', 46),
#  ('녹차', 46),
#  ('게시', 46),
#  ('스튜디오', 46),
#  ('내구', 46),
#  ('스터디', 46),
#  ('디톡스', 45),
#  ('유산소', 45),
#  ('즐겁', 45),
#  ('서울', 44),
#  ('리뷰', 44),
#  ('식량', 44),
#  ('밸런스', 44),
#  ('끼니', 44),
#  ('즐거운', 44),
#  ('먹스', 44),
#  ('후드', 44),
#  ('워머', 44),
#  ('카페라떼', 43),
#  ('밀스칩', 43),
#  ('편의점', 43),
#  ('올리', 43),
#  ('새댁', 43),
#  ('파프리카', 43),
#  ('설탕', 42),
#  ('브로콜리', 42),
#  ('부부', 42),
#  ('마라톤', 42),
#  ('레시피', 42),
#  ('공유', 42),
#  ('유지', 42),
#  ('맛없', 42),
#  ('아메리카노', 42),
#  ('다신', 42),
#  ('종류', 41),
#  ('나온', 41),
#  ('나왔', 41),
#  ('라면', 41),
#  ('아보카도', 41),
#  ('배고파서', 41),
#  ('렌지', 41),
#  ('생일', 41),
#  ('한입', 41),
#  ('해독', 41),
#  ('근육', 41),
#  ('산행', 41),
#  ('거르', 40),
#  ('커리', 40),
#  ('주스', 40),
#  ('리얼', 40),
#  ('보이', 40),
#  ('일어나', 40),
#  ('회원', 40),
#  ('개월', 40),
#  ('관심', 40),
#  ('마스크', 40),
#  ('겨울', 40),
#  ('모닝귀리', 39),
#  ('배고플', 39),
#  ('아이스크림', 39),
#  ('가방', 39),
#  ('빠지', 39),
#  ('사용', 39),
#  ('화이팅', 39),
#  ('새벽', 39),
#  ('예쁜', 39),
#  ('냉장고', 39),
#  ('전자', 39),
#  ('나름', 39),
#  ('대구', 39),
#  ('식탁', 39),
#  ('엑스', 39),
#  ('유라', 39),
#  ('고기', 38),
#  ('와디즈', 38),
#  ('만족', 38),
#  ('연어', 38),
#  ('아빠', 38),
#  ('소개', 38),
#  ('군것질', 38),
#  ('드리', 38),
#  ('맥주', 38),
#  ('명절', 38),
#  ('다시마', 38),
#  ('일요일', 37),
#  ('코치', 37),
#  ('배부르', 37),
#  ('회복', 37),
#  ('마무리', 37),
#  ('기존', 37),
#  ('브런치', 37),
#  ('기원', 37),
#  ('리그', 37),
#  ('아웃도어', 37),
#  ('컨셉', 37),
#  ('덴마크', 36),
#  ('디저트', 36),
#  ('그런지', 36),
#  ('배고프', 36),
#  ('샌드위치', 36),
#  ('청포', 36),
#  ('스푼', 36),
#  ('블로그', 36),
#  ('체지방', 36),
#  ('플레이', 36),
#  ('지미', 36),
#  ('쟁여', 35),
#  ('폭식', 35),
#  ('홍경', 35),
#  ('선택', 35),
#  ('수제', 35),
#  ('모집', 35),
#  ('분말', 35),
#  ('복근', 35),
#  ('양송이', 35),
#  ('프리미엄', 35),
#  ('상품', 35),
#  ('발표', 35),
#  ('토스트', 34),
#  ('단백', 34),
#  ('동생', 34),
#  ('휴대', 34),
#  ('새로운', 34),
#  ('불금', 34),
#  ('시스선', 34),
#  ('대체', 34),
#  ('고마워', 34),
#  ('가족', 34),
#  ('디자인', 34),
#  ('돼지', 34),
#  ('우유죽', 34),
#  ('에스', 34),
#  ('미주', 33),
#  ('땅콩', 33),
#  ('나눠', 33),
#  ('세일', 33),
#  ('수요일', 33),
#  ('행사', 33),
#  ('시켜', 33),
#  ('사무실', 33),
#  ('예쁘', 33),
#  ('면역력', 33),
#  ('소세지', 33),
#  ('건더기', 32),
#  ('녀석', 32),
#  ('촬영', 32),
#  ('브랜드', 32),
#  ('카카오닙스', 32),
#  ('달걀', 32),
#  ('따라', 32),
#  ('피트', 32),
#  ('도전', 32),
#  ('마셔', 32),
#  ('힘든', 32),
#  ('인테리어', 32),
#  ('꺼내', 32),
#  ('비키니', 32),
#  ('완벽', 32),
#  ('눈꽃', 32),
#  ('커뮤니티', 32),
#  ('귀리우유', 31),
#  ('얼마', 31),
#  ('양파', 31),
#  ('냄새', 31),
#  ('평생', 31),
#  ('평소', 31),
#  ('기다리', 31),
#  ('실화', 31),
#  ('줄이', 31),
#  ('웨이트', 31),
#  ('치킨', 31),
#  ('고생', 31),
#  ('이유', 31),
#  ('티몬', 31),
#  ('화요일', 31),
#  ('큐브', 31),
#  ('보조제', 31),
#  ('조미료', 31),
#  ('학교', 31),
#  ('위트', 31),
#  ('호두', 31),
#  ('제작', 31),
#  ('레드', 31),
#  ('베이비', 31),
#  ('먹거리', 30),
#  ('그레인하프', 30),
#  ('조금', 30),
#  ('늦잠', 30),
#  ('즐기', 30),
#  ('아이스', 30),
#  ('강추', 30),
#  ('나오', 30),
#  ('정보', 30),
#  ('종합', 30),
#  ('브라질너트', 30),
#  ('당첨자', 30),
#  ('밀스드링크딸기', 29),
#  ('오이', 29),
#  ('가입', 29),
#  ('강남', 29),
#  ('병원', 29),
#  ('약속', 29),
#  ('얼굴', 29),
#  ('프로그램', 29),
#  ('청춘', 29),
#  ('케이크', 29),
#  ('감동', 29),
#  ('구운', 29),
#  ('라인', 29),
#  ('스페셜', 29),
#  ('밥상', 29),
#  ('학원', 28),
#  ('목요일', 28),
#  ('스테이크', 28),
#  ('출시', 28),
#  ('감성', 28),
#  ('볶음밥', 28),
#  ('배고픈', 28),
#  ('남기', 28),
#  ('메이드', 28),
#  ('통해', 28),
#  ('애정', 28),
#  ('배포', 28),
#  ('다양', 27),
#  ('보관', 27),
#  ('파우더', 27),
#  ('선스', 27),
#  ('카톡', 27),
#  ('부모', 27),
#  ('모델', 27),
#  ('조합', 27),
#  ('교정', 27),
#  ('재미', 27),
#  ('피티', 27),
#  ('저격', 27),
#  ('포뮬러', 27),
#  ('운영', 27),
#  ('상담', 27),
#  ('정리', 26),
#  ('그릭요거트', 26),
#  ('결국', 26),
#  ('훈제', 26),
#  ('수영', 26),
#  ('편리', 26),
#  ('그러', 26),
#  ('국산', 26),
#  ('스트레스', 26),
#  ('벨벳', 26),
#  ('기회', 26),
#  ('시스', 26),
#  ('에코', 26),
#  ('해도', 26),
#  ('오전', 26),
#  ('아미노', 26),
#  ('소스', 26),
#  ('학생', 26),
#  ('중요', 26),
#  ('부산', 26),
#  ('이쁘', 26),
#  ('드립니다', 26),
#  ('공지', 26),
#  ('코코', 26),
#  ('감기', 26),
#  ('런닝', 26),
#  ('해시', 26),
#  ('립스틱', 26),
#  ('지역', 26),
#  ('최다', 26),
#  ('보유', 26),
#  ('난다', 25),
#  ('발견', 25),
#  ('요구르트', 25),
#  ('당근', 25),
#  ('출장', 25),
#  ('이젠', 25),
#  ('여유', 25),
#  ('목표', 25),
#  ('고맙', 25),
#  ('자취', 25),
#  ('순간', 25),
#  ('엘시', 25),
#  ('피플', 25),
#  ('컨디션', 25),
#  ('냠냠', 25),
#  ('드링크', 25),
#  ('서울숲', 25),
#  ('표현', 25),
#  ('야근', 25),
#  ('된다', 25),
#  ('올릴', 25),
#  ('키친', 25),
#  ('김치', 25),
#  ('약콩', 25),
#  ('균형', 25),
#  ('골라', 25),
#  ('이후', 25),
#  ('대한', 25),
#  ('시크릿', 25),
#  ('삼보', 25),
#  ('채우', 25),
#  ('부르', 25),
#  ('동산', 25),
#  ('밀가루', 25),
#  ('클릭', 25),
#  ('콘트', 25),
#  ('동호회', 25),
#  ('찾아왔', 25),
#  ('가벼운', 24),
#  ('지금', 24),
#  ('충전', 24),
#  ('혼자', 24),
#  ('파티', 24),
#  ('임산부', 24),
#  ('씨리얼', 24),
#  ('아프', 24),
#  ('구성', 24),
#  ('슬라이스', 24),
#  ('판매', 24),
#  ('이미지', 24),
#  ('착한', 24),
#  ('고급', 24),
#  ('캡쳐', 24),
#  ('말차', 23),
#  ('만큼', 23),
#  ('전신', 23),
#  ('들어간', 23),
#  ('바쁠', 23),
#  ('크림', 23),
#  ('시식', 23),
#  ('완주', 23),
#  ('칭찬', 23),
#  ('데워', 23),
#  ('재료', 23),
#  ('영어', 23),
#  ('저번', 23),
#  ('몸매', 23),
#  ('땡기', 23),
#  ('흘리', 23),
#  ('달래', 23),
#  ('오픈', 23),
#  ('증정', 23),
#  ('공부', 23),
#  ('대학', 23),
#  ('운동전', 23),
#  ('맛보', 23),
#  ('마셨', 23),
#  ('트레이너', 23),
#  ('마실', 23),
#  ('계획', 23),
#  ('열량', 23),
#  ('골드', 23),
#  ('걷기', 23),
#  ('인원', 23),
#  ('이름', 23),
#  ('안주', 23),
#  ('프레쉬', 23),
#  ('식욕', 22),
#  ('후식', 22),
#  ('편한', 22),
#  ('아쉽', 22),
#  ('블루베리', 22),
#  ('모두', 22),
#  ('체크', 22),
#  ('고프', 22),
#  ('버터', 22),
#  ('한강', 22),
#  ('아이템', 22),
#  ('합니다', 22),
#  ('혼밥', 22),
#  ('이것저것', 22),
#  ('피자', 22),
#  ('인풋', 22),
#  ('기억', 22),
#  ('좋아하', 22),
#  ('느껴', 22),
#  ('전문', 22),
#  ('나트륨', 22),
#  ('데이트', 22),
#  ('안심', 22),
#  ('형태', 22),
#  ('신타', 22),
#  ('용기', 22),
#  ('마리', 22),
#  ('병아리', 22),
#  ('소비', 22),
#  ('사항', 22),
#  ('에이', 22),
#  ('최근', 22),
#  ('브릴리언트', 22),
#  ('댄스', 22),
#  ('기한', 22),
#  ('최저', 22),
#  ('에디션', 22),
#  ('챙길', 21),
#  ('모임', 21),
#  ('아점', 21),
#  ('허기', 21),
#  ('양상추', 21),
#  ('차리', 21),
#  ('신상', 21),
#  ('무한', 21),
#  ('요트', 21),
#  ('나가', 21),
#  ('거리', 21),
#  ('그렇', 21),
#  ('일반', 21),
#  ('함량', 21),
#  ('시험', 21),
#  ('든다', 21),
#  ('중간', 21),
#  ('스낵', 21),
#  ('홍보', 21),
#  ('본능', 21),
#  ('페이스북', 21),
#  ('자작나무', 21),
#  ('칼라', 21),
#  ('제주', 21),
#  ('휴가', 21),
#  ('곤약현미밥', 20),
#  ('믹스', 20),
#  ('신나', 20),
#  ('나쁘', 20),
#  ('비밀', 20),
#  ('시리즈', 20),
#  ('응원', 20),
#  ('나이트', 20),
#  ('달리', 20),
#  ('제거', 20),
#  ('가져가', 20),
#  ('근무', 20),
#  ('인바디', 20),
#  ('타입', 20),
#  ('진심', 20),
#  ('해요', 20),
#  ('뷰스타', 20),
#  ('워킹', 20),
#  ('집들이', 20),
#  ('인절미', 20),
#  ('진하', 20),
#  ('부스터', 20),
#  ('시그', 20),
#  ('버스', 20),
#  ('셀프', 20),
#  ('식빵', 20),
#  ('인생', 20),
#  ('회식', 20),
#  ('놓치', 20),
#  ('연휴', 20),
#  ('건지', 20),
#  ('곰돌이', 20),
#  ('덩어리', 20),
#  ('튜닝', 20),
#  ('한포', 20),
#  ('초콜릿', 20),
#  ('스토어', 20),
#  ('발포', 20),
#  ('해변', 20),
#  ('상단', 20),
#  ('버터치킨커리', 19),
#  ('중독', 19),
#  ('내사', 19),
#  ('특가', 19),
#  ('거부', 19),
#  ('조아', 19),
#  ('존맛', 19),
#  ('만드', 19),
#  ('문화', 19),
#  ('영상', 19),
#  ('스텝', 19),
#  ('시켰', 19),
#  ('외출', 19),
#  ('간단', 19),
#  ('돌리', 19),
#  ('라이', 19),
#  ('끝나', 19),
#  ('득템', 19),
#  ('노력', 19),
#  ('맞춤', 19),
#  ('다리', 19),
#  ('만시', 19),
#  ('전자레인지', 19),
#  ('장점', 19),
#  ('오프라인', 19),
#  ('변비', 19),
#  ('조심', 19),
#  ('고단', 19),
#  ('이해', 19),
#  ('이야기', 19),
#  ('광주', 19),
#  ('부림', 19),
#  ('케일', 19),
#  ('체력', 19),
#  ('흡입', 19),
#  ('대회', 19),
#  ('지나', 19),
#  ('영화', 19),
#  ('소고기', 19),
#  ('캠핑', 19),
#  ('요새', 19),
#  ('티포', 19),
#  ('비타', 19),
#  ('강한', 19),
#  ('스핑크', 19),
#  ('증진', 19),
#  ('이종', 19),
#  ('격투기', 19),
#  ('더럽', 19),
#  ('텐바이텐', 18),
#  ('상태', 18),
#  ('배부름', 18),
#  ('레이팅', 18),
#  ('빠른', 18),
#  ('느린', 18),
#  ('비프', 18),
#  ('바람', 18),
#  ('함정', 18),
#  ('하트', 18),
#  ('다행', 18),
#  ('텐데', 18),
#  ('장기', 18),
#  ('됩니다', 18),
#  ('즐길', 18),
#  ('동시', 18),
#  ('예약', 18),
#  ('사과즙', 18),
#  ('샘플', 18),
#  ('브라질', 18),
#  ('함유', 18),
#  ('남겨', 18),
#  ('류바', 18),
#  ('군고구마', 18),
#  ('떡볶이', 18),
#  ('앤드', 18),
#  ('아카시아', 18),
#  ('순수', 18),
#  ('귀여운', 18),
#  ('서점', 18),
#  ('초보', 18),
#  ('소금', 18),
#  ('캐슈', 18),
#  ('해수욕장', 18),
#  ('성지', 18),
#  ('리포스트', 18),
#  ('돌아와', 18),
#  ('자랑', 17),
#  ('고파서', 17),
#  ('다이어리', 17),
#  ('방토', 17),
#  ('레전드', 17),
#  ('과식', 17),
#  ('퇴근길', 17),
#  ('뚜껑', 17),
#  ('나머지', 17),
#  ('드려요', 17),
#  ('달치', 17),
#  ('러너', 17),
#  ('강제', 17),
#  ('부드럽', 17),
#  ('후추', 17),
#  ('차려', 17),
#  ('올해', 17),
#  ('피부', 17),
#  ('나라', 17),
#  ('채워', 17),
#  ('가즈', 17),
#  ('알갱이', 17),
#  ('개념', 17),
#  ('해당', 17),
#  ('은근', 17),
#  ('참치', 17),
#  ('서브웨이', 17),
#  ('일반식', 17),
#  ('달려', 17),
#  ('까스', 17),
#  ('제공', 17),
#  ('경우', 17),
#  ('반개', 17),
#  ('쿼트', 17),
#  ('귀차', 17),
#  ('언더', 17),
#  ('사이즈', 17),
#  ('아트', 17),
#  ('아미노산', 17),
#  ('완성', 17),
#  ('독소', 17),
#  ('빅스', 17),
#  ('인천', 17),
#  ('나와서', 17),
#  ('웨이', 17),
#  ('그럴', 17),
#  ('머슬', 17),
#  ('토시', 17),
#  ('요요', 17),
#  ('뮤직', 17),
#  ('밴드', 17),
#  ('오리지날', 17),
#  ('노웨어', 17),
#  ('유통기한', 16),
#  ('사은품', 16),
#  ('이랑', 16),
#  ('코코넛하프', 16),
#  ('진한', 16),
#  ('실패', 16),
#  ('참고', 16),
#  ('머리', 16),
#  ('그런가', 16),
#  ('올려', 16),
#  ('블로거', 16),
#  ('배고픔', 16),
#  ('도와', 16),
#  ('알약', 16),
#  ('즉석밥', 16),
#  ('포기', 16),
#  ('먹이', 16),
#  ('여의도', 16),
#  ('불편', 16),
#  ('부분', 16),
#  ('나이', 16),
#  ('플러스', 16),
#  ('본인', 16),
#  ('평일', 16),
#  ('미안', 16),
#  ('나중', 16),
#  ('활동', 16),
#  ('클래스', 16),
#  ('천연', 16),
#  ('재밌', 16),
#  ('미친', 16),
#  ('자체', 16),
#  ('식당', 16),
#  ('외식', 16),
#  ('스탠드', 16),
#  ('주라', 16),
#  ('놀이', 16),
#  ('마늘', 16),
#  ('양배추', 16),
#  ('송도', 16),
#  ('풀무원', 16),
#  ('센터', 16),
#  ('절반', 16),
#  ('포토', 16),
#  ('소리', 16),
#  ('귀리죽', 16),
#  ('구간', 16),
#  ('하체', 16),
#  ('스미', 16),
#  ('잡힌', 16),
#  ('포켓', 16),
#  ('디디', 16),
#  ('베이글', 16),
#  ('신혼집', 16),
#  ('가르시니', 16),
#  ('설날', 16),
#  ('의류', 16),
#  ('부지런', 16),
#  ('홍대', 16),
#  ('일렉트로', 16),
#  ('기념', 16),
#  ('컷팅', 16),
#  ('마운틴', 16),
#  ('클라이머', 16),
#  ('반숙', 15),
#  ('콜드', 15),
#  ('누룽지', 15),
#  ('소시지', 15),
#  ('쥬스', 15),
#  ('홈페이지', 15),
#  ('등등', 15),
#  ('자리', 15),
#  ('화장품', 15),
#  ('우드', 15),
#  ('요걸로', 15),
#  ('종일', 15),
#  ('비오', 15),
#  ('온라인', 15),
#  ('느끼', 15),
#  ('반성', 15),
#  ('추첨', 15),
#  ('말랭이', 15),
#  ('뱃살', 15),
#  ('방문', 15),
#  ('급하', 15),
#  ('편죽', 15),
#  ('바빠서', 15),
#  ('구경', 15),
#  ('비뉴', 15),
#  ('문제', 15),
#  ('콩가루', 15),
#  ('배불러', 15),
#  ('코스', 15),
#  ('반찬', 15),
#  ('봐야', 15),
#  ('분량', 15),
#  ('난리', 15),
#  ('초콜렛', 15),
#  ('메이크업', 15),
#  ('힐링', 15),
#  ('스콘', 15),
#  ('초록', 15),
#  ('야무지', 15),
#  ('당류', 15),
#  ('비싸', 15),
#  ('언스', 15),
#  ('김밥', 15),
#  ('오뚜기', 15),
#  ('수준', 15),
#  ('이너', 15),
#  ('다가오', 15),
#  ('자유', 15),
#  ('정상', 15),
#  ('크로스', 15),
#  ('틈새', 15),
#  ('대용품', 15),
#  ('효리', 15),
#  ('더치커피', 15),
#  ('파이브', 15),
#  ('호박돌', 15),
#  ('울산', 14),
#  ('매력', 14),
#  ('상추', 14),
#  ('쇼핑몰', 14),
#  ('의사', 14),
#  ('보통', 14),
#  ('파스타', 14),
#  ('까먹', 14),
#  ('살찌', 14),
#  ('한국', 14),
#  ('자취생', 14),
#  ('현미밥', 14),
#  ('아쉬운', 14),
#  ('주전부리', 14),
#  ('플레인', 14),
#  ('어렵', 14),
#  ('축하', 14),
#  ('섬유', 14),
#  ('취미', 14),
#  ('겁나', 14),
#  ('가슴', 14),
#  ('질리', 14),
#  ('비해', 14),
#  ('애기', 14),
#  ('추억', 14),
#  ('확인', 14),
#  ('필터', 14),
#  ('공간', 14),
#  ('패션', 14),
#  ('네일', 14),
#  ('버섯', 14),
#  ('분당', 14),
#  ('공기', 14),
#  ('폭풍', 14),
#  ('예전', 14),
#  ('다르', 14),
#  ('근력', 14),
#  ('떨어지', 14),
#  ('직원', 14),
#  ('시즌', 14),
#  ('청주', 14),
#  ('클리어', 14),
#  ('산책', 14),
#  ('결정', 14),
#  ('대전', 14),
#  ('뜨거운', 14),
#  ('키위', 14),
#  ('걸음', 14),
#  ('오징어', 14),
#  ('무침', 14),
#  ('간만', 14),
#  ('랜덤', 14),
#  ('분해', 14),
#  ('우치', 14),
#  ('출산', 14),
#  ('빠져', 14),
#  ('피칸', 14),
#  ('번개', 14),
#  ('타락죽', 14),
#  ('유래', 14),
#  ('여성', 14),
#  ('원하', 14),
#  ('프랑', 14),
#  ('호스', 14),
#  ('딜리', 14),
#  ('스타우브', 14),
#  ('버전', 13),
#  ('최애', 13),
#  ('수박', 13),
#  ('브루', 13),
#  ('아이폰', 13),
#  ('운동가', 13),
#  ('밀크티', 13),
#  ('장소', 13),
#  ('자극', 13),
#  ('흰자', 13),
#  ('커플', 13),
#  ('고고', 13),
#  ('쿠폰', 13),
#  ('소식', 13),
#  ('참외', 13),
#  ('스파이', 13),
#  ('지름신', 13),
#  ('허리', 13),
#  ('작업', 13),
#  ('만두', 13),
#  ('방지', 13),
#  ('공원', 13),
#  ('하세용', 13),
#  ('핑계', 13),
#  ('그날', 13),
#  ('플라워', 13),
#  ('자두', 13),
#  ('전후', 13),
#  ('주도', 13),
#  ('다녀왔', 13),
#  ('시장', 13),
#  ('대비', 13),
#  ('이용', 13),
#  ('이틀', 13),
#  ('용량', 13),
#  ('개봉', 13),
#  ('빈속', 13),
#  ('데워서', 13),
#  ('보조', 13),
#  ('지키', 13),
#  ('이쁜', 13),
#  ('포도', 13),
#  ('분위기', 13),
#  ('고추', 13),
#  ('조미', 13),
#  ('호기심', 13),
#  ('요일', 13),
#  ('자몽', 13),
#  ('유명', 13),
#  ('책임질', 13),
#  ('피스타치오', 13),
#  ('현대인', 13),
#  ('드세요', 13),
#  ('수원', 13),
#  ('기운', 13),
#  ('마셔야', 13),
#  ('첨가물', 13),
#  ('기구', 13),
#  ('대표', 13),
#  ('일산', 13),
#  ('인체', 13),
#  ('가을', 13),
#  ('합성', 13),
#  ('엣지', 13),
#  ('아르테', 13),
#  ('슬림', 13),
#  ('유자', 13),
#  ('다녀오', 12),
#  ('화장실', 12),
#  ('예상', 12),
#  ('허벅지', 12),
#  ('닭발', 12),
#  ('와중', 12),
#  ('의지', 12),
#  ('루니', 12),
#  ('약간', 12),
#  ('백미', 12),
#  ('즐거웠', 12),
#  ('바르', 12),
#  ('사온', 12),
#  ('시럽', 12),
#  ('마트', 12),
#  ('입점', 12),
#  ('위해서', 12),
#  ('햇살', 12),
#  ('눈뜨', 12),
#  ('넘치', 12),
#  ('모습', 12),
#  ('빠르', 12),
#  ('우먼', 12),
#  ('선생', 12),
#  ('인기', 12),
#  ('매장', 12),
#  ('바닥', 12),
#  ('고식', 12),
#  ('예뻐', 12),
#  ('활용', 12),
#  ('바보', 12),
#  ('빠진', 12),
#  ('표시', 12),
#  ('각종', 12),
#  ('크기', 12),
#  ('들어갔', 12),
#  ('혜자', 12),
#  ('콩죽', 12),
#  ('해야겠다', 12),
#  ('리뉴', 12),
#  ('청포도', 12),
#  ('결혼', 12),
#  ('무화과', 12),
#  ('교육', 12),
#  ('원래', 12),
#  ('토핑', 12),
#  ('구마', 12),
#  ('이마트', 12),
#  ('시절', 12),
#  ('개별', 12),
#  ('머핀', 12),
#  ('마이', 12),
#  ('다구리', 12),
#  ('고객', 12),
#  ('땡길', 12),
#  ('냉동실', 12),
#  ('주변', 12),
#  ('현실', 12),
#  ('식습관', 12),
#  ('캔디', 12),
#  ('그림', 12),
#  ('수다', 12),
#  ('끝내', 12),
#  ('청소', 12),
#  ('전용', 12),
#  ('건조', 12),
#  ('죽이', 12),
#  ('추운', 12),
#  ('도시', 12),
#  ('이럴', 12),
#  ('전쟁', 12),
#  ('사이드', 12),
#  ('파인애플', 12),
#  ('하늘', 12),
#  ('어쩔', 12),
#  ('적응', 12),
#  ('자세', 12),
#  ('수입', 12),
#  ('휘트', 12),
#  ('보식', 12),
#  ('연말', 12),
#  ('옵티멈', 12),
#  ('탈출', 12),
#  ('로티플', 12),
#  ('서킷', 12),
#  ('카이트', 12),
#  ('회비', 12),
#  ('미래지향', 11),
#  ('탄수', 11),
#  ('소화', 11),
#  ('베지밀', 11),
#  ('비트', 11),
#  ('시금치', 11),
#  ('서비스', 11),
#  ('리브', 11),
#  ('색깔', 11),
#  ('하우스', 11),
#  ('숟가락', 11),
#  ('패스', 11),
#  ('자신', 11),
#  ('나옴', 11),
#  ('참석', 11),
#  ('반쪽', 11),
#  ('전날', 11),
#  ('편해서', 11),
#  ('예비', 11),
#  ('꽃집', 11),
#  ('자제', 11),
#  ('변화', 11),
#  ('결론', 11),
#  ('콜라겐', 11),
#  ('부어서', 11),
#  ('습득', 11),
#  ('겁니다', 11),
#  ('원활', 11),
#  ('대로', 11),
#  ('전문점', 11),
#  ('알려', 11),
#  ('즐거움', 11),
#  ('고마워요', 11),
#  ('점심때', 11),
#  ('아가리', 11),
#  ('바이', 11),
#  ('사이', 11),
#  ('식이', 11),
#  ('지름', 11),
#  ('케어', 11),
#  ('연습', 11),
#  ('갈비', 11),
#  ('식판', 11),
#  ('마을', 11),
#  ('저녁밥', 11),
#  ('니즘', 11),
#  ('어쩌', 11),
#  ('에어', 11),
#  ('건가', 11),
#  ('아웃', 11),
#  ('황성주', 11),
#  ('휴식', 11),
#  ('실온', 11),
#  ('가요', 11),
#  ('터짐', 11),
#  ('국가', 11),
#  ('단점', 11),
#  ('애용', 11),
#  ('섞이', 11),
#  ('돌아오', 11),
#  ('헤이', 11),
#  ('골프', 11),
#  ('시티', 11),
#  ('경험', 11),
#  ('기업', 11),
#  ('발행', 11),
#  ('내용', 11),
#  ('옥수수', 11),
#  ('매일', 11),
#  ('카누', 11),
#  ('정원', 11),
#  ('극복', 11),
#  ('버티', 11),
#  ('만보', 11),
#  ('호르몬', 11),
#  ('미역국', 11),
#  ('초대', 11),
#  ('호텔', 11),
#  ('프리바', 11),
#  ('이오', 11),
#  ('포맨', 11),
#  ('혈액', 11),
#  ('데우', 11),
#  ('드셔', 11),
#  ('컬러', 11),
#  ('신사', 11),
#  ('로즈', 11),
#  ('성인', 11),
#  ('스코코', 11),
#  ('인스팅트', 11),
#  ('시기', 10),
#  ('내리', 10),
#  ('챙겨서', 10),
#  ('포인트', 10),
#  ('줄여', 10),
#  ('체리', 10),
#  ('메론', 10),
#  ('구이', 10),
#  ('콜라보', 10),
#  ('지하철', 10),
#  ('천사', 10),
#  ('필수품', 10),
#  ('한다', 10),
#  ('때우', 10),
#  ('똑같', 10),
#  ('압구정', 10),
#  ('고파', 10),
#  ('다짐', 10),
#  ('매트', 10),
#  ('더운', 10),
#  ('인정', 10),
#  ('오트', 10),
#  ('애플', 10),
#  ('신기', 10),
#  ('육포', 10),
#  ('레슨', 10),
#  ('한다고', 10),
#  ('크리스피', 10),
#  ('대학생', 10),
#  ('금주', 10),
#  ('유아', 10),
#  ('들어오', 10),
#  ('청양', 10),
#  ('어른', 10),
#  ('그랬', 10),
#  ('요정', 10),
#  ('양식', 10),
#  ('이러', 10),
#  ('순위', 10),
#  ('부드러운', 10),
#  ('인간', 10),
#  ('씨앗', 10),
#  ('가성', 10),
#  ('얼음', 10),
#  ('내용물', 10),
#  ('정했', 10),
#  ('찬물', 10),
#  ('정성', 10),
#  ('커스텀', 10),
#  ('넘어가', 10),
#  ('기초', 10),
#  ('당황', 10),
#  ('떠먹', 10),
#  ('밥알', 10),
#  ('바게트', 10),
#  ('터지', 10),
#  ('클럽', 10),
#  ('새우', 10),
#  ('갈릭', 10),
#  ('스파', 10),
#  ('연락', 10),
#  ('귀엽', 10),
#  ('그래퍼', 10),
#  ('원재료', 10),
#  ('전주', 10),
#  ('슬로우', 10),
#  ('기준', 10),
#  ('북한산', 10),
#  ('둘레길', 10),
#  ('오르', 10),
#  ('생수', 10),
#  ('불닭', 10),
#  ('이유식', 10),
#  ('노브랜드', 10),
#  ('쌀국수', 10),
#  ('얘기', 10),
#  ('수비', 10),
#  ('충동', 10),
#  ('대량', 10),
#  ('듯이', 10),
#  ('퍼먹', 10),
#  ('챙겨야', 10),
#  ('드레싱', 10),
#  ('써니', 10),
#  ('낮추', 10),
#  ('원샷', 10),
#  ('빨아먹', 10),
#  ('바빠', 10),
#  ('트리', 10),
#  ('잡지', 10),
#  ('입술', 10),
#  ('워크', 10),
#  ('올리고당', 10),
#  ('포우', 10),
#  ('해바라기', 10),
#  ('비아', 10),
#  ('안성', 10),
#  ('이하', 10),
#  ('피닝', 10),
#  ('재미있', 10),
#  ('아가', 10),
#  ('석류', 10),
#  ('시너지', 10),
#  ('아티스트', 10),
#  ('인터넷', 10),
#  ('아줌마', 10),
#  ('아마', 10),
#  ('인스', 10),
#  ('용품', 10),
#  ('감소', 10),
#  ('다크', 10),
#  ('앙금', 10),
#  ('정비', 10),
#  ('카카오톡', 10),
#  ('독립운동', 10),
#  ('규칙', 10),
#  ('캠퍼스', 10),
#  ('윤주', 10),
#  ('차갑', 9),
#  ('플랭크', 9),
#  ('출발', 9),
#  ('카푸치노', 9),
#  ('유기농', 9),
#  ('합격', 9),
#  ('가리', 9),
#  ('사회', 9),
#  ('시대', 9),
#  ('아이디어', 9),
#  ('힘드', 9),
#  ('글램', 9),
#  ('나눔', 9),
#  ('레이스', 9),
#  ('신경', 9),
#  ('수고', 9),
#  ('아디', 9),
#  ('안성맞춤', 9),
#  ('지난번', 9),
#  ('차이', 9),
#  ('남친', 9),
#  ('동네', 9),
#  ('땡겨', 9),
#  ('신박', 9),
#  ('다른', 9),
#  ('의미', 9),
#  ('보단', 9),
#  ('알찬', 9),
#  ('만점', 9),
#  ('검색창', 9),
#  ('충격', 9),
#  ('만난', 9),
#  ('넘김', 9),
#  ('초밥', 9),
#  ('해야지', 9),
#  ('포스팅', 9),
#  ('프리', 9),
#  ('챙겨온', 9),
#  ('큰일', 9),
#  ('도장', 9),
#  ('계단', 9),
#  ('해운대', 9),
#  ('흑미', 9),
#  ('컬리', 9),
#  ('심플', 9),
#  ('빠졌', 9),
#  ('크래커', 9),
#  ('관계', 9),
#  ('오일', 9),
#  ('림프', 9),
#  ('일어났', 9),
#  ('쳐묵', 9),
#  ('원료', 9),
#  ('비상', 9),
#  ('베이', 9),
#  ('라이스', 9),
#  ('실습', 9),
#  ('돌아가', 9),
#  ('내년', 9),
#  ('본다', 9),
#  ('타이어', 9),
#  ('인스턴트', 9),
#  ('정신없', 9),
#  ('첫날', 9),
#  ('근처', 9),
#  ('엄지', 9),
#  ('이래', 9),
#  ('분홍', 9),
#  ('사이클', 9),
#  ('우울', 9),
#  ('지난', 9),
#  ('그동안', 9),
#  ('배불', 9),
#  ('유동식', 9),
#  ('계속', 9),
#  ('지바', 9),
#  ('버리', 9),
#  ('레그', 9),
#  ('사이트', 9),
#  ('빠질', 9),
#  ('걸까', 9),
#  ('카본', 9),
#  ('고요', 9),
#  ('오틀리', 9),
#  ('기력', 9),
#  ('테이크', 9),
#  ('몸짱', 9),
#  ('구두', 9),
#  ('어린이', 9),
#  ('나와', 9),
#  ('돌려서', 9),
#  ('연락처', 9),
#  ('초점', 9),
#  ('으깨', 9),
#  ('코리아', 9),
#  ('담긴', 9),
#  ('편식', 9),
#  ('멸치', 9),
#  ('웨딩', 9),
#  ('스크루', 9),
#  ('허브', 9),
#  ('업그레이드', 9),
#  ('예술', 9),
#  ('피아노', 9),
#  ('크리스마스', 9),
#  ('위하', 9),
#  ('대학교', 9),
#  ('가미', 9),
#  ('리커버리', 9),
#  ('발레', 9),
#  ('코어', 9),
#  ('거북', 9),
#  ('러스', 9),
#  ('씨씨', 9),
#  ('민이', 9),
#  ('우하', 9),
#  ('노한', 9),
#  ('금지', 8),
#  ('모닝채소', 8),
#  ('유혹', 8),
#  ('팥빙수', 8),
#  ('특유', 8),
#  ('냉동', 8),
#  ('기아', 8),
#  ('점심밥', 8),
#  ('산후', 8),
#  ('부자', 8),
#  ('반사', 8),
#  ('부대찌개', 8),
#  ('카페인', 8),
#  ('발란스', 8),
#  ('지친', 8),
#  ('다스', 8),
#  ('이득', 8),
#  ('떠서', 8),
#  ('선수', 8),
#  ('지점', 8),
#  ('케이', 8),
#  ('노른자', 8),
#  ('지나가', 8),
#  ('허기져서', 8),
#  ('지옥', 8),
#  ('이브닝', 8),
#  ('무리', 8),
#  ('비교', 8),
#  ('씹힌다', 8),
#  ('서울대', 8),
#  ('위주', 8),
#  ('월요병', 8),
#  ('폭발', 8),
#  ('세션', 8),
#  ('센스', 8),
#  ('이제', 8),
#  ('편안', 8),
#  ('탄단', 8),
#  ('답사', 8),
#  ('걸렸', 8),
#  ('처리', 8),
#  ('도서관', 8),
#  ('김치찌개', 8),
#  ('느낄', 8),
#  ('배달', 8),
#  ('고마운', 8),
#  ('개시', 8),
#  ('시킨', 8),
#  ('기름', 8),
#  ('쇼콜라', 8),
#  ('만남', 8),
#  ('소환', 8),
#  ('과제', 8),
#  ('모드', 8),
#  ('모양', 8),
#  ('요플레', 8),
#  ('허니', 8),
#  ('터져서', 8),
#  ('벌크', 8),
#  ('엄청나', 8),
#  ('매콤', 8),
#  ('임신', 8),
#  ('의외', 8),
#  ('바다', 8),
#  ('다녀와서', 8),
#  ('교수', 8),
#  ('사장', 8),
#  ('매운', 8),
#  ('오븐', 8),
#  ('즐겨', 8),
#  ('케익', 8),
#  ('동원', 8),
#  ('레토르트', 8),
#  ('이동', 8),
#  ('조깅', 8),
#  ('제이', 8),
#  ('스타트', 8),
#  ('스타일링', 8),
#  ('강아지', 8),
#  ('아깝', 8),
#  ('뱅크', 8),
#  ('신상품', 8),
#  ('웰빙', 8),
#  ('자판기', 8),
#  ('모금', 8),
#  ('사놓', 8),
#  ('빵이', 8),
#  ('일치', 8),
#  ('맞음', 8),
#  ('부으면', 8),
#  ('생선', 8),
#  ('호박씨', 8),
#  ('몰랐', 8),
#  ('콩국수', 8),
#  ('인터', 8),
#  ('엔진', 8),
#  ('새해', 8),
#  ('애견', 8),
#  ('할까', 8),
#  ('코코아', 8),
#  ('잠들', 8),
#  ('본죽', 8),
#  ('쿠팡', 8),
#  ('잡곡', 8),
#  ('낫토', 8),
#  ('생기', 8),
#  ('양심', 8),
#  ('푸딩', 8),
#  ('공주', 8),
#  ('할머니', 8),
#  ('대해', 8),
#  ('마무트', 8),
#  ('발송', 8),
#  ('까르보', 8),
#  ('주소', 8),
#  ('크런치', 8),
#  ('단거', 8),
#  ('고양이', 8),
#  ('서리', 8),
#  ('후회', 8),
#  ('양념', 8),
#  ('직전', 8),
#  ('시중', 8),
#  ('결제', 8),
#  ('어묵', 8),
#  ('구리', 8),
#  ('기부', 8),
#  ('비어', 8),
#  ('책임져줄', 8),
#  ('진짜', 8),
#  ('기본', 8),
#  ('마카', 8),
#  ('파슬리', 8),
#  ('얼려', 8),
#  ('까망', 8),
#  ('베르', 8),
#  ('요법', 8),
#  ('느껴졌', 8),
#  ('반응', 8),
#  ('바라', 8),
#  ('리코타', 8),
#  ('신촌', 8),
#  ('김해', 8),
#  ('화이트', 8),
#  ('혈관', 8),
#  ('간다', 8),
#  ('헤어', 8),
#  ('소울', 8),
#  ('향기', 8),
#  ('미션', 8),
#  ('드립', 8),
#  ('통째', 8),
#  ('업무', 8),
#  ('강화', 8),
#  ('인터뷰', 8),
#  ('책방', 8),
#  ('용도', 8),
#  ('쉐이', 8),
#  ('미키', 8),
#  ('전원', 8),
#  ('퀘스트', 8),
#  ('프레시', 8),
#  ('미란다커', 8),
#  ('맥스', 8),
#  ('한국인', 8),
#  ('아망', 8),
#  ('교실', 8),
#  ('에브리', 8),
#  ('공개', 8),
#  ('발색', 8),
#  ('계절', 8),
#  ('퍼드', 8),
#  ('고르', 7),
#  ('입문', 7),
#  ('계산', 7),
#  ('중국', 7),
#  ('롤러', 7),
#  ('신세계', 7),
#  ('스윗그레인', 7),
#  ('써서', 7),
#  ('기전', 7),
#  ('핸드폰', 7),
#  ('모카', 7),
#  ('대두', 7),
#  ('커서', 7),
#  ('바꿔', 7),
#  ('기다렸', 7),
#  ('드론', 7),
#  ('한솔', 7),
#  ('급수', 7),
#  ('창업', 7),
#  ('접시', 7),
#  ('결심', 7),
#  ('작년', 7),
#  ('베이스', 7),
#  ('퍼지', 7),
#  ('발라', 7),
#  ('육개장', 7),
#  ('경천', 7),
#  ('생명', 7),
#  ('불량', 7),
#  ('흡수', 7),
#  ('지수', 7),
#  ('실천', 7),
#  ('수분', 7),
#  ('흡기', 7),
#  ('뚜레', 7),
#  ('거하', 7),
#  ('목이버섯', 7),
#  ('식구', 7),
#  ('아자', 7),
#  ('스피', 7),
#  ('액상', 7),
#  ('희희', 7),
#  ('더위', 7),
#  ('비용', 7),
#  ('기리', 7),
#  ('물건', 7),
#  ('대상', 7),
#  ('전체', 7),
#  ('올라가', 7),
#  ('키우', 7),
#  ('실물', 7),
#  ('절식', 7),
#  ('영양분', 7),
#  ('산딸기', 7),
#  ('이른', 7),
#  ('참가', 7),
#  ('알차', 7),
#  ('주의', 7),
#  ('이쁨', 7),
#  ('작가', 7),
#  ('올라오', 7),
#  ('예뻐서', 7),
#  ('칼슘', 7),
#  ('모여서', 7),
#  ('단체', 7),
#  ('빠짐', 7),
#  ('마치', 7),
#  ('일용', 7),
#  ('서울우유', 7),
#  ('그레', 7),
#  ('숙제', 7),
#  ('세븐', 7),
#  ('올림', 7),
#  ('버틸', 7),
#  ('사본', 7),
#  ('지갑', 7),
#  ('모아', 7),
#  ('데리', 7),
#  ('결혼식', 7),
#  ('나갈', 7),
#  ('새우볶음', 7),
#  ('발효', 7),
#  ('아파서', 7),
#  ('업체', 7),
#  ('시음', 7),
#  ('이얌', 7),
#  ('챙겼', 7),
#  ('깻잎', 7),
#  ('챙긴', 7),
#  ('생겨', 7),
#  ('대장', 7),
#  ('먹여', 7),
#  ('삼겹살', 7),
#  ('미인', 7),
#  ('진주', 7),
#  ('히알루론산', 7),
#  ('알로에', 7),
#  ('빨간', 7),
#  ('조식', 7),
#  ('뿌리', 7),
#  ('이전', 7),
#  ('분유', 7),
#  ('그때', 7),
#  ('싸이클', 7),
#  ('쌀알', 7),
#  ('갱신', 7),
#  ('배불러서', 7),
#  ('편함', 7),
#  ('버텨', 7),
#  ('대추', 7),
#  ('짜증', 7),
#  ('찬스', 7),
#  ('마신', 7),
#  ('이불', 7),
#  ('근대', 7),
#  ('종료', 7),
#  ('이루', 7),
#  ('부름', 7),
#  ('유치원', 7),
#  ('삼각김밥', 7),
#  ('시도', 7),
#  ('사랑니', 7),
#  ('순대', 7),
#  ('벗어나', 7),
#  ('정규', 7),
#  ('육회', 7),
#  ('지인', 7),
#  ('며칠', 7),
#  ('에프', 7),
#  ('폭식증', 7),
#  ('사고', 7),
#  ('로고', 7),
#  ('도입', 7),
#  ('보장', 7),
#  ('세계', 7),
#  ('신진대사', 7),
#  ('위장', 7),
#  ('아무것', 7),
#  ('맞춰진', 7),
#  ('아침잠', 7),
#  ('일본', 7),
#  ('기숙사', 7),
#  ('프랑크', 7),
#  ('순서', 7),
#  ('경기', 7),
#  ('피클', 7),
#  ('안전', 7),
#  ('스윗', 7),
#  ('방학', 7),
#  ('배우', 7),
#  ('거울', 7),
#  ('카스타', 7),
#  ('기상', 7),
#  ('무게', 7),
#  ('밤새', 7),
#  ('재미나', 7),
#  ('말린', 7),
#  ('눈썹', 7),
#  ('누베', 7),
#  ('피로회', 7),
#  ('올렸', 7),
#  ('합시다', 7),
#  ('배출', 7),
#  ('될까', 7),
#  ('망나니', 7),
#  ('동지', 7),
#  ('초등', 7),
#  ('에서', 7),
#  ('피지', 7),
#  ('멋진', 7),
#  ('죽순', 7),
#  ('산다', 7),
#  ('베이커리', 7),
#  ('인지', 7),
#  ('살려', 7),
#  ('리빙', 7),
#  ('해피', 7),
#  ('스타스', 7),
#  ('억제', 7),
#  ('신사역', 7),
#  ('위염', 7),
#  ('상상', 7),
#  ('벤트', 7),
#  ('비치', 7),
#  ('백년초', 7),
#  ('자분', 7),
#  ('쪼이', 7),
#  ('고정', 7),
#  ('디너', 7),
#  ('광고주', 7),
#  ('기획', 7),
#  ('아껴', 7),
#  ('용접', 7),
#  ('술안주', 7),
#  ('산모', 7),
#  ('크림치즈', 7),
#  ('수험', 7),
#  ('달빛', 7),
#  ('웅녀', 7),
#  ('지킨', 7),
#  ('높였', 7),
#  ('미티', 7),
#  ('체식', 6),
#  ('로얄밀크티', 6),
#  ('기쁨', 6),
#  ('디엠', 6),
#  ('병행', 6),
#  ('카드', 6),
#  ('매일유업', 6),
#  ('상온', 6),
#  ('사리', 6),
#  ('끓여', 6),
#  ('더워', 6),
#  ('뺀다', 6),
#  ('순삭', 6),
#  ('해소', 6),
#  ('무튼', 6),
#  ('크라', 6),
#  ('혁명', 6),
#  ('책임져', 6),
#  ('의문', 6),
#  ('대부분', 6),
#  ('지윤', 6),
#  ('블루투스', 6),
#  ('스피커', 6),
#  ('역삼동', 6),
#  ('언주', 6),
#  ('논현동', 6),
#  ('신사동', 6),
#  ('청담동', 6),
#  ('꼬치', 6),
#  ('건져', 6),
#  ('불러서', 6),
#  ('꺼냈', 6),
#  ('낮잠', 6),
#  ('비몽사몽', 6),
#  ('바른', 6),
#  ('넘기', 6),
#  ('숙취', 6),
#  ('플랫', 6),
#  ('아로니아', 6),
#  ('자서', 6),
#  ('속도', 6),
#  ('위험', 6),
#  ('허기진', 6),
#  ('방기', 6),
#  ('간장', 6),
#  ('과하', 6),
#  ('생각나', 6),
#  ('루리', 6),
#  ('야매', 6),
#  ('쪄서', 6),
#  ('고픈', 6),
#  ('떨어질', 6),
#  ('주년', 6),
#  ('섞인', 6),
#  ('쉬운', 6),
#  ('아까워서', 6),
#  ('플리', 6),
#  ('타이거', 6),
#  ('망했', 6),
#  ('빙수', 6),
#  ('데코', 6),
#  ('떨어져서', 6),
#  ('마심', 6),
#  ('젓가락', 6),
#  ('현상', 6),
#  ('친절', 6),
#  ('수정', 6),
#  ('지난주', 6),
#  ('아래', 6),
#  ('전시회', 6),
#  ('비율', 6),
#  ('마산', 6),
#  ('표정', 6),
#  ('지각', 6),
#  ('인사', 6),
#  ('순천', 6),
#  ('사전', 6),
#  ('죄책감', 6),
#  ('랬는', 6),
#  ('영업', 6),
#  ('그간', 6),
#  ('일품', 6),
#  ('소품', 6),
#  ('대학원', 6),
#  ('어릴', 6),
#  ('주식', 6),
#  ('호밀빵', 6),
#  ('탕수육', 6),
#  ('흑임자', 6),
#  ('미역', 6),
#  ('팔뚝', 6),
#  ('얼리', 6),
#  ('성수동', 6),
#  ('렌트', 6),
#  ('송료', 6),
#  ('허기질', 6),
#  ('애호박', 6),
#  ('생크림', 6),
#  ('연속', 6),
#  ('해장', 6),
#  ('느껴져서', 6),
#  ('무겁', 6),
#  ('생겼', 6),
#  ('한줌', 6),
#  ('라이브', 6),
#  ('실수', 6),
#  ('아내', 6),
#  ('사실', 6),
#  ('바도', 6),
#  ('시키', 6),
#  ('어버이날', 6),
#  ('식전', 6),
#  ('위로', 6),
#  ('재활', 6),
#  ('수성구', 6),
#  ('우동', 6),
#  ('좋아해서', 6),
#  ('담주', 6),
#  ('자색', 6),
#  ('주먹밥', 6),
#  ('시내', 6),
#  ('스타일리스트', 6),
#  ('최대', 6),
#  ('반갑', 6),
#  ('바닐라', 6),
#  ('돌아온', 6),
#  ('남김', 6),
#  ('타이', 6),
#  ('매워', 6),
#  ('잔소리', 6),
#  ('소녀', 6),
#  ('한정', 6),
#  ('마르', 6),
#  ('등원', 6),
#  ('국제', 6),
#  ('청바지', 6),
#  ('쿨러', 6),
#  ('터보', 6),
#  ('스팸', 6),
#  ('뒤늦', 6),
#  ('테스트', 6),
#  ('입구', 6),
#  ('컵라면', 6),
#  ('써야', 6),
#  ('준다', 6),
#  ('식초', 6),
#  ('지퍼', 6),
#  ('부른', 6),
#  ('노래', 6),
#  ('리알', 6),
#  ('장조림', 6),
#  ('계죽', 6),
#  ('야채샐러드', 6),
#  ('몸살', 6),
#  ('정기', 6),
#  ('역시', 6),
#  ('홀릭', 6),
#  ('순정', 6),
#  ('미쳤', 6),
#  ('전화', 6),
#  ('책임지', 6),
#  ('밀도', 6),
#  ('집어먹', 6),
#  ('폭탄', 6),
#  ('가벼워', 6),
#  ('휴무', 6),
#  ('찾아보', 6),
#  ('생긴', 6),
#  ('으로', 6),
#  ('가까운', 6),
#  ('아쉬움', 6),
#  ('오류', 6),
#  ('자신감', 6),
#  ('노예', 6),
#  ('둥이', 6),
#  ('포지', 6),
#  ('칼국수', 6),
#  ('뉴스', 6),
#  ('책임', 6),
#  ('검정콩', 6),
#  ('내조', 6),
#  ('기사', 6),
#  ('작심', 6),
#  ('집중', 6),
#  ('다닐', 6),
#  ('열운', 6),
#  ('사탕', 6),
#  ('결과', 6),
#  ('가치', 6),
#  ('지치', 6),
#  ('개꿀', 6),
#  ('머그', 6),
#  ('주방', 6),
#  ('와인', 6),
#  ('영양가', 6),
#  ('곱창', 6),
#  ('아파트', 6),
#  ('샤넬', 6),
#  ('팽이버섯', 6),
#  ('복부', 6),
#  ('플라스틱', 6),
#  ('오피스', 6),
#  ('갑니다', 6),
#  ('학년', 6),
#  ('예쁨', 6),
#  ('감독', 6),
#  ('기억력', 6),
#  ('탄산수', 6),
#  ('공연', 6),
#  ('해먹', 6),
#  ('불러', 6),
#  ('표고버섯', 6),
#  ('스팅어', 6),
#  ('소량', 6),
#  ('카페모카', 6),
#  ('인나', 6),
#  ('초이스', 6),
#  ('인치', 6),
#  ('제주도', 6),
#  ('마요네즈', 6),
#  ('개운', 6),
#  ('살까', 6),
#  ('편해요', 6),
#  ('토끼', 6),
#  ('파크', 6),
#  ('로드', 6),
#  ('살림', 6),
#  ('플레이크', 6),
#  ('실장', 6),
#  ('과정', 6),
#  ('가진', 6),
#  ('고픈데', 6),
#  ('가구', 6),
#  ('쾌변', 6),
#  ('엄청난', 6),
#  ('낱개', 6),
#  ('버킷', 6),
#  ('신장', 6),
#  ('입심', 6),
#  ('비추', 6),
#  ('번갈', 6),
#  ('하림', 6),
#  ('국시', 6),
#  ('파이팅', 6),
#  ('내장', 6),
#  ('착향료', 6),
#  ('상자', 6),
#  ('걸리', 6),
#  ('남매', 6),
#  ('강식', 6),
#  ('복지', 6),
#  ('어울리', 6),
#  ('속초', 6),
#  ('경주', 6),
#  ('봉투', 6),
#  ('레이크', 6),
#  ('돌렸', 6),
#  ('승리', 6),
#  ('국수', 6),
#  ('니타스', 6),
#  ('상시', 6),
#  ('제격', 6),
#  ('분석', 6),
#  ('고실', 6),
#  ('강사', 6),
#  ('현장', 6),
#  ('증가', 6),
#  ('안내', 6),
#  ('근교', 6),
#  ('전문직', 6),
#  ('종사자', 6),
#  ('힘듭니다', 6),
#  ('구조', 6),
#  ('석비', 6),
#  ('대한민국', 6),
#  ('원두', 6),
#  ('타르트', 6),
#  ('율무차', 6),
#  ('희망', 6),
#  ('린이', 6),
#  ('왼쪽', 6),
#  ('화보', 6),
#  ('플라이트', 6),
#  ('진세', 6),
#  ('허닭', 6),
#  ('아카데미', 6),
#  ('세종시', 6),
#  ('유주', 6),
#  ('싱그런', 6),
#  ('미미', 6),
#  ('매미', 6),
#  ('봄날', 6),
#  ('찾아와서', 6),
#  ('놀래', 6),
#  ('삽입', 6),
#  ('달기', 6),
#  ('왕관', 6),
#  ('제외', 6),
#  ('아레나', 6),
#  ('모건', 6),
#  ('임서방', 6),
#  ('라디오', 5),
#  ('보냈', 5),
#  ('상품권', 5),
#  ('1일1식', 5),
#  ('눈물', 5),
#  ('일쑤', 5),
#  ('설거지', 5),
#  ('따위', 5),
#  ('바꾸', 5),
#  ('오랫만', 5),
#  ('순환', 5),
#  ('강해서', 5),
#  ('상하목장', 5),
#  ('줄넘기', 5),
#  ('배고팠', 5),
#  ('저하', 5),
#  ('어깨', 5),
#  ('도배', 5),
#  ('애자', 5),
#  ('멋있', 5),
#  ('출석', 5),
#  ('스타트업', 5),
#  ('흔한', 5),
#  ('탄생', 5),
#  ('내입', 5),
#  ('리덕', 5),
#  ('느꼈', 5),
#  ('장마', 5),
#  ('불렀', 5),
#  ('식비', 5),
#  ('때려', 5),
#  ('수록', 5),
#  ('여의나루', 5),
#  ('입가심', 5),
#  ('자라', 5),
#  ('경품', 5),
#  ('바를', 5),
#  ('귀요미', 5),
#  ('현재', 5),
#  ('심장', 5),
#  ('책상', 5),
#  ('매니아', 5),
#  ('아반떼', 5),
#  ('포함', 5),
#  ('써브웨이', 5),
#  ('소분', 5),
#  ('잠실', 5),
#  ('마카롱', 5),
#  ('실험', 5),
#  ('고마웠', 5),
#  ('운전', 5),
#  ('빠져라', 5),
#  ('포화', 5),
#  ('노출', 5),
#  ('상황', 5),
#  ('이어지', 5),
#  ('문장', 5),
#  ('보여', 5),
#  ('새롭', 5),
#  ('쳐서', 5),
#  ('마감', 5),
#  ('보답', 5),
#  ('나무', 5),
#  ('고마', 5),
#  ('제이제이', 5),
#  ('롱드', 5),
#  ('지코', 5),
#  ('쑥떡', 5),
#  ('보인다', 5),
#  ('씹힘', 5),
#  ('전국', 5),
#  ('양치', 5),
#  ('늘어나', 5),
#  ('향도', 5),
#  ('누난', 5),
#  ('뱃속', 5),
#  ('서나', 5),
#  ('건물', 5),
#  ('심할', 5),
#  ('뿌려', 5),
#  ('연하', 5),
#  ('선거', 5),
#  ('정해', 5),
#  ('찐하', 5),
#  ('아쉬웠', 5),
#  ('이킹', 5),
#  ('사기', 5),
#  ('드릴', 5),
#  ('찐한', 5),
#  ('마그네슘', 5),
#  ('혜택', 5),
#  ('투표', 5),
#  ('지내', 5),
#  ('에센셜', 5),
#  ('아픈데', 5),
#  ('페이스', 5),
#  ('온다', 5),
#  ('마다', 5),
#  ('긍정', 5),
#  ('낸시', 5),
#  ('섞임', 5),
#  ('바이탈', 5),
#  ('독서', 5),
#  ('초반', 5),
#  ('정체기', 5),
#  ('검색어', 5),
#  ('야쿠르트', 5),
#  ('찹쌀떡', 5),
#  ('식후', 5),
#  ('인연', 5),
#  ('반가운', 5),
#  ('까지', 5),
#  ('돌려', 5),
#  ('무사', 5),
#  ('얼렸', 5),
#  ('성당', 5),
#  ('배부', 5),
#  ('각자', 5),
#  ('가져왔', 5),
#  ('챙겨준', 5),
#  ('조리', 5),
#  ('가바', 5),
#  ('말아먹', 5),
#  ('줄어들', 5),
#  ('대사', 5),
#  ('빡세', 5),
#  ('유청', 5),
#  ('콜레스테롤', 5),
#  ('짱구', 5),
#  ('침대', 5),
#  ('당도', 5),
#  ('설명', 5),
#  ('튀긴', 5),
#  ('소름', 5),
#  ('구용', 5),
#  ('히비스커스', 5),
#  ('호밀', 5),
#  ('돈육', 5),
#  ('단골', 5),
#  ('쭈니', 5),
#  ('아이디', 5),
#  ('최대한', 5),
#  ('껍질', 5),
#  ('아플', 5),
#  ('카네이션', 5),
#  ('성격', 5),
#  ('연맹', 5),
#  ('야지', 5),
#  ('인위', 5),
#  ('궁합', 5),
#  ('남녀', 5),
#  ('룰루랄라', 5),
#  ('자격증', 5),
#  ('연두부', 5),
#  ('양조', 5),
#  ('차림', 5),
#  ('패턴', 5),
#  ('랠리', 5),
#  ('쭈쭈', 5),
#  ('드림', 5),
#  ('신규', 5),
#  ('브라우니', 5),
#  ('황금', 5),
#  ('불고기', 5),
#  ('공짜', 5),
#  ('요한', 5),
#  ('바빴', 5),
#  ('김재식', 5),
#  ('공식', 5),
#  ('아픈', 5),
#  ('내자', 5),
#  ('빡시', 5),
#  ('장비', 5),
#  ('음료수', 5),
#  ('섞여', 5),
#  ('천안', 5),
#  ('콧물', 5),
#  ('한참', 5),
#  ('메일', 5),
#  ('덤벨', 5),
#  ('연구소', 5),
#  ('적혀', 5),
#  ('메추', 5),
#  ('무생채', 5),
#  ('도토리묵', 5),
#  ('몰리', 5),
#  ('송파', 5),
#  ('메로', 5),
#  ('태기', 5),
#  ('이겨', 5),
#  ('리딩', 5),
#  ('위드', 5),
#  ('설계', 5),
#  ('모터스', 5),
#  ('건망', 5),
#  ('게으름', 5),
#  ('주세요', 5),
#  ('가르', 5),
#  ('카라멜', 5),
#  ('야구', 5),
#  ('작심삼일', 5),
#  ('마니', 5),
#  ('디데이', 5),
#  ('송이', 5),
#  ('비키', 5),
#  ('레이즈', 5),
#  ('밥상머리', 5),
#  ('질렀', 5),
#  ('복귀', 5),
#  ('스토리', 5),
#  ('동아', 5),
#  ('회분', 5),
#  ('개당', 5),
#  ('나바', 5),
#  ('어때요', 5),
#  ('아미', 5),
#  ('전환', 5),
#  ('교시', 5),
#  ('삼양', 5),
#  ('치커리', 5),
#  ('된다고', 5),
#  ('이훈', 5),
#  ('브라더', 5),
#  ('고통', 5),
#  ('바나나맛', 5),
#  ('펭귄', 5),
#  ('나당', 5),
#  ('회사원', 5),
#  ('동영상', 5),
#  ('밸리', 5),
#  ('비엔나', 5),
#  ('수면', 5),
#  ('담날', 5),
#  ('특별', 5),
#  ('머랭', 5),
#  ('다미아', 5),
#  ('헤이즐넛', 5),
#  ('문구', 5),
#  ('시즈', 5),
#  ('설선', 5),
#  ('신난다', 5),
#  ('유리', 5),
#  ('강박', 5),
#  ('열운동', 5),
#  ('거래처', 5),
#  ('어린', 5),
#  ('아놀드홍', 5),
#  ('명산', 5),
#  ('씹혀', 5),
#  ('풍경', 5),
#  ('보였', 5),
#  ('무더위', 5),
#  ('심야', 5),
#  ('모닝커피', 5),
#  ('원숭이띠', 5),
#  ('비피', 5),
#  ('복제', 5),
#  ('내꺼야', 5),
#  ('돼요', 5),
#  ('남성', 5),
#  ('공항', 5),
#  ('보톡스', 5),
#  ('방해', 5),
#  ('요소', 5),
#  ('종영', 5),
#  ('양소', 5),
#  ('연비', 5),
#  ('내독소', 5),
#  ('깡패', 5),
#  ('어려운', 5),
#  ('스타드', 5),
#  ('구로', 5),
#  ('탄력', 5),
#  ('의정부', 5),
#  ('놀랐', 5),
#  ('신림', 5),
#  ('디자이너', 5),
#  ('어니언', 5),
#  ('식약청', 5),
#  ('친척', 5),
#  ('불안', 5),
#  ('바랍니다', 5),
#  ('지속', 5),
#  ('빨대', 5),
#  ('홀트', 5),
#  ('아동복', 5),
#  ('지회', 5),
#  ('마케팅', 5),
#  ('브라운', 5),
#  ('수유', 5),
#  ('어젯밤', 5),
#  ('배불러요', 5),
#  ('번창', 5),
#  ('사업', 5),
#  ('선발전', 5),
#  ('쓰리', 5),
#  ('피치', 5),
#  ('벌꿀', 5),
#  ('패밀리', 5),
#  ('바이크', 5),
#  ('히도', 5),
#  ('담겨', 5),
#  ('실내', 5),
#  ('클라이밍', 5),
#  ('티켓', 5),
#  ('떼우', 5),
#  ('총각', 5),
#  ('맛볼', 5),
#  ('나용', 5),
#  ('복용', 5),
#  ('셰이크', 5),
#  ('미용실', 5),
#  ('다이어', 5),
#  ('연관', 5),
#  ('쉐프', 5),
#  ('절제', 5),
#  ('섬유질', 5),
#  ('손종현', 5),
#  ('코스모', 5),
#  ('비타민제', 5),
#  ('원액', 5),
#  ('옴므', 5),
#  ('꼬맹이', 5),
#  ('만우절', 5),
#  ('전투', 5),
#  ('기프트', 5),
#  ('불태우', 5),
#  ('요미', 5),
#  ('하리보', 5),
#  ('일주', 5),
#  ('소일', 5),
#  ('게이너', 5),
#  ('줄리아', 5),
#  ('페레로', 5),
#  ('축적', 5),
#  ('은지', 5),
#  ('필링크', 5),
#  ('까페', 5),
#  ('메이크', 5),
#  ('이영', 5),
#  ('숙성', 5),
#  ('문자', 4),
#  ('버터치킨', 4),
#  ('주전', 4),
#  ('토달', 4),
#  ('만사', 4),
#  ('팥톡스', 4),
#  ('국물', 4),
#  ('시트', 4),
#  ('콩나물', 4),
#  ('완두콩', 4),
#  ('주제', 4),
#  ('노랑', 4),
#  ('와요', 4),
#  ('다방', 4),
#  ('지르', 4),
#  ('귀찬', 4),
#  ('어떨', 4),
#  ('과학', 4),
#  ('만세', 4),
#  ('질감', 4),
#  ('대화', 4),
#  ('반복', 4),
#  ('석호', 4),
#  ('말콤', 4),
#  ('경수', 4),
#  ('홍석', 4),
#  ('액션', 4),
#  ('유한', 4),
#  ('윤영', 4),
#  ('경환', 4),
#  ('소담', 4),
#  ('다솜', 4),
#  ('주자', 4),
#  ('불리', 4),
#  ('아름다운', 4),
#  ('베스트', 4),
#  ('졸려', 4),
#  ('종로', 4),
#  ('들렸', 4),
#  ('김치볶음밥', 4),
#  ('여름휴가', 4),
#  ('리커', 4),
#  ('손실', 4),
#  ('달릴', 4),
#  ('갈비찜', 4),
#  ('살아나', 4),
#  ('남길', 4),
#  ('보호', 4),
#  ('모찌', 4),
#  ('못생김', 4),
#  ('강하', 4),
#  ('위작', 4),
#  ('용인', 4),
#  ('로스트', 4),
#  ('들어간다', 4),
#  ('코드', 4),
#  ('시나몬', 4),
#  ('여친', 4),
#  ('공구', 4),
#  ('다이', 4),
#  ('한숨', 4),
#  ('새끼', 4),
#  ('캡슐', 4),
#  ('시어터', 4),
#  ('감탄', 4),
#  ('애니', 4),
#  ('마차', 4),
#  ('경희대', 4),
#  ('아토', 4),
#  ('볼일', 4),
#  ('바지', 4),
#  ('편해', 4),
#  ('아웃풋', 4),
#  ('유일', 4),
#  ('발화', 4),
#  ('붙이', 4),
#  ('조기', 4),
#  ('봐서', 4),
#  ('가져다주', 4),
#  ('컨테이너', 4),
#  ('반값', 4),
#  ('건빵', 4),
#  ('무염', 4),
#  ('잘라', 4),
#  ('유행', 4),
#  ('사라짐', 4),
#  ('미루', 4),
#  ('인상', 4),
#  ('차향', 4),
#  ('더워서', 4),
#  ('조정', 4),
#  ('매런', 4),
#  ('마라', 4),
#  ('쌈장', 4),
#  ('모자라', 4),
#  ('모어', 4),
#  ('티비', 4),
#  ('다노바', 4),
#  ('반가웠', 4),
#  ('택시', 4),
#  ('휴일', 4),
#  ('반한', 4),
#  ('평균', 4),
#  ('달리기', 4),
#  ('부럽', 4),
#  ('다요', 4),
#  ('문화동', 4),
#  ('터졌', 4),
#  ('내려가', 4),
#  ('기다려', 4),
#  ('나올', 4),
#  ('지원', 4),
#  ('게유', 4),
#  ('부장', 4),
#  ('거트', 4),
#  ('입안', 4),
#  ('아픔', 4),
#  ('달렸', 4),
#  ('대용량', 4),
#  ('쿠퍼', 4),
#  ('취업', 4),
#  ('했었', 4),
#  ('영향', 4),
#  ('나잇', 4),
#  ('개조', 4),
#  ('농도', 4),
#  ('실리콘', 4),
#  ('처먹', 4),
#  ('발전', 4),
#  ('갈께요', 4),
#  ('돼서', 4),
#  ('주위', 4),
#  ('봐도', 4),
#  ('다녔', 4),
#  ('살쪄', 4),
#  ('소모', 4),
#  ('박사', 4),
#  ('남긴', 4),
#  ('뜯어먹', 4),
#  ('친한', 4),
#  ('돌잔치', 4),
#  ('종아리', 4),
#  ('갈까', 4),
#  ('반숙란', 4),
#  ('후배', 4),
#  ('차안', 4),
#  ('일정', 4),
#  ('하단', 4),
#  ('쥬얼', 4),
#  ('건과', 4),
#  ('이프로', 4),
#  ('생일상', 4),
#  ('해산물', 4),
#  ('파리', 4),
#  ('호불호', 4),
#  ('꿀잠', 4),
#  ('배고파요', 4),
#  ('습관성', 4),
#  ('감자튀김', 4),
#  ('모야', 4),
#  ('클렌징', 4),
#  ('롯데마트', 4),
#  ('오리', 4),
#  ('라멘', 4),
#  ('응모', 4),
#  ('봐요', 4),
#  ('딸래미', 4),
#  ('내맘대로', 4),
#  ('찌개', 4),
#  ('구워서', 4),
#  ('말씀', 4),
#  ('날려', 4),
#  ('가져온', 4),
#  ('숙주나물', 4),
#  ('이디야', 4),
#  ('사료', 4),
#  ('단비', 4),
#  ('연구', 4),
#  ('예방', 4),
#  ('튀김', 4),
#  ('환불', 4),
#  ('이뻐', 4),
#  ('특이', 4),
#  ('프라', 4),
#  ('드실', 4),
#  ('퍼스널', 4),
#  ('서포터', 4),
#  ('손가락', 4),
#  ('킬로', 4),
#  ('준거', 4),
#  ('입양', 4),
#  ('고려', 4),
#  ('이사', 4),
#  ('생겨서', 4),
#  ('데울', 4),
#  ('알바', 4),
#  ('아사이', 4),
#  ('에피', 4),
#  ('고추장', 4),
#  ('파이', 4),
#  ('페퍼민트', 4),
#  ('인한', 4),
#  ('질러', 4),
#  ('배부른데', 4),
#  ('눕혀서', 4),
#  ('서방', 4),
#  ('마당', 4),
#  ('비비', 4),
#  ('의원', 4),
#  ('치료', 4),
#  ('개취', 4),
#  ('무디', 4),
#  ('배추김치', 4),
#  ('착즙', 4),
#  ('두부조림', 4),
#  ('압축', 4),
#  ('검사', 4),
#  ('숫자', 4),
#  ('오바', 4),
#  ('터치', 4),
#  ('반병', 4),
#  ('키즈', 4),
#  ('주머니', 4),
#  ('외근', 4),
#  ('뒤돌아서', 4),
#  ('도넛', 4),
#  ('단기', 4),
#  ('무서운', 4),
#  ('생략', 4),
#  ('감자탕', 4),
#  ('피넛', 4),
#  ('강릉', 4),
#  ('능력', 4),
#  ('죠리퐁', 4),
#  ('모를', 4),
#  ('찹쌀', 4),
#  ('청년', 4),
#  ('프레스', 4),
#  ('어린잎', 4),
#  ('모시', 4),
#  ('거절', 4),
#  ('몸만들기', 4),
#  ('콩밥', 4),
#  ('역대', 4),
#  ('추워서', 4),
#  ('땅콩버터', 4),
#  ('빨라', 4),
#  ('저스트', 4),
#  ('팩토리', 4),
#  ('가스', 4),
#  ('누워서', 4),
#  ('이기', 4),
#  ('합리', 4),
#  ('효율', 4),
#  ('대식가', 4),
#  ('손바닥', 4),
#  ('할텐데', 4),
#  ('전병', 4),
#  ('조림', 4),
#  ('오믈렛', 4),
#  ('제때', 4),
#  ('생채', 4),
#  ('거제', 4),
#  ('백화점', 4),
#  ('운동복', 4),
#  ('단독', 4),
#  ('봉봉', 4),
#  ('숟갈', 4),
#  ('할려고', 4),
#  ('음악', 4),
#  ('투자', 4),
#  ('원장', 4),
#  ('벚꽃', 4),
#  ('디즈', 4),
#  ('창고', 4),
#  ('고대', 4),
#  ('통곡', 4),
#  ('무거운', 4),
#  ('가져', 4),
#  ('기쁘', 4),
#  ('원동력', 4),
#  ('울회', 4),
#  ('원님', 4),
#  ('타파', 4),
#  ('산점', 4),
#  ('시켜야', 4),
#  ('셀렉', 4),
#  ('고개', 4),
#  ('하우', 4),
#  ('편지', 4),
#  ('올라온', 4),
#  ('기침', 4),
#  ('고른', 4),
#  ('고팠', 4),
#  ('구름', 4),
#  ('전망대', 4),
#  ('배경', 4),
#  ('수량', 4),
#  ('케이스', 4),
#  ('전달', 4),
#  ('엉망진창', 4),
#  ('망설이', 4),
#  ('들려서', 4),
#  ('질려서', 4),
#  ('미세먼지', 4),
#  ('저울', 4),
#  ('골라서', 4),
#  ('그레이', 4),
#  ('또띠', 4),
#  ('무섭', 4),
#  ('프레이크', 4),
#  ('리스트', 4),
#  ('모트', 4),
#  ('카테킨', 4),
#  ('돌아왔', 4),
#  ('수령', 4),
#  ('버거', 4),
#  ('나리', 4),
#  ('스켓', 4),
#  ('제형', 4),
#  ('입막음', 4),
#  ('후레쉬', 4),
#  ('얼려서', 4),
#  ('이당', 4),
#  ('떨어진', 4),
#  ('면역', 4),
#  ('크러쉬', 4),
#  ('까까', 4),
#  ('폰트', 4),
#  ('스케줄', 4),
#  ('탐방', 4),
#  ('줘서', 4),
#  ('주간', 4),
#  ('조하', 4),
#  ('천국', 4),
#  ('와플', 4),
#  ('깜놀', 4),
#  ('합성동', 4),
#  ('월계수', 4),
#  ('이뻐서', 4),
#  ('착해서', 4),
#  ('누르', 4),
#  ('정월', 4),
#  ('보름', 4),
#  ('막히', 4),
#  ('등장', 4),
#  ('친정', 4),
#  ('풀렸', 4),
#  ('베이지', 4),
#  ('통해서', 4),
#  ('사태', 4),
#  ('모여', 4),
#  ('디카페인', 4),
#  ('여수', 4),
#  ('켈로그', 4),
#  ('고치', 4),
#  ('개뿔', 4),
#  ('찬다', 4),
#  ('할께요', 4),
#  ('쏟아지', 4),
#  ('바지락', 4),
#  ('구정', 4),
#  ('정관', 4),
#  ('메카', 4),
#  ('파츠', 4),
#  ('그릴', 4),
#  ('당장', 4),
#  ('묶음', 4),
#  ('현기증', 4),
#  ('정직', 4),
#  ('수혈', 4),
#  ('마인드', 4),
#  ('사차', 4),
#  ('늘리', 4),
#  ('풀리', 4),
#  ('귀한', 4),
#  ('한다면', 4),
#  ('노트', 4),
#  ('체인지', 4),
#  ('남양유업', 4),
#  ('강남역', 4),
#  ('인공', 4),
#  ('서랍', 4),
#  ('브레이크', 4),
#  ('루이보스', 4),
#  ('인식', 4),
#  ('추우', 4),
#  ('존재', 4),
#  ('의도', 4),
#  ('통현', 4),
#  ('에너', 4),
#  ('막걸리', 4),
#  ('합정', 4),
#  ('트라이얼', 4),
#  ('지니', 4),
#  ('그래요', 4),
#  ('이원', 4),
#  ('우왕', 4),
#  ('오예', 4),
#  ('역사', 4),
#  ('동성', 4),
#  ('리언', 4),
#  ('오구', 4),
#  ('잠자', 4),
#  ('스텐', 4),
#  ('무한리필', 4),
#  ('망원', 4),
#  ('트레이', 4),
#  ('독박', 4),
#  ('원피스', 4),
#  ('차지', 4),
#  ('여왕', 4),
#  ('효능', 4),
#  ('기별', 4),
#  ('어떨지', 4),
#  ('세세', 4),
#  ('킬러', 4),
#  ('형제', 4),
#  ('기호', 4),
#  ('팝업', 4),
#  ('한우', 4),
#  ('모녀', 4),
#  ('잘라서', 4),
#  ('서프라이즈', 4),
#  ('단신', 4),
#  ('나와요', 4),
#  ('기입', 4),
#  ('숙박', 4),
#  ('수술', 4),
#  ('축제', 4),
#  ('모래', 4),
#  ('부천', 4),
#  ('업로드', 4),
#  ('파주', 4),
#  ('아재', 4),
#  ('공감', 4),
#  ('달째', 4),
#  ('블럭', 4),
#  ('위기', 4),
#  ('후원', 4),
#  ('개그맨', 4),
#  ('이세진', 4),
#  ('다니엘', 4),
#  ('캔들', 4),
#  ('센트', 4),
#  ('정식', 4),
#  ('튜브', 4),
#  ('알람', 4),
#  ('광교', 4),
#  ('콘돔', 4),
#  ('색이', 4),
#  ('챙겨요', 4),
#  ('우수', 4),
#  ('갈증', 4),
#  ('클래식', 4),
#  ('아캄', 4),
#  ('추출물', 4),
#  ('밀즈', 4),
#  ('소프트', 4),
#  ('죽도', 4),
#  ('유액', 4),
#  ('바빠도', 4),
#  ('로우', 4),
#  ('단식', 4),
#  ('할땐', 4),
#  ('애스타', 4),
#  ('조음', 4),
#  ('한식', 4),
#  ('미치', 4),
#  ('순이', 4),
#  ('핸들러', 4),
#  ('건포도', 4),
#  ('원주', 4),
#  ('프레드', 4),
#  ('벤츠', 4),
#  ('영화관', 4),
#  ('했으니', 4),
#  ('채워서', 4),
#  ('목장', 4),
#  ('센트럴', 4),
#  ('조커', 4),
#  ('마키', 4),
#  ('목적', 4),
#  ('바깥', 4),
#  ('버릇', 4),
#  ('걸어가', 4),
#  ('시공', 4),
#  ('사례', 4),
#  ('아마존', 4),
#  ('아아', 4),
#  ('교회', 4),
#  ('홍차', 4),
#  ('참새', 4),
#  ('중학교', 4),
#  ('화천', 4),
#  ('초록색', 4),
#  ('기반', 4),
#  ('이모', 4),
#  ('초딩', 4),
#  ('참깨', 4),
#  ('군산', 4),
#  ('곁들여', 4),
#  ('색상', 4),
#  ('조이', 4),
#  ('황금기', 4),
#  ('반디', 4),
#  ('스프링', 4),
#  ('특허', 4),
#  ('역삼역', 4),
#  ('페이지', 4),
#  ('공방', 4),
#  ('리브레', 4),
#  ('호빵', 4),
#  ('튀기', 4),
#  ('식물', 4),
#  ('에뛰드', 4),
#  ('귀여워', 4),
#  ('추선', 4),
#  ('두뇌', 4),
#  ('천도복숭아', 4),
#  ('주월동', 4),
#  ('운도', 4),
#  ('토리', 4),
#  ('보편', 4),
#  ('배민', 4),
#  ('로쉐', 4),
#  ('롤링', 4),
#  ('과다', 4),
#  ('둥글', 4),
#  ('남치', 4),
#  ('새언니', 4),
#  ('아드', 4),
#  ('스모킹', 4),
#  ('아나킨', 4),
#  ('오미자', 4),
#  ('경단', 4),
#  ('빨랫줄', 3),
#  ('고농축', 3),
#  ('얼리버드', 3),
#  ('사라졌', 3),
#  ('하루야채', 3),
#  ('영혼', 3),
#  ('무나', 3),
#  ('거르기', 3),
#  ('다이렉트', 3),
#  ('냄비', 3),
#  ('공복감', 3),
#  ('단축', 3),
#  ('색감', 3),
#  ('에스프레소', 3),
#  ('바리스타', 3),
#  ('볶음콩', 3),
#  ('커브', 3),
#  ('해라', 3),
#  ('끓이', 3),
#  ('생긴다', 3),
#  ('분리', 3),
#  ('다녀', 3),
#  ('브라이트', 3),
#  ('목살', 3),
#  ('함박', 3),
#  ('헤비', 3),
#  ('와사비', 3),
#  ('로얄', 3),
#  ('버려', 3),
#  ('코디', 3),
#  ('트렌드', 3),
#  ('창원', 3),
#  ('비결', 3),
#  ('익선동', 3),
#  ('발려', 3),
#  ('인분', 3),
#  ('갈아먹', 3),
#  ('달린', 3),
#  ('발리', 3),
#  ('인도', 3),
#  ('노리', 3),
#  ('햇빛', 3),
#  ('지진', 3),
#  ('덜한', 3),
#  ('살찔', 3),
#  ('서플리', 3),
#  ('페이서', 3),
#  ('지켜보', 3),
#  ('뭉치', 3),
#  ('미뤄', 3),
#  ('지은', 3),
#  ('끈적임', 3),
#  ('수대', 3),
#  ('심해', 3),
#  ('설치', 3),
#  ('골든', 3),
#  ('얻어먹', 3),
#  ('더블', 3),
#  ('톡스', 3),
#  ('구웠', 3),
#  ('실종', 3),
#  ('눈감', 3),
#  ('소포', 3),
#  ('대지', 3),
#  ('태어나', 3),
#  ('곳간', 3),
#  ('해줌', 3),
#  ('루테인', 3),
#  ('바꿨', 3),
#  ('땡겼', 3),
#  ('소심', 3),
#  ('라지', 3),
#  ('비빔밥', 3),
#  ('지하', 3),
#  ('허들', 3),
#  ('아파', 3),
#  ('신호', 3),
#  ('액체', 3),
#  ('휴학생', 3),
#  ('임파', 3),
#  ('선염', 3),
#  ('중심', 3),
#  ('역할', 3),
#  ('들려', 3),
#  ('한주', 3),
#  ('세이', 3),
#  ('과장', 3),
#  ('워라', 3),
#  ('그런', 3),
#  ('니모', 3),
#  ('얼린', 3),
#  ('만삭', 3),
#  ('마가', 3),
#  ('예고', 3),
#  ('쓴맛', 3),
#  ('상한', 3),
#  ('주세', 3),
#  ('포카리', 3),
#  ('가공', 3),
#  ('편할', 3),
#  ('안장', 3),
#  ('부지', 3),
#  ('감추', 3),
#  ('규동', 3),
#  ('일부', 3),
#  ('비우', 3),
#  ('피크닉', 3),
#  ('인우', 3),
#  ('관련', 3),
#  ('가라앉', 3),
#  ('절약', 3),
#  ('카야노', 3),
#  ('의리', 3),
#  ('위생', 3),
#  ('타사', 3),
#  ('흘릴', 3),
#  ('나서', 3),
#  ('적극', 3),
#  ('참가자', 3),
#  ('전하', 3),
#  ('배변', 3),
#  ('여보', 3),
#  ('추울', 3),
#  ('친하', 3),
#  ('구내식당', 3),
#  ('들어감', 3),
#  ('아스', 3),
#  ('검차', 3),
#  ('나눠서', 3),
#  ('성수', 3),
#  ('자스타', 3),
#  ('가위바위보', 3),
#  ('도치', 3),
#  ('긴장', 3),
#  ('내려서', 3),
#  ('쫓기', 3),
#  ('욕심', 3),
#  ('제안', 3),
#  ('나누', 3),
#  ('소주', 3),
#  ('언저리', 3),
#  ('바뀌', 3),
#  ('유어', 3),
#  ('콩국', 3),
#  ('콩두', 3),
#  ('다녀도', 3),
#  ('실용', 3),
#  ('사재', 3),
#  ('공휴일', 3),
#  ('허기지', 3),
#  ('동료', 3),
#  ('포크', 3),
#  ('밴쿠버', 3),
#  ('우정', 3),
#  ('활력', 3),
#  ('장국', 3),
#  ('몰라요', 3),
#  ('들이', 3),
#  ('배추', 3),
#  ('장난', 3),
#  ('마카로니', 3),
#  ('강정', 3),
#  ('등심', 3),
#  ('토탈', 3),
#  ('뿌림', 3),
#  ('돼지고기', 3),
#  ('모밀', 3),
#  ('내려오', 3),
#  ('직구', 3),
#  ('영양식', 3),
#  ('조사', 3),
#  ('아쉬워', 3),
#  ('백수', 3),
#  ('설마', 3),
#  ('선배', 3),
#  ('하인즈', 3),
#  ('백숙', 3),
#  ('날짜', 3),
#  ('주워', 3),
#  ('방식', 3),
#  ('본의', 3),
#  ('소용', 3),
#  ('혼합', 3),
#  ('품질', 3),
#  ('부업', 3),
#  ('마법', 3),
#  ('참으', 3),
#  ('유통', 3),
#  ('거짓말', 3),
#  ('재우', 3),
#  ('베란다', 3),
#  ('무가당', 3),
#  ('코크', 3),
#  ('파운드', 3),
#  ('새우만두', 3),
#  ('미만', 3),
#  ('시합', 3),
#  ('공화국', 3),
#  ('소맥', 3),
#  ('구워', 3),
#  ('올려야', 3),
#  ('들렀', 3),
#  ('나열', 3),
#  ('치즈케이크', 3),
#  ('정착', 3),
#  ('라따뚜이', 3),
#  ('파트너', 3),
#  ('실제', 3),
#  ('직행', 3),
#  ('오니', 3),
#  ('어린이집', 3),
#  ('호두과자', 3),
#  ('된장', 3),
#  ('조화', 3),
#  ('맥반석', 3),
#  ('연기', 3),
#  ('몸뚱아리', 3),
#  ('파스텔', 3),
#  ('바란스', 3),
#  ('두릅', 3),
#  ('채워줄', 3),
#  ('원조', 3),
#  ('소식가', 3),
#  ('주황색', 3),
#  ('월남', 3),
#  ('스크램블', 3),
#  ('이나', 3),
#  ('봄맞이', 3),
#  ('깨달음', 3),
#  ('편집', 3),
#  ('불타', 3),
#  ('레깅스', 3),
#  ('넘겨', 3),
#  ('머드', 3),
#  ('아름답', 3),
#  ('아푸', 3),
#  ('우승', 3),
#  ('추운데', 3),
#  ('멍청이', 3),
#  ('선착순', 3),
#  ('페스티벌', 3),
#  ('누나', 3),
#  ('이리', 3),
#  ('따또', 3),
#  ('필드', 3),
#  ('스파게티', 3),
#  ('장미', 3),
#  ('바라보', 3),
#  ('녹여', 3),
#  ('온몸', 3),
#  ('매각', 3),
#  ('살쪘', 3),
#  ('보스', 3),
#  ('열일', 3),
#  ('이슬', 3),
#  ('동용', 3),
#  ('밀렸', 3),
#  ('연남동', 3),
#  ('트레일', 3),
#  ('통과', 3),
#  ('저질', 3),
#  ('무릎', 3),
#  ('야호', 3),
#  ('터빈', 3),
#  ('스테이지', 3),
#  ('홈플러스', 3),
#  ('피로야', 3),
#  ('세종', 3),
#  ('설레임', 3),
#  ('요기', 3),
#  ('과한', 3),
#  ('노란', 3),
#  ('지겨워서', 3),
#  ('월급날', 3),
#  ('보노', 3),
#  ('누텔라', 3),
#  ('와이드', 3),
#  ('산다는', 3),
#  ('포장지', 3),
#  ('거의', 3),
#  ('포식', 3),
#  ('순두부', 3),
#  ('마요', 3),
#  ('식대', 3),
#  ('반죽', 3),
#  ('핫초코', 3),
#  ('밤고구마', 3),
#  ('기억나', 3),
#  ('싫어하', 3),
#  ('종이', 3),
#  ('화장', 3),
#  ('지우', 3),
#  ('요양', 3),
#  ('장염', 3),
#  ('골반', 3),
#  ('발라서', 3),
#  ('단사', 3),
#  ('당하', 3),
#  ('추워', 3),
#  ('코바', 3),
#  ('모션', 3),
#  ('느껴진다', 3),
#  ('패킹', 3),
#  ('여기저기', 3),
#  ('데친', 3),
#  ('고인돌', 3),
#  ('익스트림', 3),
#  ('올려서', 3),
#  ('가단', 3),
#  ('떨어져', 3),
#  ('아머', 3),
#  ('자켓', 3),
#  ('릴레이', 3),
#  ('한동안', 3),
#  ('부종', 3),
#  ('지식', 3),
#  ('단계', 3),
#  ('신고', 3),
#  ('보여요', 3),
#  ('끝났으면', 3),
#  ('해장국', 3),
#  ('안정', 3),
#  ('태가', 3),
#  ('로메인', 3),
#  ('예감', 3),
#  ('올라왔', 3),
#  ('손목', 3),
#  ('감칠맛', 3),
#  ('할지', 3),
#  ('목감기', 3),
#  ('완존', 3),
#  ('착하', 3),
#  ('보양', 3),
#  ('써요', 3),
#  ('느낀', 3),
#  ('될까요', 3),
#  ('고래', 3),
#  ('구가', 3),
#  ('컴백', 3),
#  ('세븐일레븐', 3),
#  ('재능', 3),
#  ('공동', 3),
#  ('신체', 3),
#  ('아팠', 3),
#  ('골골대', 3),
#  ('팀장', 3),
#  ('국밥', 3),
#  ('글자', 3),
#  ('설명서', 3),
#  ('금액', 3),
#  ('충족', 3),
#  ('향연', 3),
#  ('흐름', 3),
#  ('배고픈데', 3),
#  ('생후', 3),
#  ('트럭', 3),
#  ('아크릴', 3),
#  ('정체', 3),
#  ('옹심', 3),
#  ('덮밥', 3),
#  ('깜빡하', 3),
#  ('떨어졌', 3),
#  ('파이터', 3),
#  ('통장', 3),
#  ('닭갈비', 3),
#  ('일리', 3),
#  ('내기', 3),
#  ('소셜', 3),
#  ('파니니', 3),
#  ('생길', 3),
#  ('꼬꼬', 3),
#  ('매운맛', 3),
#  ('바베큐', 3),
#  ('토이', 3),
#  ('운명', 3),
#  ('대행', 3),
#  ('위안', 3),
#  ('다즐링', 3),
#  ('냉장', 3),
#  ('바램', 3),
#  ('비만', 3),
#  ('피자헛', 3),
#  ('비싼', 3),
#  ('정신줄', 3),
#  ('다이빙', 3),
#  ('구름길', 3),
#  ('소규모', 3),
#  ('피부과', 3),
#  ('전복죽', 3),
#  ('텍스', 3),
#  ('품절', 3),
#  ('컴퓨터', 3),
#  ('심하', 3),
#  ('겉절이', 3),
#  ('관장', 3),
#  ('두입', 3),
#  ('압박', 3),
#  ('외부', 3),
#  ('시당', 3),
#  ('야밤', 3),
#  ('후르츠', 3),
#  ('러버', 3),
#  ('갖춘', 3),
#  ('두산', 3),
#  ('포스트', 3),
#  ('시켜서', 3),
#  ('윙크', 3),
#  ('여우', 3),
#  ('핫도그', 3),
#  ('돌아다니', 3),
#  ('혈당', 3),
#  ('육고추장', 3),
#  ('오이생채', 3),
#  ('버림', 3),
#  ('비스킷', 3),
#  ('스파이스', 3),
#  ('콜라', 3),
#  ('판다', 3),
#  ('도쿄', 3),
#  ('비온다', 3),
#  ('이탈리안', 3),
#  ('싸리재', 3),
#  ('방앗간', 3),
#  ('머신', 3),
#  ('복직', 3),
#  ('쌓여', 3),
#  ('개강', 3),
#  ('기술', 3),
#  ('건새', 3),
#  ('매생', 3),
#  ('움직이', 3),
#  ('라라', 3),
#  ('밀린', 3),
#  ('노랭이', 3),
#  ('갈아타', 3),
#  ('강원도', 3),
#  ('된다니', 3),
#  ('요리사', 3),
#  ('들녘', 3),
#  ('재이니', 3),
#  ('금복주', 3),
#  ('성능', 3),
#  ('잡채', 3),
#  ('이중생활', 3),
#  ('발목', 3),
#  ('케이블', 3),
#  ('달성', 3),
#  ('한라', 3),
#  ('차가운', 3),
#  ('선호', 3),
#  ('눈앞', 3),
#  ('부추', 3),
#  ('구매처', 3),
#  ('브이', 3),
#  ('퍼포먼스', 3),
#  ('약문', 3),
#  ('피타', 3),
#  ('자려', 3),
#  ('보낼', 3),
#  ('접해', 3),
#  ('영추', 3),
#  ('체형', 3),
#  ('풀이', 3),
#  ('누워', 3),
#  ('계란밥', 3),
#  ('독감', 3),
#  ('락앤락', 3),
#  ('취침', 3),
#  ('케틀', 3),
#  ('스윙', 3),
#  ('초면', 3),
#  ('꼬꼬마', 3),
#  ('알아보', 3),
#  ('델리', 3),
#  ('미트볼', 3),
#  ('만날', 3),
#  ('리어', 3),
#  ('장식', 3),
#  ('퍼센트', 3),
#  ('베지', 3),
#  ('일출', 3),
#  ('핸드', 3),
#  ('한약', 3),
#  ('비로봉', 3),
#  ('부농', 3),
#  ('마사지', 3),
#  ('어르신', 3),
#  ('리조', 3),
#  ('패딩', 3),
#  ('하얀', 3),
#  ('인티', 3),
#  ('드렸', 3),
#  ('고지방', 3),
#  ('혁신', 3),
#  ('이빨', 3),
#  ('파이프', 3),
#  ('둘러보', 3),
#  ('착용', 3),
#  ('다듬', 3),
#  ('뷔페', 3),
#  ('스퀘어', 3),
#  ('코트', 3),
#  ('딸내미', 3),
#  ('따님', 3),
# ...
#  ('비해서', 1),
#  ('세련', 1),
#  ('지향', 1),
#  ('바이럴', 1),
#  ('응아', 1),
#  ('단다', 1),
#  ('도래', 1),
#  ('담임', 1),
#  ('귀여움', 1),
#  ('진정한', 1),
#  ('장속', 1),
#  ('배양', 1),
#  ('장건', 1),
#  ('비커', 1),
#  ('수맛', 1),
#  ('먼데이', 1),
#  ('판타지', 1),
#  ('해지', 1),
#  ('장아', 1),
#  ('겁났', 1),
#  ('이달', 1),
#  ('농협', 1),
#  ('만리', 1),
#  ('세용', 1),
#  ('내릴래', 1),
#  ('공진단', 1),
#  ('카베', 1),
#  ('식혜', 1),
#  ('찾아가', 1),
#  ('영양학', 1),
#  ('스피룰리나', 1),
#  ('금상첨화', 1),
#  ('분리수거', 1),
#  ('뒷주머니', 1),
#  ('임박', 1),
#  ('바리오', 1),
#  ('동반자', 1),
#  ('헤즈메', 1),
#  ('리카', 1),
#  ('워러', 1),
#  ('법석', 1),
#  ('테크', 1),
#  ('선도', 1),
#  ('사옥', 1),
#  ('신들린', 1),
#  ('리나', 1),
#  ('번거롭', 1),
#  ('파티션', 1),
#  ('넘어오', 1),
#  ('들린', 1),
#  ('이이', 1),
#  ('기다릴게요', 1),
#  ('기다립니다', 1),
#  ('까부', 1),
#  ('파전', 1),
#  ('동동주', 1),
#  ('뜬물', 1),
#  ('유익', 1),
#  ('유해', 1),
#  ('헝그리', 1),
#  ('푸른색', 1),
#  ('대리', 1),
#  ('불토', 1),
#  ('강동구', 1),
#  ('유부남', 1),
#  ('던데', 1),
#  ('풀기', 1),
#  ('마셔서', 1),
#  ('배아', 1),
#  ('방요', 1),
#  ('걸어다니', 1),
#  ('산고', 1),
#  ('세노', 1),
#  ('비스만', 1),
#  ('것만', 1),
#  ('난단', 1),
#  ('양림동', 1),
#  ('서구', 1),
#  ('남구', 1),
#  ('레보', 1),
#  ('소미', 1),
#  ('부끄러움', 1),
#  ('기다릴까', 1),
#  ('생고구마', 1),
#  ('철분제', 1),
#  ('무지하', 1),
#  ('이규민', 1),
#  ('미니미', 1),
#  ('둥근', 1),
#  ('보름달', 1),
#  ('깨물', 1),
#  ('잡술', 1),
#  ('겐가', 1),
#  ('콘플레이크', 1),
#  ('담겨짐', 1),
#  ('들이켜', 1),
#  ('왕국', 1),
#  ('갈라', 1),
#  ('폰타나', 1),
#  ('피에몬테', 1),
#  ('군밤', 1),
#  ('꽃등심', 1),
#  ('종이컵', 1),
#  ('들이밀', 1),
#  ('세입', 1),
#  ('소용없', 1),
#  ('세알', 1),
#  ('위장병', 1),
#  ('잉글리시', 1),
#  ('유창', 1),
#  ('바나나킥', 1),
#  ('가져간다', 1),
#  ('박수', 1),
#  ('친다', 1),
#  ('거래', 1),
#  ('챙겨줘', 1),
#  ('입금', 1),
#  ('최곤데', 1),
#  ('콩고물', 1),
#  ('두꺼운', 1),
#  ('떨어뜨리', 1),
#  ('떠다닐', 1),
#  ('명목', 1),
#  ('밥걱정', 1),
#  ('물엿', 1),
#  ('글리세린', 1),
#  ('최고봉', 1),
#  ('안다구', 1),
#  ('베이컨', 1),
#  ('아오', 1),
#  ('빈후', 1),
#  ('보컬', 1),
#  ('노설', 1),
#  ('섭외', 1),
#  ('한현철', 1),
#  ('이외', 1),
#  ('쌀보리', 1),
#  ('율무', 1),
#  ('수수', 1),
#  ('검정깨', 1),
#  ('들깨', 1),
#  ('은행', 1),
#  ('홍화', 1),
#  ('신선초', 1),
#  ('솔잎', 1),
#  ('뽕잎', 1),
#  ('쥐코', 1),
#  ('즐거', 1),
#  ('이파리', 1),
#  ('고비', 1),
#  ('꿀참외', 1),
#  ('자니', 1),
#  ('여비', 1),
#  ('지켰', 1),
#  ('초심', 1),
#  ('군데', 1),
#  ('진천동', 1),
#  ('냉장실', 1),
#  ('글레이즈', 1),
#  ('부셔', 1),
#  ('이양', 1),
#  ('고마워하', 1),
#  ('물고지', 1),
#  ('뉴질랜드', 1),
#  ('쥐어짜', 1),
#  ('방황', 1),
#  ('욕봤', 1),
#  ('걸린다고', 1),
#  ('사드', 1),
#  ('날카로워', 1),
#  ('무민', 1),
#  ('페리오', 1),
#  ('결의', 1),
#  ('돌맞이', 1),
#  ('고속도', 1),
#  ('가락국수', 1),
#  ('휴게소', 1),
#  ('얼음장', 1),
#  ('눈발', 1),
#  ('달려라', 1),
#  ('첫눈', 1),
#  ('마우스패드', 1),
#  ('귀여운데', 1),
#  ('받침대', 1),
#  ('잠잘', 1),
#  ('후언', 1),
#  ('나아졌', 1),
#  ('품명', 1),
#  ('누디', 1),
#  ('바닥나기', 1),
#  ('지친다', 1),
#  ('아카', 1),
#  ('끼니때', 1),
#  ('마누라', 1),
#  ('모셔', 1),
#  ('임팩트', 1),
#  ('종각', 1),
#  ('주재료', 1),
#  ('샌드', 1),
#  ('한자', 1),
#  ('눌러', 1),
#  ('매김', 1),
#  ('궁동', 1),
#  ('충남', 1),
#  ('장대동', 1),
#  ('대파', 1),
#  ('부드러워', 1),
#  ('할리데이', 1),
#  ('비슨', 1),
#  ('포스터', 1),
#  ('바버', 1),
#  ('게이지', 1),
#  ('크리너', 1),
#  ('내꺼니까', 1),
#  ('스루', 1),
#  ('극소량', 1),
#  ('시리', 1),
#  ('애끼', 1),
#  ('무거', 1),
#  ('리토', 1),
#  ('임당', 1),
#  ('네이밍', 1),
#  ('나기', 1),
#  ('바래요', 1),
#  ('단모', 1),
#  ('커튼', 1),
#  ('가스레인지', 1),
#  ('바깥쪽', 1),
#  ('곤지', 1),
#  ('암천', 1),
#  ('쏘이', 1),
#  ('갈라짐', 1),
#  ('오리진', 1),
#  ('수지니', 1),
#  ('가세', 1),
#  ('나날', 1),
#  ('그랜드', 1),
#  ('역쉬', 1),
#  ('크리스프', 1),
#  ('감귤', 1),
#  ('진저', 1),
#  ('앞선', 1),
#  ('반칙', 1),
#  ('스키장', 1),
#  ('털리', 1),
#  ('미진', 1),
#  ('아저씨', 1),
#  ('여심', 1),
#  ('해뒀', 1),
#  ('머플러', 1),
#  ('드릴께요', 1),
#  ('느껴질', 1),
#  ('이불속', 1),
#  ('애벌레', 1),
#  ('김장', 1),
#  ('확신', 1),
#  ('할라', 1),
#  ('단스', 1),
#  ('정산', 1),
#  ('다가온다는', 1),
#  ('깨닫', 1),
#  ('시출', 1),
#  ('군진', 1),
#  ('친오빠', 1),
#  ('대문', 1),
#  ('싸이트', 1),
#  ('줄여야', 1),
#  ('약한', 1),
#  ('아르바이트', 1),
#  ('굳힌', 1),
#  ('좁쌀', 1),
#  ('뛰어다녔', 1),
#  ('위속', 1),
#  ('열받', 1),
#  ('이고', 1),
#  ('급할', 1),
#  ('케프', 1),
#  ('납치', 1),
#  ('시호', 1),
#  ('감안', 1),
#  ('내외', 1),
#  ('과자라', 1),
#  ('아닝', 1),
#  ('유승우', 1),
#  ('끝났으니', 1),
#  ('착함', 1),
#  ('내렸', 1),
#  ('직방', 1),
#  ('요마', 1),
#  ('덩그러', 1),
#  ('아까웠', 1),
#  ('공안', 1),
#  ('인도어', 1),
#  ('골퍼', 1),
#  ('한달전', 1),
#  ('오들리', 1),
#  ('음악회', 1),
#  ('아진', 1),
#  ('미연', 1),
#  ('두사', 1),
#  ('행운동', 1),
#  ('동거남', 1),
#  ('밀매', 1),
#  ('허벌나', 1),
#  ('탱이', 1),
#  ('거낭', 1),
#  ('읍지', 1),
#  ('드러누', 1),
#  ('생각난다', 1),
#  ('뻥쳤', 1),
#  ('파랑', 1),
#  ('해조류', 1),
#  ('어렸', 1),
#  ('담당', 1),
#  ('바쁠수록', 1),
#  ('지낸', 1),
#  ('유자차', 1),
#  ('버건', 1),
#  ('디네', 1),
#  ('세워볼까', 1),
#  ('일주일', 1),
#  ('온스', 1),
#  ('치오', 1),
#  ('단감', 1),
#  ('치명', 1),
#  ('수용성', 1),
#  ('물오른', 1),
#  ('예언', 1),
#  ('무거울', 1),
#  ('두봉', 1),
#  ('대다수', 1),
#  ('완두', 1),
#  ('쟁이', 1),
#  ('요골', 1),
#  ('따움', 1),
#  ('갈색', 1),
#  ('디엘', 1),
#  ('테디', 1),
#  ('딜리셔스', 1),
#  ('더페이스샵', 1),
#  ('아이라이너', 1),
#  ('죽상', 1),
#  ('붙였', 1),
#  ('사들임', 1),
#  ('정감', 1),
#  ('아라리', 1),
#  ('답글', 1),
#  ('시다', 1),
#  ('장땡', 1),
#  ('반하', 1),
#  ('허해', 1),
#  ('소원', 1),
#  ('요리왕', 1),
#  ('소키', 1),
#  ('접종', 1),
#  ('측정', 1),
#  ('픽셀', 1),
#  ('디스크', 1),
#  ('제견', 1),
#  ('피웠', 1),
#  ('고마어', 1),
#  ('메모홀더', 1),
#  ('마시멜로', 1),
#  ('잔디', 1),
#  ('라비앙', 1),
#  ('보르', 1),
#  ('아티바', 1),
#  ('스크림', 1),
#  ('미래인', 1),
#  ('달려감', 1),
#  ('부끄부끄', 1),
#  ('정아랑', 1),
#  ('초심자', 1),
#  ('계량', 1),
#  ('저만큼', 1),
#  ('작음', 1),
#  ('동래', 1),
#  ('동백', 1),
#  ('매스꺼워', 1),
#  ('스케치', 1),
#  ('된다던데', 1),
#  ('얌전', 1),
#  ('펜션', 1),
#  ('엠마오', 1),
#  ('갔다오', 1),
#  ('비즈니스', 1),
#  ('전쟁터', 1),
#  ('앙팡', 1),
#  ('짤려', 1),
#  ('놀랬', 1),
#  ('방판', 1),
#  ('려고', 1),
#  ('기뻤', 1),
#  ('노사', 1),
#  ('혈소판', 1),
#  ('응집', 1),
#  ('개개', 1),
#  ('피하', 1),
#  ('터진다는', 1),
#  ('칠갑', 1),
#  ('업과', 1),
#  ('보내오', 1),
#  ('신행', 1),
#  ('내리기', 1),
#  ('겉옷', 1),
#  ('고데', 1),
#  ('마스카라', 1),
#  ('도돌이표', 1),
#  ('그만두', 1),
#  ('요샌', 1),
#  ('어려운게', 1),
#  ('빠뜨리', 1),
#  ('클로이', 1),
#  ('구제', 1),
#  ('해유', 1),
#  ('살린다고', 1),
#  ('다주', 1),
#  ('두라', 1),
#  ('맡개', 1),
#  ('이웃집', 1),
#  ('민경', 1),
#  ('은빛', 1),
#  ('웃기', 1),
#  ('어린아이', 1),
#  ('오메기', 1),
#  ('담당자', 1),
#  ('심혈', 1),
#  ('기울여서', 1),
#  ('맛군', 1),
#  ('도라', 1),
#  ('지청', 1),
#  ('이빈스', 1),
#  ('권태기', 1),
#  ('싱기', 1),
#  ('아씨', 1),
#  ('김서', 1),
#  ('비법', 1),
#  ('넷플릭스', 1),
#  ('쌓여서', 1),
#  ('졸음', 1),
#  ('회제', 1),
#  ('청평', 1),
#  ('바나나보트', 1),
#  ('뿌린', 1),
#  ('태운', 1),
#  ('생신', 1),
#  ('마궁', 1),
#  ('사라다', 1),
#  ('옛날', 1),
#  ('깜짝이', 1),
#  ('방향제', 1),
#  ('풍겨', 1),
#  ('조증', 1),
#  ('보라', 1),
#  ('슈렉', 1),
#  ('박카스', 1),
#  ('내스', 1),
#  ('혜지', 1),
#  ('체크포인트', 1),
#  ('인삼', 1),
#  ('사포닌', 1),
#  ('한승연', 1),
#  ('댄서', 1),
#  ('노하우', 1),
#  ('관료', 1),
#  ('책정', 1),
#  ('배정', 1),
#  ('실하', 1),
#  ('슬러', 1),
#  ('공양미', 1),
#  ('갈려서', 1),
#  ('뒤적거리', 1),
#  ('헬로키티', 1),
#  ('저세상', 1),
#  ('적격', 1),
#  ('송준기', 1),
#  ('뛰미', 1),
#  ('딸렸', 1),
#  ('들어도', 1),
#  ('혈행', 1),
#  ('진과', 1),
#  ('낸다', 1),
#  ('편견', 1),
#  ('연습장', 1),
#  ('골프장', 1),
#  ('터로', 1),
#  ('나타난', 1),
#  ('진어', 1),
#  ('흑맥주', 1),
#  ('서연', 1),
#  ('직찍', 1),
#  ('메세지', 1),
#  ('문주', 1),
#  ('오리사', 1),
#  ('숨넘어가', 1),
#  ('정글', 1),
#  ('무트', 1),
#  ('눈떴', 1),
#  ('누적', 1),
#  ('박자', 1),
#  ('물놀이', 1),
#  ('무더운', 1),
#  ('죽사발', 1),
#  ('더워도', 1),
#  ('노화', 1),
#  ('불러요', 1),
#  ('찾아온', 1),
#  ('핸드백', 1),
#  ('이열치열', 1),
#  ('챙겨봅니다', 1),
#  ('수능', 1),
#  ('클러치', 1),
#  ('찔레', 1),
#  ('빈손', 1),
#  ('매거', 1),
#  ('추구', 1),
#  ('아라동', 1),
#  ('의존', 1),
#  ('호화', 1),
#  ('소피', 1),
#  ('렌디', 1),
#  ('긁어먹', 1),
#  ('포켓북', 1),
#  ('픽스', 1),
#  ('구독', 1),
#  ('입주', 1),
#  ('흘러가', 1),
#  ('잠투정', 1),
#  ('냈었', 1),
#  ('여겨', 1),
#  ('출발점', 1),
#  ('출간', 1),
#  ('실렸', 1),
#  ('벅찼', 1),
#  ('자작', 1),
#  ('북스', 1),
#  ('황성동', 1),
#  ('오스', 1),
#  ('체게바라', 1),
#  ('끝낼', 1),
#  ('써야지', 1),
#  ('고퀄', 1),
#  ('끊어치', 1),
#  ('더울', 1),
#  ('다스렸', 1),
#  ('잉태', 1),
#  ('다스리', 1),
#  ('매품', 1),
#  ('품고', 1),
#  ('백설탕', 1),
#  ('모래사장', 1),
#  ('빨간불', 1),
#  ('지니어', 1),
#  ('지니어스', 1),
#  ('정해진', 1),
#  ('남겼으니', 1),
#  ('유로', 1),
#  ('아토피', 1),
#  ('잠재워', 1),
#  ('생명수', 1),
#  ('탑재', 1),
#  ('퍼졌', 1),
#  ('안심살', 1),
#  ('리타', 1),
#  ('별다른', 1),
#  ('열나', 1),
#  ('부음', 1),
#  ('퍼펙트', 1),
#  ('떨리', 1),
#  ('시퀀스', 1),
#  ('위타', 1),
#  ('건국', 1),
#  ('울리', 1),
#  ('비닐', 1),
#  ('씌워', 1),
#  ('전도사', 1),
#  ('디모', 1),
#  ('벨로스터', 1),
#  ('든당', 1),
#  ('대령', 1),
#  ('이무라', 1),
#  ('투척', 1),
#  ('버켓', 1),
#  ('포대기', 1),
#  ('깨울', 1),
#  ('보칸', 1),
#  ('여라', 1),
#  ('귀욤', 1),
#  ('할미', 1),
#  ('노마', 1),
#  ('따라와요', 1),
#  ('판토텐산', 1),
#  ('찢어져서', 1),
#  ('세대', 1),
#  ('나아', 1),
#  ('앙꼬', 1),
#  ('래서', 1),
#  ('별류', 1),
#  ('지용', 1),
#  ('배속', 1),
#  ('탈락', 1),
#  ('임의', 1),
#  ('끌리', 1),
#  ('약해', 1),
#  ('인공감미료', 1),
#  ('자일리톨', 1),
#  ('개발자', 1),
#  ('넘침', 1),
#  ('당뇨', 1),
#  ('초식', 1),
#  ('동물', 1),
#  ('이럼', 1),
#  ('노바', 1),
#  ('렉스', 1),
#  ('코로', 1),
#  ('주중', 1),
#  ('대조', 1),
#  ('비비드', 1),
#  ('와이어', 1),
#  ('마련', 1),
#  ('못가', 1),
#  ('현미빵', 1),
#  ('다이앙', 1),
#  ('뿌셔뿌셔', 1),
#  ('될지', 1),
#  ('후자', 1),
#  ('버거킹', 1),
#  ('꺼리', 1),
#  ('무너진', 1),
#  ('푸리', 1),
#  ('버틀', 1),
#  ('리안', 1),
#  ('찜질방', 1),
#  ('과외', 1),
#  ('학부모', 1),
#  ('마이네', 1),
#  ('방점', 1),
#  ('매머드', 1),
#  ('약한가', 1),
#  ('커트', 1),
#  ('사절', 1),
#  ('장마비', 1),
#  ('비시', 1),
#  ('스트로베리', 1),
#  ('우주정거장', 1),
#  ('앞서', 1),
#  ('파오', 1),
#  ('둔건', 1),
#  ('넘긴', 1),
#  ('다반사', 1),
#  ('가운데', 1),
#  ('변하', 1),
#  ('페티쉬', 1),
#  ('그른가', 1),
#  ('듣보잡', 1),
#  ('허덕일', 1),
#  ('베어', 1),
#  ('가득찬', 1),
#  ('몰라서', 1),
#  ('요청', 1),
#  ('정확', 1),
#  ('의견', 1),
#  ('오뉴월', 1),
#  ('걸린다는', 1),
#  ('겹쳐', 1),
#  ('강비', 1),
#  ('할꺼', 1),
#  ('돌산', 1),
#  ('쓰러졌었', 1),
#  ('열기', 1),
#  ('알려준', 1),
#  ('어려워요', 1),
#  ('다시', 1),
#  ('꺼지', 1),
#  ('예민', 1),
#  ('북치', 1),
#  ('슬로건', 1),
#  ('살펴보', 1),
#  ('모양새', 1),
#  ('요란', 1),
#  ('루나', 1),
#  ('하이얀', 1),
#  ('이쁠', 1),
#  ('마이보', 1),
#  ('당줄', 1),
#  ('개지', 1),
#  ('죽여버려', 1),
#  ('긍가', 1),
#  ('디종', 1),
#  ('염분', 1),
#  ('맴돌', 1),
#  ('워치', 1),
#  ('구할', 1),
#  ('볼루', 1),
#  ('구우', 1),
#  ('깍둑썰기', 1),
#  ('건포', 1),
#  ('앞둔', 1),
#  ('간헐', 1),
#  ('반반', 1),
#  ('이런', 1),
#  ('스쿱', 1),
#  ('손잡', 1),
#  ('마을버스', 1),
#  ('정하', 1),
#  ('부실', 1),
#  ('배울', 1),
#  ('어답터', 1),
#  ('모름', 1),
#  ('홍초', 1),
#  ('프로도', 1),
#  ('어울린다', 1),
#  ('성북동', 1),
#  ('싸이드', 1),
#  ('가난', 1),
#  ('슬로베니아', 1),
#  ('봅시다', 1),
#  ('어게인', 1),
#  ('은화', 1),
#  ('수식', 1),
#  ('테라스', 1),
#  ('취해', 1),
#  ('선데이', 1),
#  ('훌라후프', 1),
#  ('박봄', 1),
#  ('악세사리', 1),
#  ('동대문', 1),
#  ('녹양역', 1),
#  ('중국인', 1),
#  ('아리아', 1),
#  ('청계천', 1),
#  ('난무', 1),
#  ('팔찌', 1),
#  ('미니어처', 1),
#  ('보중', 1),
#  ('부리기', 1),
#  ('숙주', 1),
#  ('실성', 1),
#  ('면회', 1),
#  ('닭튀김', 1),
#  ('네드', 1),
#  ('가피자', 1),
#  ('로이드', 1),
#  ('진영', 1),
#  ('고강', 1),
#  ('세유', 1),
#  ('덴마크인', 1),
#  ('탕가', 1),
#  ('허락', 1),
#  ('무서웠', 1),
#  ('마이에', 1),
#  ('더우', 1),
#  ('부스러기', 1),
#  ('내보', 1),
#  ('무거워서', 1),
#  ('정시', 1),
#  ('들여다', 1),
#  ('말즘', 1),
#  ('방구석', 1),
#  ('미드', 1),
#  ('따라온', 1),
#  ('데모', 1),
#  ('터질까', 1),
#  ('혹사', 1),
#  ('철벽', 1),
#  ('나타날', 1),
#  ('로딩', 1),
#  ('낯설', 1),
#  ('남겨뒀', 1),
#  ('위시', 1),
#  ('방배', 1),
#  ('정적', 1),
#  ('미끼', 1),
#  ('놔둬', 1),
#  ('휴지통', 1),
#  ('칠레', 1),
#  ('그리울', 1),
#  ('그리움', 1),
#  ('진수성찬', 1),
#  ('버팀', 1),
#  ('훔쳐', 1),
#  ('카테', 1),
#  ('고라', 1),
#  ('맞이해', 1),
#  ('감춘', 1),
#  ('우연', 1),
#  ('흘렀', 1),
#  ('속상한', 1),
#  ('수압', 1),
#  ('상죽', 1),
#  ('보네', 1),
#  ('너도', 1),
#  ('빨리', 1),
#  ('안드로메다', 1),
#  ('알지', 1),
#  ('여의치', 1),
#  ('잠시', 1),
#  ('가져와서', 1),
#  ('말썽', 1),
#  ('망가지', 1),
#  ('장량', 1),
#  ('질량', 1),
#  ('소보', 1),
#  ('일으킬', 1),
#  ('여사원', 1),
#  ('보감', 1),
#  ('반애', 1),
#  ('진리', 1),
#  ('물리', 1),
#  ('처방전', 1),
#  ('날라서', 1),
#  ('끌려', 1),
#  ('오심', 1),
#  ('여쭤', 1),
#  ('여신', 1),
#  ('일어날', 1),
#  ('한수', 1),
#  ('집히', 1),
#  ('주먹', 1),
#  ('도그', 1),
#  ('바가지', 1),
#  ('폴리', 1),
#  ('여잔', 1),
#  ('폴리나', 1),
#  ('두껍', 1),
#  ('달고', 1),
#  ('달덩이', 1),
#  ('혼나', 1),
#  ('해봐요', 1),
#  ('날라리', 1),
#  ('루이스', 1),
#  ('인해서', 1),
#  ('회장', 1),
#  ('일하', 1),
#  ('담궈서', 1),
#  ('데운', 1),
#  ('니홀드', 1),
#  ('수리', 1),
#  ('물시', 1),
#  ('화면', 1),
#  ('됐었', 1),
#  ('전공', 1),
#  ('채택', 1),
#  ('뽑혔', 1),
#  ('갖춰져', 1),
#  ('식목일', 1),
#  ('선인장', 1),
#  ('데려오', 1),
#  ('다육', 1),
#  ('요키', 1),
#  ('디보', 1),
#  ('보인다며', 1),
#  ('마십', 1),
#  ('다빈', 1),
#  ('낮춰', 1),
#  ('여전', 1),
#  ('그미', 1),
#  ('살려줘', 1),
#  ('제네시스', 1),
#  ('쿠페', 1),
#  ('트윈', 1),
#  ('블로우', 1),
#  ('밸브', 1),
#  ('미드나잇', 1),
#  ('브러시', 1),
#  ('이수미', 1),
#  ('권선영', 1),
#  ('수미', 1),
#  ('부원장', 1),
#  ('이성애자', 1),
#  ('이노', 1),
#  ('훈육', 1),
#  ('늘어져', 1),
#  ('가져간', 1),
#  ('무경', 1),
#  ('선보이', 1),
#  ('엉클', 1),
#  ('완자', 1),
#  ('취만', 1),
#  ('포커', 1),
#  ('송한', 1),
#  ('지속력', 1),
#  ('슬아', 1),
#  ('군하', 1),
#  ('시동', 1),
#  ('작동', 1),
#  ('깨우침', 1),
#  ('시험장', 1),
#  ('응시', 1),
#  ('면허', 1),
#  ('닙시', 1),
#  ('구동', 1),
#  ('기달려', 1),
#  ('공산품', 1),
#  ('빠져나가', 1),
#  ('요로', 1),
#  ('원했', 1),
#  ('록키', 1),
#  ('때늦', 1),
#  ('예산', 1),
#  ('정돈', 1),
#  ('블루아', 1),
#  ('브룩', 1),
#  ('아들딸', 1),
#  ('번가', 1),
#  ('제것은', 1),
#  ('분실', 1),
#  ('구세주', 1),
#  ('사계절', 1),
#  ('변치', 1),
#  ('준우', 1),
#  ('양쪽', 1),
#  ('제눈에', 1),
#  ('근린공원', 1),
#  ('시차', 1),
#  ('주라쿠', 1),
#  ('빠진다는', 1),
#  ('모올', 1),
#  ('날아갔', 1),
#  ('포토샵', 1),
#  ('하규', 1),
#  ('올게', 1),
#  ('반겨', 1),
#  ('때워', 1),
#  ('트릭스', 1),
#  ('센슈', 1),
#  ('더스트', 1),
#  ('엔디', 1),
#  ('묻혀', 1),
#  ('채워준다', 1),
#  ('프라이밍', 1),
#  ('트리트', 1),
#  ('안쪽', 1),
#  ('덧발라', 1),
#  ('성숙', 1),
#  ('허허', 1),
#  ('랬으나', 1),
#  ('내줬', 1),
#  ('비운', 1),
#  ('참말', 1),
#  ('버블', 1),
#  ('색칠', 1),
#  ('품평', 1),
#  ('달한', 1),
#  ('밝혀', 1),
#  ('샤랄', 1),
#  ('스킵', 1),
#  ('주가', 1),
#  ('건주', 1),
#  ('덧바르', 1),
#  ('드랑', 1),
#  ('포샤', 1),
#  ('튜토리얼', 1),
#  ('머뭇거렸', 1),
#  ('떨어질까봐', 1),
#  ('쓸려고', 1),
#  ('밀착', 1),
#  ('진합', 1),
#  ('세미', 1),
#  ('하이브리드', 1),
#  ('단디', 1),
#  ('치인', 1),
#  ('조앙', 1),
#  ('낀데', 1),
#  ('배틀', 1),
#  ('두려워', 1),
#  ('꺼이', 1),
#  ('마구잡이', 1),
#  ('열자', 1),
#  ('즐거워', 1),
#  ('위통', 1),
#  ('찢어질', 1),
#  ('인계', 1),
#  ('지으러', 1),
#  ('한눈', 1),
#  ('온데', 1),
#  ('아셨', 1),
#  ('와나', 1),
#  ('죽염', 1),
#  ('제목', 1),
#  ('해쥬', 1),
#  ('먹칼', 1),
#  ('빨라서', 1),
#  ('순심', 1),
#  ('영주', 1),
#  ('시골', 1),
#  ('코위', 1),
#  ('닫혀', 1),
#  ('제방', 1),
#  ('온도', 1),
#  ('시피', 1),
#  ('나베이', 1),
#  ('샌즈', 1),
#  ('모터', 1),
#  ('비안코', 1),
#  ('시저', 1),
#  ('크램', 1),
#  ('파열', 1),
#  ('정품', 1),
#  ('참기', 1),
#  ('난이도', 1),
#  ('최상', 1),
#  ('갈거라', 1),
#  ('무너졌', 1),
#  ('핀티', 1),
#  ('딸라', 1),
#  ('니버', 1),
#  ('걸죽한', 1),
#  ('시에나', 1),
#  ('탄두리', 1),
#  ('느타리버섯', 1),
#  ('풋고추', 1),
#  ('온다고', 1),
#  ('먹였', 1),
#  ('카인드', 1),
#  ('저녁때', 1),
#  ('사연', 1),
#  ('안기', 1),
#  ('대흥동', 1),
#  ('적성', 1),
#  ('마샤', 1),
#  ('측면', 1),
#  ('뜨신', 1),
#  ('용동', 1),
#  ('무효', 1),
#  ('터질', 1),
#  ('코차', 1),
#  ('마비', 1),
#  ('빌렸', 1),
#  ('실리', 1),
#  ('선입', 1),
#  ('선출', 1),
#  ('이름표', 1),
#  ('앞이', 1),
#  ('벌리', 1),
#  ('먹인', 1),
#  ('편한데', 1),
#  ('다를', 1),
#  ('바쁜지', 1),
#  ('모았', 1),
#  ('승준', 1),
#  ('입감', 1),
#  ('한술', 1),
#  ('쏘울', 1),
#  ('프렌치토스트', 1),
#  ('프렌치', 1),
#  ('고냥', 1),
#  ('보내온', 1),
#  ('벗기', 1),
#  ('전해져', 1),
#  ('엘모', 1),
#  ('블랭킷', 1),
#  ('자괴', 1),
#  ('망해서', 1),
#  ('달걀흰자', 1),
#  ('앙고라', 1),
#  ('양모', 1),
#  ('목도리', 1),
#  ('패스트', 1),
#  ('이즈', 1),
#  ('스토', 1),
#  ('후두', 1),
#  ('신경통', 1),
#  ('다닌다는', 1),
#  ('스포츠센터', 1),
#  ('조거', 1),
#  ('지후', 1),
#  ('유노', 1),
#  ('댄다', 1),
#  ('장갑', 1),
#  ('타정', 1),
#  ('갈지', 1),
#  ('오르내리', 1),
#  ('가유', 1),
#  ('귀여웠', 1),
#  ('폴바셋', 1),
#  ('여잔데', 1),
#  ('원뿔', 1),
#  ('리콜', 1),
#  ('황금사과', 1),
#  ('앤로즈', 1),
#  ('무맛', 1),
#  ('찻잔', 1),
#  ('두려운', 1),
#  ('생김', 1),
#  ('따가웠', 1),
#  ('이표', 1),
#  ('다져서', 1),
#  ('뱅스', 1),
#  ('빈틈없', 1),
#  ('터져요', 1),
#  ('카루', 1),
#  ('셀리', 1),
#  ('큐티', 1),
#  ('사워크림', 1),
#  ('오리털', 1),
#  ('벙어리장갑', 1),
#  ('얼티밋', 1),
#  ('이어폰', 1),
#  ('현경', 1),
#  ('귀신', 1),
#  ('빨강', 1),
#  ('루돌프', 1),
#  ('데려와서', 1),
#  ('놔두', 1),
#  ('즐거우', 1),
#  ('실려', 1),
#  ('볼거리', 1),
#  ('응답', 1),
#  ('용이', 1),
#  ('생겼어요', 1),
#  ('무포', 1),
#  ('터드', 1),
#  ('몰라볼', 1),
#  ('더치', 1),
#  ('낮술', 1),
#  ('통팥', 1),
#  ('내츄럴', 1),
#  ('코스터', 1),
#  ('금치', 1),
#  ('양념장', 1),
#  ('상해서', 1),
#  ('시금', 1),
#  ('치국', 1),
#  ('레스토랑', 1),
#  ('꾸려', 1),
#  ('둘째치', 1),
#  ('용팔이', 1),
#  ('로바트', 1),
#  ('양가', 1),
#  ('전투력', 1),
#  ('기자단', 1),
#  ('수료증', 1),
#  ('모스', 1),
#  ('형식', 1),
#  ('여요', 1),
#  ('빌보', 1),
#  ('빌레', 1),
#  ('보흐', 1),
#  ('웨이브', 1),
#  ('캐릭터', 1),
#  ('찰리', 1),
#  ('산야초', 1),
#  ('마멀레이드', 1),
#  ('게으름뱅이', 1),
#  ('할렐루야', 1),
#  ('나와도', 1),
#  ('안겨', 1),
#  ('드시', 1),
#  ('상승', 1),
#  ('아스파라거스', 1),
#  ('찐만두', 1),
#  ('모였', 1),
#  ('진열장', 1),
#  ('걸릴', 1),
#  ('다구', 1),
#  ('이중', 1),
#  ('마리네', 1),
#  ('이드', 1),
#  ('꺼렸', 1),
#  ('보존제', 1),
#  ('나을', 1),
#  ('물결', 1),
#  ('노른', 1),
#  ('다녀요', 1),
#  ('그런가요', 1),
#  ('식단표', 1),
#  ('까맣', 1),
#  ('그중', 1),
#  ('콤플렉스', 1),
#  ('엘레', 1),
#  ('이터', 1),
#  ('공사', 1),
#  ('최종', 1),
#  ('주예', 1),
#  ('고파도', 1),
#  ('너스', 1),
#  ('케이브', 1),
#  ('낭한', 1),
#  ('부마', 1),
#  ('시름', 1),
#  ('관둬', 1),
#  ('안목', 1),
#  ('텀블벅', 1),
#  ('올립니다', 1),
#  ('고용', 1),
#  ('차별', 1),
#  ('두꺼웠', 1),
#  ('대추야자', 1),
#  ('설렌다', 1),
#  ('자요', 1),
#  ('무염식', 1),
#  ('린지', 1),
#  ('마버', 1),
#  ('예랑', 1),
#  ('이밥', 1),
#  ('채전', 1),
#  ('더덕', 1),
#  ('동그랑땡', 1),
#  ('헤즐', 1),
#  ('요색', 1),
#  ('묵히', 1),
#  ('조코', 1),
#  ('한계', 1),
#  ('쥐포', 1),
#  ('초절임', 1),
#  ('물부추', 1),
#  ('하네', 1),
#  ('왕비', 1),
#  ('뒤처리', 1),
#  ('부동', 1),
#  ('코딱지', 1),
#  ('저러', 1),
#  ('손톱', 1),
#  ('지롱', 1),
#  ('싱글', 1),
#  ('죽계', 1),
#  ('첫걸음', 1),
#  ('일기장', 1),
#  ('모기', 1),
#  ('개새끼', 1),
#  ('엄선', 1),
#  ('올래', 1),
#  ('로스팅', 1),
#  ('이루어진', 1),
#  ('간담회', 1),
#  ('생색', 1),
#  ('칫솔', 1),
#  ('갈망', 1),
#  ('비위', 1),
#  ('거품', 1),
#  ('연평해전', 1),
#  ('싫어해서', 1),
#  ('그랬었', 1),
#  ('기다려져', 1),
#  ('내사랑', 1),
#  ('마셔요', 1),
#  ('불태워', 1),
#  ('애서', 1),
#  ('졸고', 1),
#  ('발톱', 1),
#  ('대매', 1),
#  ('어울릴', 1),
#  ('히말라야', 1),
#  ('마이신', 1),
#  ('작렬', 1),
#  ('강레오', 1),
#  ('레이먼킴', 1),
#  ('샘킴', 1),
#  ('플랩', 1),
#  ('우가', 1),
#  ('투르', 1),
#  ('곁들이', 1),
#  ('다가올수록', 1),
#  ('타나', 1),
#  ('아퀴노', 1),
#  ('호랑이', 1),
#  ('마드', 1),
#  ('애비', 1),
#  ('들어올', 1),
#  ('도부어', 1),
#  ('나아진', 1),
#  ('규주', 1),
#  ('컨트리', 1),
#  ('가져갈', 1),
#  ('질소', 1),
#  ('무질소', 1),
#  ('재규어', 1),
#  ('한덩', 1),
#  ('찌게', 1),
#  ('교보문고', 1),
#  ('하임', 1),
#  ('시빅', 1),
#  ('버나비', 1),
#  ('복장', 1)]

# %%
intake.nav_joined = intake.join_list(intake.nav_list)

# %%
intake.LDA = SB_LDA()
intake.LDA.make_lda(intake.nav_joined, ntopic=5, learning_method='batch', max_iter=25, random_state=0, n_words=20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-cb676e8c7d53> in <module>()
#       1 intake.LDA = SB_LDA()
# ----> 2 intake.LDA.make_lda(intake.nav_joined, ntopic=5, learning_method='batch', max_iter=25, random_state=0, n_words=20)
#
# AttributeError: 'Social_analysis' object has no attribute 'nav_joined'

# %%
def add_dictionary(*tokenized_list):
    origin_df = 1
    try:
        origin_df = pd.read_csv("C:\\mecab\\user-dic\\intake_dic.csv", encoding='utf-8', header=None)
    except:
        print('No default intake_dic')
    keyword_list = []   
    for i in tokenized_list:
        if type(i) == list:
            for j in i:
                j = j.split('_')
                temp = [j[0],'' ,'' ,'' ,j[1],'',j[2], j[3],'*','*','*','*']
                keyword_list.append(temp)
        else:
            i = i.split('_')
            temp = [i[0],'','','',i[1],'',i[2], i[3], '*','*','*','*']
            keyword_list.append(temp)


    keyword_df = pd.DataFrame(keyword_list)
    print(type(origin_df))
    if type(origin_df) != int:
        keyword_df = pd.concat((origin_df, keyword_df), ignore_index=True)
    else: 
        print('a')
        pass
    print(keyword_df.shape)

    keyword_df.to_csv("C:\\mecab\\user-dic\\intake_dic.csv", encoding='utf-8',index=None, header=False)

# %%
import pandas as pd
add_dictionary('인테이크_NNP_F_인테이크')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (66, 13)

# %% [markdown]
# 단어_태그_T/F(받침여부)_원단어의발음

# %%
keyword_dic = '''모닝죽,,,,NNG,*,T,모닝죽,*,*,*,*,*
인테이크,,,,NNG,*,F,인테이크,*,*,*,*,*
꿀고구마,,,,NNG,*,F,꿀고구마,*,*,*,*,*
한끼,,,,NNG,*,F,한끼,*,*,*,*,*
밀스라이트,,,,NNG,*,F,밀스라이트,*,*,*,*,*
식단인증,,,,NNG,*,F,식단인증,*,*,*,*,*
직장인,,,,NNG,*,T,직장인,*,*,*,*,*
스타그램,,,,NNG,*,T,스타그램,*,*,*,*,*
귀리우유,,,,NNG,*,F,귀리우유,*,*,*,*,*
텐바이텐,,,,NNG,*,T,텐바이텐,*,*,*,*,*
텐텐쇼퍼,,,,NNG,*,F,텐텐쇼퍼,*,*,*,*,*
간편식,,,,NNG,*,T,간편식,*,*,*,*,*
1일1식,,,,NNG,*,T,1일1식,*,*,*,*,*
카페라떼,,,,NNG,*,F,카페라떼,*,*,*,*,*
벨벳초콜렛,,,,NNG,*,T,벨벳초콜렛,*,*,*,*,*
혼밥,,,,NNG,*,T,혼밥,*,*,*,*,*
곤약현미밥,,,,NNG,*,T,곤약현미밥,*,*,*,*,*
버터치킨커리,,,,NNG,*,F,버터치킨커리,*,*,*,*,*
유지어터,,,,NNG,*,F,유지어터,*,*,*,*,*
치킨커리,,,,NNG,*,F,치킨커리,*,*,*,*,*
버터치킨,,,,NNG,*,F,버터치킨,*,*,*,*,*
밀스칩,,,,NNG,*,T,밀스칩,*,*,*,*,*
미래지향,,,,NNG,*,F,미래지향,*,*,*,*,*
유통기한,,,,NNG,*,T,유통기한,*,*,*,*,*
고농축,,,,NNG,*,T,고농축,*,*,*,*,*
단백질,,,,NNG,*,T,단백질,*,*,*,*,*
밀스드링크딸기,,,,NNG,*,F,밀스드링크딸기,*,*,*,*,*
프레시모닝,,,,NNG,*,T,프레시모닝,*,*,*,*,*
대체,,,,NNG,*,F,대체,*,*,*,*,*
클랜즈,,,,NNG,*,F,클랜즈,*,*,*,*,*
와디즈,,,,NNG,*,F,와디즈,*,*,*,*,*
얼리버드,,,,NNG,*,F,얼리버드,*,*,*,*,*
까페라떼,,,,NNG,*,F,까페라떼,*,*,*,*,*
로얄밀크티,,,,NNG,*,F,로얄밀크티,*,*,*,*,*
곤약젤리,,,,NNG,*,F,곤약젤리,*,*,*,*,*
모닝채소,,,,NNG,*,F,모닝채소,*,*,*,*,*
콜드프레스,,,,NNG,*,F,콜드프레스,*,*,*,*,*
하루야채,,,,NNG,*,F,하루야채,*,*,*,*,*
씨리얼,,,,NNG,*,T,씨리얼,*,*,*,*,*
콜드부르,,,,NNG,*,F,콜드부르,*,*,*,*,*
스타벅스,,,,NNG,*,F,스타벅스,*,*,*,*,*
밀스드링크,,,,NNG,*,F,밀스드링크,*,*,*,*,*
존맛,,,,VA,*,T,존맛,*,*,*,*,*
아워홈,,,,NNG,*,T,아워홈,*,*,*,*,*
모닝바게트,,,,NNG,*,F,모닝바게트,*,*,*,*,*
모닝귀리,,,,NNG,*,F,모닝귀리,*,*,*,*,*
스윗그레인,,,,NNG,*,T,스윗그레인,*,*,*,*,*
그릭요거트,,,,NNG,*,F,그릭요거트,*,*,*,*,*
팥톡스,,,,NNG,*,F,팥톡스,*,*,*,*,*
식이섬유,,,,NNG,*,F,식이섬유,*,*,*,*,*
베지밀,,,,NNG,*,T,베지밀,*,*,*,*,*
그레인하프,,,,NNG,*,F,그레인하프,*,*,*,*,*
코코넛하프,,,,NNG,*,F,코코넛하프,*,*,*,*,*
식이조절,,,,NNG,*,T,식이조절,*,*,*,*,*
줌마,,,,NNG,*,F,줌마,*,*,*,*,*
매일유업,,,,NNG,*,T,매일유업,*,*,*,*,*
볶음콩,,,,NNG,*,T,볶음콩,*,*,*,*,*
상하목장,,,,NNG,*,T,상하목장,*,*,*,*,*
요거트,,,,NNG,*,F,요거트,*,*,*,*,*
카카오닙스,,,,NNG,*,F,카카오닙스,*,*,*,*,*
잇클린,,,,NNG,*,T,잇클린,*,*,*,*,*
카페다이어트,,,,NNG,*,F,카페다이어트,*,*,*,*,*
사과맛워터젤리,,,,NNG,*,F,사과맛워터젤리,*,*,*,*,*
맛있는다이어트칩,,,,NNG,*,T,맛있는다이어트칩,*,*,*,*,*
다이어트칩,,,,NNG,*,T,다이어트칩,*,*,*,*,*'''.split('\n')

# %%
for idx, i in enumerate(keyword_dic):
    keyword_dic[idx] = i.split(',')

# %%
pd.DataFrame(keyword_dic).to_csv('c:\\mecab\\user-dic\\intake_dic.csv', encoding='utf-8', index=None, header=False)

# %%
keyword_list = []

# %%
for idx in range(len(intake.morph_list)):
    idx = -idx-1
    print(intake.morph_list[idx])
    print(intake.modified[idx, 2])
    print(idx)
    k = input()    
    while k:
        keyword_list.append(k)
        k = input()
        if k == 'break' or k == 'next':
            break
    if k == 'break':
        break
# Out:
# ['시장_NNG', '바_NNB', '잉가_VCP+EC', '는_JX', '쌀쌀_XR', '한_XSA+ETM', '아침_NNG', '에_JKB', '는_JX', '속_NNG', '든든_XR', '하_XSA', '게_EC', '챙겨_VV+EC', '먹_VV', '고_EC', '빠샤_IC', '예쁜_VA+ETM', '거_NNB', '한_MM', '트럭_NNBC', '실_VV', '어_EC', '와야_VX+EC+VX', '지_EF', '빅_NNP', '사이즈_NNP', '여성_NNG', '의류_NNG', '인테이크_NNG', '모닝죽_NNG', '단호박_NNG', '죽_MAG', '냠냠_MAG', '데일리_NNP', '룩_NNP']
# by_skshin시장 바잉가는 쌀쌀한  아침 에는
# 속 든든하게 챙겨먹고  빠샤 ��
# 예쁜거 한트럭 실어와야지:) *  빅사이즈여성의류
#  인테이크  모닝죽  단호박죽  냠냠  데일리룩
#  daily  shoes  cute  yammy  fur
# -99
#
# ['은_JX', '뇨_VCP+EF', '의_JKG', '점심_NNG', '바나나_NNG', '한_MM', '개_NNBC', '와_JKB', '인테이크_NNG', '일_NNBC', '넛_NNP']
# workout_byeun은뇨의점심��
#  바나나 한개와  인테이크 1일1넛
# -100
#
# ['저녁_NNG', '식사_NNG', '뻔_NNB', '녀_NNG', '일_NNBC', '식단_NNG', '프로그램_NNG', '일_NNBC', '차_NNG', '뻔_NNB', '녀_NNG', '건강_NNG', '스무디_NNP', '그린_VV+ETM', '스무디_NNP', '레몬_NNG', '바나나_NNG', '사과_NNG', '근대_NNG', '케일_NNG', '물_NNG', '컵_NNG', '인테이크_NNG', '씨_NNG', '즈_XSN', '쓰리_NR', '아마_MAG', '씨드_NNP', '바질_NNP', '씨드_NNP', '치아_NNG', '씨드_NNP', '우_VV', '히_EC', '월요일_NNG', '이_JKS', '끝_NNG', '나가_VV', '네요_EF', '이번_NNG', '주도_NNG', '휘리_NNG', '릭_NNG', '지나갈_VV+ETM', '것_NNB', '같_VA', '은_ETM', '느낌_NNG', '지난번_NNG', '에_JKB', '중요_NNG', '한_XSA+ETM', '결과_NNG', '발표_NNG', '있_VV', '다고_EC', '했었_VX+EP', '죠_EF', '그때_NNG', '차_NNBC', '는_JX', '통과_NNG', '했_XSV+EP', '구_EC', '이제_MAG', '마지막_NNG', '차_NNBC', '최종_NNG', '발표_NNG', '가_JKS', '이번_NNG', '주예_NNG', '요_JX', '두근두근_MAG', '좋_VA', '은_ETM', '결과_NNG', '가_JKS', '있_VV', '길_ETN+JKO', '비오_NNG', '는_JX', '밤_NNG', '즐거운_VA+ETM', '저녁_NNG', '보내_VV', '세요_EP+EF', '다이어트_NNG', '그램_NNG', '다이어트_NNG', '식단_NNG', '식단_NNG', '기록_NNG', '식단_NNG', '일지_VCP+EC', '식단_NNG', '홈_NNG', '쿡_MAG', '식단_NNG', '조절_NNG', '다노_NNP', '뻔_NNB', '녀_NNG', '요리_NNG', '스타그램_NNG', '쿡_MAG', '스타그램_NNG', '플레이_NNG', '팅_IC', '다이어터_NNP', '맞_XPN', '팔_NNG', '소통_NNG', '환영_NNG']
# yoo.hana517.
# �Diet +482�
# 20151116 저녁식사 � .
# .
# .
# .
# .
#  뻔녀5일식단프로그램 1일차
#  뻔녀_건강스무디  그린스무디
# ➡️ 레몬 1/2 바나나1 사과1/2 근대2 케일5 물1컵
# ➡️  인테이크  씨즈쓰리 아마씨드&바질씨드&치아씨드
# .
# .
# 우히 월요일이 끝나가네요!
# 이번주도 휘리릭 지나갈 것 같은 느낌!
# 지난번에 중요한 결과 발표 있다고 했었죠!
# 그때 2차는 통과했구 이제 마지막 3차 최종발표가
# 이번주예요 두근두근 좋은 결과가 있길�
# 비오는 밤! 즐거운 저녁 보내세요�
# .
# .
#  다이어트그램  diet  다이어트식단
#  식단기록  식단일지  식단  dietfood
#  홈쿡  식단조절  다노  DANO  뻔녀
#  요리스타그램  쿡스타그램  플레이팅
#  다이어터_맞팔_소통_환영 ��
# -101
#
# ['저녁_NNG', '식사_NNG', '뻔_NNB', '녀_NNG', '일_NNBC', '식단_NNG', '프로그램_NNG', '일_NNBC', '차_NNG', '뻔_NNB', '녀_NNG', '건강_NNG', '스무디_NNP', '그린_VV+ETM', '스무디_NNP', '레몬_NNG', '바나나_NNG', '블루베리_NNG', '컵_NNG', '근대_NNG', '케일_NNG', '물_NNG', '컵_NNG', '인테이크_NNG', '씨_NNG', '즈_XSN', '쓰리_NR', '아마_MAG', '씨드_NNP', '바질_NNP', '씨드_NNP', '치아_NNG', '씨드_NNP', '블루베리_NNG', '때문_NNB', '에_JKB', '까맣_VA', '지만_EC', '그린_VV+ETM', '스무디_NNP', '입니다_VCP+EF', '와우_IC', '오늘_MAG', '택배_NNG', '가_JKS', '개_NNBC', '나_JX', '그중_NNG', '이벤트_NNG', '택배_NNG', '개_NNBC', '이_NR', '뿌_VX', '게_EC', '찍_VV', '어서_EC', '후기_NNG', '써야_VV+EC+VX', '겠_EP', '다_EC', '저_IC', '오늘_MAG', '기분_NNG', '좋_VA', '아요_EF', '제_NP', '가_JKS', '하체_NNG', '튼튼_XR', '이_VCP', '라_EC', '콤플렉스_NNG', '거든요_VCP+EC', '근데_MAJ', '요즘_MAG', '엄마_NNG', '도_JX', '이모_NNG', '도_JX', '엉덩이_NNG', '랑_JKB', '하체_NNG', '쪽_NNB', '이_JKS', '많이_MAG', '빠진_VV+ETM', '것_NNB', '같_VA', '다고_EC', '했_VX+EP', '는데_EC', '직장_NNG', '동료_NNG', '쌤_NNG', '께서_JKS', '도_JX', '요즘_MAG', '하체_NNG', '빠진_VV+ETM', '것_NNB', '같_VA', '다며_EF', '꺄_UNKNOWN', '기분_NNG', '조아_NNG', '엘레_NNG', '베_NNG', '이터_NNP', '교체_NNG', '로_JKB', '강제_NNG', '층_NNG', '계단_NNG', '오르_VV', '기_ETN', '덕분_NNG', '일까요_VCP+EF', 'ㅋ_IC', '이러면_MAJ', '안_MAG', '되_VV', '는데_EC', 'ㅋㅋ_IC', '교체_NNG', '공사_NNG', '끝_NNG', '나_NP', '도_JX', '계단_NNG', '올라가_VV', '기_ETN', '해야_VV+EC', '하_VV', '나_EC', '싶_VX', '네요_EC', '인친_NNG', '님_XSN', '들_XSN', '즐거운_VA+ETM', '저녁_NNG', '보내_VV', '세요_EP+EF', '다이어트_NNG', '그램_NNG', '다이어트_NNG', '식단_NNG', '식단_NNG', '기록_NNG', '식단_NNG', '일지_VCP+EC', '식단_NNG', '홈_NNG', '쿡_MAG', '식단_NNG', '조절_NNG', '다노_NNP', '뻔_NNB', '녀_NNG', '요리_NNG', '스타그램_NNG', '쿡_MAG', '스타그램_NNG', '플레이_NNG', '팅_IC', '다이어터_NNP', '맞_XPN', '팔_NNG', '소통_NNG', '환영_NNG']
# yoo.hana517.
# �Diet +483�
# 20151117 저녁식사 � .
# .
# .
# .
# .
#  뻔녀5일식단프로그램 2일차
#  뻔녀_건강스무디  그린스무디
# ➡️ 레몬 1/2 바나나1 블루베리1/2컵 근대2 케일5 물1컵
# ➡️  인테이크  씨즈쓰리 아마씨드&바질씨드&치아씨드
# ➡️ 블루베리때문에 까맣지만  그린스무디 입니다!
# .
# .
# 와우 오늘 택배가 7개나..그중 이벤트택배 4개
# 이뿌게 찍어서 후기 써야겠다�
# 저 오늘 기분 좋아요!!
# 제가 하체 튼튼이라 콤플렉스거든요�
# 근데 요즘 엄마도 이모도 엉덩이랑 하체쪽이
# 많이 빠진 것 같다고 했는데! 직장동료쌤께서도
# 요즘 하체 빠진것 같다며! 꺄 기분 조아♥️
# 엘레베이터 교체로  강제_15층_계단오르기 덕분일까요?ㅋ
# 이러면 안되는데...ㅋㅋ 교체공사 끝나도 계단올라가기 해야하나 싶네요 ���
# 인친님들♥️♥️♥️♥️♥️♥️
# 즐거운 저녁 보내세요�
# .
# .
#  다이어트그램  diet  다이어트식단
#  식단기록  식단일지  식단  dietfood
#  홈쿡  식단조절  다노  DANO  뻔녀
#  요리스타그램  쿡스타그램  플레이팅
#  다이어터_맞팔_소통_환영 ��
# -102
#
# ['넘_MAG', '마음_NNG', '에_JKB', '드_VV', '는_ETM', '집들이_NNG', '선물_NNG', '집들이_NNG', '선물_NNG', '조미료_NNG', '조미료_NNG', '세트_NNG', '향신료_NNG', '허브_NNG', '아기_NNG', '자기_NP', '오밀조밀_MAG', '인테이크_NNG', '오늘_NNG', '손_NNG', '님_XSN', '은_JX', '예쁜_VA+ETM', '커플_NNG', '알콩달콩_MAG', '잘_MAG', '만나_VV', '세용_EP+EF']
# after_10y넘 마음에드는  집들이  선물  집들이선물  조미료  조미료세트  향신료  허브  아기자기  오밀조밀  인테이크  intake 오늘 손님은 예쁜 커플, 알콩달콩 잘만나세용:) �
# -103
#
# ['저녁_NNG', '식사_NNG', '뻔_NNB', '녀_NNG', '일_NNBC', '식단_NNG', '프로그램_NNG', '일_NNBC', '차_NNG', '뻔_NNB', '녀_NNG', '건강_NNG', '스무디_NNP', '레몬_NNG', '바나나_NNG', '블루베리_NNG', '컵_NNG', '요거트_NNG', '스푼_NNG', '물_NNG', '컵_NNG', '인테이크_NNG', '씨_NNG', '즈_XSN', '쓰리_NR', '아마_MAG', '씨드_NNP', '바질_NNP', '씨드_NNP', '치아_NNG', '씨드_NNP', '오늘_NNG', '은_JX', '색이_NNG', '뿐_JX', '스무디_NNP', '날씨_NNG', '가_JKS', '엄청_MAG', '추운_VA+ETM', '것_NNB', '같_VA', '아요_EF', '저_NP', '만_JX', '그런가요_VA+EC+VCP+EF', 'ㅠ_UNKNOWN', '오늘_NNG', '도_JX', '계단_NNG', '오르_VV', '기_ETN', '클리어_NNP', '오늘_NNG', '부터_JX', '주간_NNBC', '체험_NNG', '단_MM', '선정_NNG', '되_XSV', '서_EC', '모바일_NNP', '고고_NNG', '일_NR', '주일_NNBC', '식단표_NNG', '랑_JKB', '다_MAG', '받_VV', '았_EP', '는데_EC', '직장인_NNG', '은_JX', '현실_NNG', '불_XPN', '가능_NNG', '그래서_MAJ', '탄단_VV+ETM', '지_NNB', '잘_MAG', '챙기_VV', '는_ETM', '식단_NNG', '으로_JKB', '제_NP+JKG', '나름_NNB', '구성_NNG', '해서_XSV+EC', '먹_VV', '는_ETM', '걸로_NNB+JKB', '분_NNBC', '운동_NNG', '동영상_NNG', '보_VV', '고_EC', '따라_VV+EC', '하_VV', '면_EC', '되_VV', '더라구요_EF', '분_NNBC', '운동_NNG', '인데_VCP+EC', '칼로리_NNG', '소모_NNG', '가_JKS', '엄청나_VA', '다며_EF', '일_NR', '주일_NNBC', '운동_NNG', '구성_NNG', '되_XSV', '어_EC', '있_VX', '더라구요_EF', '그_IC', '뉵맨이_UNKNOWN', '동영상_NNG', '강의_NNG', '를_JKO', '오늘_MAG', '한_MM', '번_NNBC', '해_VV+EC', '보_VX', '겠_EP', '습니다_EF', '일단_MAG', 'ㅋㅋㅋ_IC', 'ㅋㅋㅋ_IC', '카톡_NNP', '으로_JKB', '트레이너_NNG', '가_JKS', '식단_NNG', '운동_NNG', '등_NNB', '피드백_NNG', '을_JKO', '줘요_VV+EC', '언제_NP', '든지_JX', '제_NP', '가_JKS', '일단_MAG', '해_VV+EC', '보_VX', '고_EC', '후기_NNG', '남길_VV+ETM', '게_NNB+JKS', '요_JX', '인친_NNG', '님_XSN', '들_XSN', '즐거운_VA+ETM', '저녁_NNG', '보내_VV', '세요_EP+EF', '씨씨_IC', '앙_NNG', '다이어트_NNG', '그램_NNG', '다이어트_NNG', '식단_NNG', '식단_NNG', '기록_NNG', '식단_NNG', '일지_VCP+EC', '식단_NNG', '홈_NNG', '쿡_MAG', '식단_NNG', '조절_NNG', '다노_NNP', '뻔_NNB', '녀_NNG', '요리_NNG', '스타그램_NNG', '쿡_MAG', '스타그램_NNG', '플레이_NNG', '팅_IC', '다이어터_NNP', '맞_XPN', '팔_NNG', '소통_NNG', '환영_NNG']
# yoo.hana517.
# �Diet +484�
# 20151118 저녁식사 � .
# .
# .
# .
# .
#  뻔녀5일식단프로그램 3일차
#  뻔녀_건강스무디 .
# ➡️ 레몬 1/2 바나나1 블루베리1컵 요거트3스푼 물1컵
# ➡️  인테이크  씨즈쓰리 아마씨드&바질씨드&치아씨드
# ➡️ 오늘은 색이뿐 스무디 �
# .
# .
# 날씨가 엄청 추운 것 같아요 저만 그런가요ㅠ
# 오늘도 계단오르기 클리어:)
# 오늘부터 2주간 체험단 선정되서  모바일PT 고고!
# 일주일식단표랑 다 받았는데 직장인은 현실불가능!
# 그래서 탄단지 잘 챙기는 식단으로
# 제 나름 구성해서 먹는걸로:) .
#  11분운동 동영상보고 따라하면 되더라구요! .
# 11분운동인데 칼로리 소모가 엄청나다며..! .
# 일주일 운동 구성되어 있더라구요� 그뉵맨이 동영상강의를!
# 오늘 한번 해보겠습니다 일단 ㅋㅋㅋㅋㅋㅋ
# 카톡으로 트레이너가 식단 운동 등 피드백을 줘요 언제든지! .
# 제가 일단 해보고 후기 남길게요�
# 인친님들♥️♥️♥️♥️♥️♥️
# 즐거운 저녁 보내세요�
# .
# .
#  씨씨앙  ccang
#  다이어트그램  diet  다이어트식단
#  식단기록  식단일지  식단  dietfood
#  홈쿡  식단조절  다노  DANO  뻔녀
#  요리스타그램  쿡스타그램  플레이팅
#  다이어터_맞팔_소통_환영 ��
# -104
#
# ['저녁_NNG', '식사_NNG', '뻔_NNB', '녀_NNG', '일_NNBC', '식단_NNG', '프로그램_NNG', '일_NNBC', '차_NNG', '뻔_NNB', '녀_NNG', '건강_NNG', '스무디_NNP', '레몬_NNG', '토마토_NNG', '사과_NNG', '파프리카_NNG', '물_NNG', '컵_NNG', '인테이크_NNG', '씨_NNG', '즈_XSN', '쓰리_NR', '아마_MAG', '씨드_NNP', '바질_NNP', '씨드_NNP', '치아_NNG', '씨드_NNP', '오늘_NNG', '은_JX', '색이_NNG', '뿐_JX', '스무디_NNP', '오늘_NNG', '도_JX', '계단_NNG', '오르_VV', '기_ETN', '클리어_NNP', '이제_IC', '익숙_XR', '해_XSA+EC', '지_VX', '려는_ETM', '계단_NNG', '오르_VV', '기_ETN', 'ㅋㅋ_IC', 'ㅋㅋ_IC', '우리_NP', '집_NNG', '이_JKS', '층_NNG', '이_VCP', '면_EC', '좋_VA', '을_ETM', '것_NNB', '같_VA', '아요_EC', '층_NNG', '이_JKS', '딱_MAG', '오르_VV', '기_ETN', '좋_VA', '은_ETM', 'ㅋㅋ_IC', '층_NNG', '부터_JX', '숨_NNG', '막힘_VV+ETN', '낮_NNG', '에_JKB', '외식_NNG', '했으니_XSV+EP+EC', '나트륨_NNG', '배출_NNG', '위해_VV+EC', '스무디_NNP', '에_JKB', '토마토_NNG', '를_JKO', '넣_VV', '었_EP', '어요_EF', '인친_NNG', '님_XSN', '들_XSN', '즐거운_VA+ETM', '저녁_NNG', '보내_VV', '세요_EP+EF', '다이어트_NNG', '그램_NNG', '다이어트_NNG', '식단_NNG', '식단_NNG', '기록_NNG', '식단_NNG', '일지_VCP+EC', '식단_NNG', '홈_NNG', '쿡_MAG', '식단_NNG', '조절_NNG', '다노_NNP', '뻔_NNB', '녀_NNG', '요리_NNG', '스타그램_NNG', '쿡_MAG', '스타그램_NNG', '플레이_NNG', '팅_IC', '다이어터_NNP', '맞_XPN', '팔_NNG', '소통_NNG', '환영_NNG']
# yoo.hana517.
# �Diet +485�
# 20151119 저녁식사 � .
# .
# .
# .
# .
#  뻔녀5일식단프로그램 4일차
#  뻔녀_건강스무디 .
# ➡️ 레몬 1/2 토마토2 사과1/2 파프리카1/2 물1컵
# ➡️  인테이크  씨즈쓰리 아마씨드&바질씨드&치아씨드
# ➡️ 오늘은 색이뿐 스무디 �
# .
# .
# 오늘도 계단오르기 클리어:)
# 이제 익숙해지려는 계단오르기 ㅋㅋㅋㅋ
# 우리집이 10층이면 좋을 것 같아요
# 10층이 딱 오르기 좋은 ㅋㅋ 11층부터 숨막힘�
# 낮에 외식했으니  나트륨_배출 위해 스무디에 토마토를 넣었어요:)
# 인친님들♥️♥️♥️♥️♥️♥️
# 즐거운 저녁 보내세요�
# .
# .
#  다이어트그램  diet  다이어트식단
#  식단기록  식단일지  식단  dietfood
#  홈쿡  식단조절  다노  DANO  뻔녀
#  요리스타그램  쿡스타그램  플레이팅
#  다이어터_맞팔_소통_환영 ��
# -105
# ['저녁_NNG', '식사_NNG', '뻔_NNB', '녀_NNG', '건강_NNG', '스무디_NNP', '레몬_NNG', '귤_NNG', '사과_NNG', '당근_NNG', '물_NNG', '컵_NNG', '인테이크_NNG', '씨_NNG', '즈_XSN', '쓰리_NR', '아마_MAG', '씨드_NNP', '바질_NNP', '씨드_NNP', '치아_NNG', '씨드_NNP', '오늘_NNG', '은_JX', '색이_NNG', '뿐_JX', '스무디_NNP', '점심_NNG', '외식_NNG', '했으니_XSV+EP+EC', '저녁_NNG', '은_JX', '건강_NNG', '스무디_NNP', '아_IC', '흑_IC', '맛나_VA', '고_EC', '든든_XR', '해유_XSA+EF', '제_NP+JKG', '꺼_MAG', '스무디_NNP', '만들_VV', '어_EC', '마시_VV', '구_EC', '엄마_NNG', '아빠_NNG', '위해_VV+EC', '요리_NNG', '했_XSV+EP', '답니당_EF', '인친_NNG', '님_XSN', '들_XSN', '즐거운_VA+ETM', '저녁_NNG', '보내_VV', '세요_EP+EF', '다이어트_NNG', '그램_NNG', '다이어트_NNG', '식단_NNG', '식단_NNG', '기록_NNG', '식단_NNG', '일지_VCP+EC', '식단_NNG', '홈_NNG', '쿡_MAG', '식단_NNG', '조절_NNG', '다노_NNP', '뻔_NNB', '녀_NNG', '요리_NNG', '스타그램_NNG', '쿡_MAG', '스타그램_NNG', '플레이_NNG', '팅_IC', '다이어터_NNP', '맞_XPN', '팔_NNG', '소통_NNG', '환영_NNG']
# yoo.hana517.
# �Diet +488�
# 20151122 저녁식사 � .
# .
# .
# .
# .
#  뻔녀_건강스무디 .
# ➡️ 레몬 1/2 귤2 사과1 당근1/3 물1컵
# ➡️  인테이크  씨즈쓰리 아마씨드&바질씨드&치아씨드
# ➡️ 오늘은 색이뿐 스무디 �
# .
# .
# 점심 외식했으니 저녁은  건강스무디
# 아흑 맛나고 든든해유:)
# 제꺼 스무디 만들어 마시구 엄마아빠 위해
# 요리했답니당☺️�
# 인친님들♥️♥️♥️♥️♥️♥️
# 즐거운 저녁 보내세요�
# .
# .
#  다이어트그램  diet  다이어트식단
#  식단기록  식단일지  식단  dietfood
#  홈쿡  식단조절  다노  DANO  뻔녀
#  요리스타그램  쿡스타그램  플레이팅
#  다이어터_맞팔_소통_환영 ��
# -106
#
# ['아침_NNG', '식사_NNG', '든든_XR', '하_XSA', '게_EC', '모닝죽_NNG', '인테이크_NNG', '단호_NNG', '박죽_NNG', '다음_NNG', '엔_JKB+JX', '고구_NNG', '마죽_NNG', '사먹_VV', '어_EC', '봐야지_VX+EC', '직_NNG', '딩_NNG', '아침밥_NNG', '식사_NNG', '대용_NNG', '간편식_NNG', '직_NNG', '딩_NNG', '라이프_NNG', '직_NNG', '딩_NNG', '스타그램_NNG', '아침_NNG', '먹_VV', '고_EC', '다녀요_VV+EF']
# namkkaaa 아침식사  든든하게  모닝죽  인테이크  intake  단호박죽 다음엔 고구마죽 사먹어봐야지�  직딩아침밥  식사대용  간편식  직딩라이프  직딩스타그램  아침먹고다녀요
# -107
#
# ['식단_NNG', '일기_NNG', '아침_NNG', '그릭요거트_NNG', '사과_NNG', '블루베리_NNG', '귤_NNG', '잼_NNG', '당근_NNG', '팝콘_NNG', '감동_NNG', '란_JX', '개_NNBC', '인테이크_NNG', '수퍼_NNP', '바_NNB', '개_NNBC', '좋_VA', '은_ETM', '아침_NNG', '감동_NNG', '란_NNG', '은_JX', '후기_NNG', '들_XSN', '이_JKS', '감동_NNG', '의_JKG', '물결_NNG', '이_VCP', '라_EC', '지난번_NNG', '마트_NNG', '할인_NNG', '때_NNG', '사_VV+EC', '봤_VX+EP', '어요_EF', '근데_MAJ', '제_MM', '입_NNG', '엔_JKB+JX', '좀_MAG', '짜_VV', '요_EF', '소금_NNG', '들어간_VV+ETM', '계란_NNG', '을_JKO', '너무_MAG', '오랜만_NNG', '에_JKB', '먹_VV', '어_EC', '봐서_VX+EC', '그렇_VA', '기_ETN', '두_JX', '하_VV', '구_EC', 'ㅎㅎ_IC', '예전_NNG', '이_VCP', '었_EP', '으면_EC', '딱_MAG', '좋_VA', '아_EC', '했_VX+EP', '을_ETM', '것_NNB', '같_VA', '아요_EF', '노른_VA+ETM', '자_NNB', '영롱_XR', '하_XSA', '고_EC', '포근포근_MAG', '하_VV', '구_EC', '여_VCP+EF', '근데_MAJ', '넘_MAG', '비싸_VA', '서_EC', '바깥_NNG', '에서_JKB', '사먹_VV', '어야_EC', '할_VX+ETM', '때_NNG', '아니_VCN', '면_EC', '굳이_MAG', '사진_NNG', '않_VV', '을_ETM', '것_NNB', '같_VA', '아요_EF', '수퍼_NNP', '바_NNB', '는_JX', '다양_XR', '한_XSA+ETM', '견과_NNG', '류_XSN', '를_JKO', '한_MM', '번_NNBC', '에_JKB', '섭취_NNG', '하_XSV', '려구_EC', '구매_NNG', '했_XSV+EP', '어요_EF', '설탕_NNG', '은_JX', '들_VV', '어_EC', '있_VX', '는_ETM', '제품_NNG', '이_VCP', '예요_EF', '그래서_MAJ', '그런지_VA+EC', '맛있_VA', '닫_NNG', 'ㅎ_IC', '앞_NNG', '으로_JKB', '제_XPN', '아침_NNG', '이나_JC', '간식_NNG', '반개_NNG', '씩_XSN', '남긴_VV+ETM', '건_NNB+JX', '운동_NNG', '후_NNG', '간식_NNG', '으루_JKB', '마이_NNP', '웨이_NNP', '다이어트_NNG', '다이어트_NNG', '다이어트_NNG', '식단_NNG', '식이조절_NNG', '건강식_NNG', '건강_NNG', '식단_NNG', '다이어터_NNP', '그램_NNG', '다이어터_NNP', '데일리_NNP', '식단_NNG', '일상_NNG']
# diet_balmoxx 식단일기 2015.11.23  아침 breakfast
# -
#
#  그릭요거트 50g
#  사과 72g
#  블루베리 8g
#  귤잼 10g
#  당근팝콘 15g
#
#  감동란 1/2개
#  인테이크 수퍼바 1/2개
# -
#
# 1. 좋은아침:D
#
# 2. 감동란은 후기들이 감동의 물결이라 지난번 마트할인때 사봤어요.
#
# 근데 제 입엔 좀짜요. 소금 들어간 계란을 너무 오랜만에 먹어봐서 그렇기두하구 ㅎㅎ 예전이었으면 딱 좋아했을것 같아요. 노른자 영롱하고 포근포근하구여.
#
# 근데 넘 비싸서 바깥에서 사먹어야할때 아니면 굳이 사진 않을것 같아요.
#
# 3. 수퍼바는 다양한 견과류를 한번에 섭취하려구 구매했어요. 설탕은 들어있는 제품이예요. 그래서 그런지 맛있닫ㅎ... 앞으로 제 아침이나 간식!
#
# 4. 반개씩 남긴건 운동후 간식으루!!
# -
#
#  마이웨이다이어트 다이어트 diet 다이어트식단 식이조절 건강식 건강식단 다이어터그램 다이어터 데일리 식단 일상
# -108
#
# ['식단_NNG', '일기_NNG', '운동_NNG', '후_NNG', '단백질_NNG', '간식_NNG', '감동_NNG', '란_JX', '인테이크_NNG', '수퍼_NNP', '바_NNB', '프로_NNG', '틴_NNG', '셰이크_NNG', '아몬드_NNP', '브리즈_NNP', '오랜만_NNG', '에_JKB', '운동_NNG', '후_NNG', '간식_NNG', '요즘_NNG', '은_JX', '그냥_MAG', '운동_NNG', '하_XSV', '고_EC', '식사_NNG', '하_XSV', '거나_EC', '밤_NNG', '운동_NNG', '하_XSV', '고_EC', '프_VX', '셰_EC', '계_XSN', '흰_VA+ETM', '먹_VV', '은_ETM', '거_NNB', '피드_NNP', '생략_NNG', '하_VV', '거나_EC', '했었_VX+EP', '네요_EF', '역시_MAJ', '낮_NNG', '운동_NNG', '후_NNG', '간식_NNG', '이_JKS', '제일_MAG', '꿀_NNG', '아몬드_NNP', '브리즈_NNP', '전_MM', '아몬드_NNG', '우유_NNG', '인_VCP+ETM', '줄_NNB', '알_VV', '구_EC', '지방_NNG', '많_VA', '을까_EC', '봐_VX+EC', '구매_NNG', '꺼렸_VV+EP', '는데_EC', '아니_VCN', '었_EP', '네요_EF', 'ㅋㅋㅋ_IC', '개인_NNG', '적_XSN', '으로_JKB', '두유_NNG', '나_JC', '무_XPN', '지방_NNG', '우유_NNG', '보다_JKB', '아몬드_NNP', '브리즈_NNP', '영양_NNG', '성분_NNG', '이_JKS', '제일_MAG', '마음_NNG', '에_JKB', '들_VV', '어요_EF', '내사_NNP', '랑_JC', '각_MM', '요즘_MAG', '먹_VV', '은_ETM', '걸_NNB+JKO', '보_VV', '구_EC', '반성_NNG', '하_XSV', '는_ETM', '게_NNB+JKS', '설탕_NNG', '소금_NNG', '식물_NNG', '성_XSN', '오_NR', '일_NNBC', '조금_NNG', '에_JKB', '도_JX', '벌벌_MAG', '떨_VV', '다가_EC', '막상_MAG', '어느_MM', '때_NNG', '되_XSV', '면_EC', '빵_NNG', '이나_JC', '튀김_NNG', '도_JX', '냉큼_MAG', '한입_NNG', '만_JX', '하_VV', '면서_EC', '먹_VV', '어_EC', '버리_VX', '고_EC', 'ㅠㅠ_UNKNOWN', '차라리_MAG', '딱_MAG', '잇클린_NNG', '의_JKG', '기준_NNG', '을_JKO', '버터_NNG', '밀가루_NNG', '보존제_NNG', '로_JKB', '잡_VV', '고_EC', '그_MM', '외_NNB', '에_JKB', '는_JX', '조금_MAG', '마음_NNG', '을_JKO', '편하_VA', '게_EC', '먹_VV', '는_ETM', '게_NNB+JKS', '나을_VA+ETM', '것_NNB', '같_VA', '아서_EC', '기준_NNG', '을_JKO', '수정_NNG', '했_XSV+EP', '어요_EF', '매우_MAG', '소량_NNG', '의_JKG', '소금_NNG', '설탕_NNG', '식물_NNG', '성_XSN', '유지_NNG', '는_JX', '기록_NNG', '하_XSV', '면서_EC', '조절_NNG', '섭취_NNG', '하_XSV', '기_ETN', '과_NNG', '섭취_NNG', '안_MAG', '하_VV', '도록_EC', '신경_NNG', '을_JKO', '많이_MAG', '써야_VV+EC+VX', '겠_EP', '지만_EC', '요_JX', '다행히_MAG', '요번_NNG', '에_JKB', '인테이크_NNG', '에서_JKB', '비_XPN', '정제_NNG', '설탕_NNG', '이랑_JC', '향신료_NNG', '여러_MM', '개_NNBC', '구매_NNG', '했_XSV+EP', '어요_EF', '요리_NNG', '하_XSV', '는_ETM', '데_NNB', '재미_NNG', '붙_VV', '어서_EC', 'ㅎㅎ_IC', '담_NNG', '에_JKB', '는_JX', '코코넛_NNG', '오일_NNG', '이랑_JC', '통밀_NNG', '가루_NNG', '를_JKO', '구매_NNG', '해_XSV+EC', '볼까_VX+EC', '하_VX', '구요_EF']
# diet_balmoxx 식단일기 2015.11.23  운동후단백질 간식
# -
#
#  감동란 1/2
#  인테이크 수퍼바 1/2
#  프로틴셰이크 (아몬드브리즈 200ml) 1
# -
#
# 1. 오랜만에 운동후간식!
# 요즘은 그냥 운동하고 식사하거나 밤운동하고 프셰+계흰 먹은거 피드생략�하거나했었네요.
#
# 역시 낮 운동후 간식이 제일꿀!
#
# 2. 아몬드브리즈 전 아몬드+우유인줄알구 지방 많을까봐 구매꺼렸는데 아니었네요ㅋㅋㅋ
#
# 개인적으로 두유나 무지방우유보다 아몬드브리즈 영양성분이 제일 마음에들어요!! 내사랑각�
#
# 3. 요즘 먹은걸보구 반성하는게 설탕, 소금, 식물성 오일 조금에도 벌벌 떨다가
# 막상 어느 때되면 빵이나 튀김도 냉큼 한입만하면서 먹어버리고...ㅠㅠ
#
# 차라리 딱 잇클린의 기준을 <버터 X, 밀가루 X , 보존제X>로 잡고 그외에는 조금 마음을 편하게 먹는게 나을것 같아서 기준을 수정했어요.
#
# 매우 소량의 소금, 설탕, 식물성유지는 기록하면서 조절 섭취하기! 과섭취 안하도록 신경을 많이 써야겠지만요.
#
# 다행히 요번에  인테이크 에서 비정제 설탕이랑 향신료 여러개 구매했어요! 요리하는데 재미붙어서 ㅎㅎ
# 담에는 코코넛오일이랑 통밀가루를 구매해볼까하구요.
# -
# -109
#
# ['식단_NNG', '일기_NNG', '운동_NNG', '후_NNG', '간식_NNG', '인테이크_NNG', '수퍼_NNP', '바_NNB', '프로_NNG', '틴_NNG', '셰이크_NNG', '무_XPN', '지방_NNG', '우유_NNG', '점심_NNG', '만드_VV', '는데_EC', '또_MAG', '시간_NNG', '걸릴_VV+ETM', '것_NNB', '같_VA', '아서_EC', '일단_MAG', '섭취_NNG', '엄마_NNG', '한테_JKB', '뭘_NP+JKO', '자꾸_MAG', '사_VV+EC', '모으_VV', '고_EC', '만들_VV', '어_EC', '댄_VX+ETM', '다구_NNG', '혼_NNG', '나서_VV+EF', '냉장고_NNG', '털_NNG', '이중_NNG', '이_VCP', '예요_EC', '어제_NNG', '토마토_NNG', '마리네_NNP', '이드_NNP', '클리어_NNP', '하구_JC', '오늘_NNG', '은_JX', '우유_NNG', '클리어_NNP', '매번_MAG', '요리_NNG', '할_XSV+ETM', '때_NNG', '면_VCP+EC', '맛_NNG', '낸다구_XSV+EF', '재료_NNG', '를_JKO', '자꾸_MAG', '더_MAG', '넣_VV', '는_ETM', '것_NNB', '같_VA', '아서_EC', 'ㅠㅠ_UNKNOWN', '재료_NNG', '하나_NR', '만_JX', '참_VV', '고_EC', '안_MAG', '넣_VV', '기_ETN', '간식_NNG', '하나_NR', '만_JX', '참_VV', '고_EC', '안_MAG', '먹_VV', '기_ETN', '캠페인_NNG', '을_JKO', '잘_MAG', '지키_VV', '면_EC', '그날_NNG', '은_JX', '셀프_NNG', '잘_MAG', '했_VV+EP', '어요_EF', '도장_NNG', '찍_VV', '어_EC', '주_VX', '는_ETM', '걸루_NNB+JKB', '도장_NNG', '백_NR', '개_NNBC', '모으_VV', '면_EC', '먹_VV', '고_EC', '싶_VX', '은_ETM', '거_NNB', '하나_NR', '보상_NNG']
# diet_balmoxx 식단일기 2015.11.25  운동후  간식
# -
#
#  인테이크 수퍼바 1
#  프로틴셰이크(무지방우유 100ml)
# -
#
# 1. 점심 만드는데 또시간 걸릴것같아서 일단 섭취!
#
# 2. 엄마한테 뭘자꾸 사모으고 만들어댄다구 혼나서...냉장고 털이중이예요;;
# 어제 토마토마리네이드 클리어하구 오늘은 우유 클리어!
#
# 3. 매번 요리할때면 맛낸다구 재료를 자꾸 더넣는것 같아서 ㅠㅠ 재료 하나만 참고 안넣기, 간식 하나만 참고 안먹기 캠페인을...!! 잘지키면 그날은 셀프 잘했어요 도장찍어주는걸루! 도장 백개 모으면 먹고싶은거 하나 보상...!?
# -
# -110
#
# ['식단_NNG', '일기_NNG', '오후_NNG', '인테이크_NNG', '수퍼_NNP', '바_NNB', '계란_NNG', '프_VX', '셰_EC', '아몬드_NNP', '브리즈_NNP', '고구마_NNG', '병아리_NNG', '콩_NNG', '샐러드_NNG', '대추_NNG', '토마토_NNG', '케일_NNG', '페스_NNP', '토_NNP', '시간_NNG', '이_JKS', '없_VA', '어_EC', '섞_VV', '기_ETN', '만_JX', '한_NNP', '인테이크_NNG', '수퍼_NNP', '바_NNB', '프_VX', '셰_EC', '아몬드_NNP', '브리즈_NNP', '너무_MAG', '간식_NNG', '을_JKO', '먹_VV', '어_EC', '버렸_VX+EP', '어요_EF', 'ㅠㅜ_UNKNOWN', '아까_MAG', '학원_NNG', '다녀와서_VV+EC', '너무_MAG', '힘들_VA', '고_EC', '배고파서_VA+EC', '먹_VV', '었_EP', '는데_EC', '오늘_MAG', '하루_NNG', '식단_NNG', '은_JX', '칭찬_NNG', '해_XSV+EC', '주_VX', '기_ETN', '가_JKS', '어렵_VA', '네요_EF', '반성_NNG', 'ㅜㅠ_UNKNOWN', '마이_NNP', '웨이_NNP', '다이어트_NNG', '다이어트_NNG', '다이어트_NNG', '식단_NNG', '식이조절_NNG', '건강식_NNG', '건강_NNG', '식단_NNG', '다이어터_NNP', '그램_NNG', '다이어터_NNP', '다이어터_NNP', '맞_XPN', '팔_NNG', '데일리_NNP', '식단_NNG', '일상_NNG']
# diet_balmoxx 식단일기 2015.11.27  오후
# -
#
# PM 3:30
#  인테이크 수퍼바 1
#  계란 1
#  프셰(아몬드브리즈 200ml) 1
#
# PM 6:30
#  고구마 100g
#  병아리콩 10
#  샐러드 15g
#  대추토마토 1
#  케일페스토 (시간이없어섞기만한) 1ts
#
# PM 10:00
#  인테이크 수퍼바 1
#  프셰(아몬드브리즈 100ml) 1
# -
#
# 너무 간식을 먹어버렸어요ㅠㅜ
# 아까 학원다녀와서 너무 힘들고 배고파서 먹었는데 오늘 하루 식단은 칭찬해주기가 어렵네요. 반성ㅜㅠ
# -
#
#  마이웨이다이어트 다이어트 diet 다이어트식단 식이조절 건강식 건강식단 다이어터그램 다이어터 다이어터맞팔 데일리 식단 일상
# -111
# ['진열장_NNG', '확대_NNG', '인테이크_NNG', '조미_NNG', '향신료_NNG']
# thesemipropig 진열장  확대  인테이크  조미향신료
# -112
#
# ['인테이크_NNG', '수퍼_NNP', '바_NNB', '가지_NNBC', '수퍼_NNP', '푸드_NNG', '가_JKS', '한_MM', '자리_NNG', '에_JKB', '모였_VV+EP', '다_EF', '하루_NNG', '에_JKB', '한_MM', '개_NNBC', '씩_XSN', '영양_NNG', '간식_NNG', '으로_JKB', '건강_NNG', '채우_VV', '기_ETN', '인테이크_NNG', '인테이크_NNG', '푸즈_NNP', '슈퍼_NNG', '바_NNB', '수퍼_NNP', '바_NNB', '수퍼_NNP', '푸드_NNG', '건강_NNG', '간식_NNG', '다이어트_NNG', '간식_NNG', '견과_NNG', '바_NNG', '수제_NNG', '견과_NNG', '바_NNB']
# ragoni.shineun인테이크 수퍼바
#
# 13가지 수퍼푸드가 한자리에 모였다.
# 하루에 한개씩 영양간식으로 건강채우기.
#
#  인테이크  인테이크푸즈  슈퍼바  수퍼바  수퍼푸드  건강간식  다이어트간식  견과바  수제견과바  INTAKE  SUPERBAR
# -113
#
# ['신림_NNG', '우리_NP', '집_NNG', '간식_NNG', '인테이크_NNG', '수퍼_NNP', '바_NNP', '빈스_NNP', '바_NNB', '비비_VV', '고_EC', '김치_NNG', '왕_NNG', '교자_NNG', '찐만두_NNG', '만두_NNG', '김치_NNG', '만_JX', '두_MM', '우유_NNG', '먹_NNG', '스타그램_NNG', '인테이크_NNG', '협찬_NNG']
# yeon__bb 신림  우리집  간식
#  인테이크  수퍼바  빈스바
#  비비고  김치왕교자  찐만두  만두  김치만두
#  우유  먹스타그램
# .
# �  인테이크협찬
# -114
# 빈스바_NNG
#
# ['단호_NNG', '박죽_NNG', '야채_NNG', '프리타타_NNP', '죽_VV', '은_ETM', '당신_NP', '꺼_VV+EC', '남편_NNG', '은_JX', '장염_NNG', '주말_NNG', '인데_VCP+EC', '집_NNG', '콕_MAG', '신세_NNG', '파프리카_NNG', '양파_NNG', '아스파라거스_NNP', '토마토_NNP', '프리타타_NNP', '간단_XR', '하_XSA', '니_EC', '넘_MAG', '좋_VA', '네_EF', '인테이크_NNG', '단호_NNG', '박죽_NNG', '회사_NNG', '갈_VV+ETM', '때_NNG', '도_JX', '싸_VV+EC', '줄_VX+ETM', '게_NNB+JKS', '커피_NNG', '곡물_NNG', '바_NNG', '드립_NNG', '커피_NNG', '아침밥_NNG', '스타그램_NNG', '죽_NNG', '과_JC', '곡물_NNG', '바_NNB', '는_JX', '협찬_NNG', '으로_JKB', '진행_NNG', '되_XSV', '었_EP', '습니다_EF']
# joosami 단호박죽 야채프리타타
#
# 죽은 당신꺼~�  남편은장염 주말인데집콕신세
#  파프리카 양파 아스파라거스 토마토 프리타타
#  간단하니넘좋네� 인테이크 단호박죽
#  회사갈때도싸줄게
#  커피 곡물바 드립커피
#  아침밥스타그램
#  goodmorning .
# .
# *죽과 곡물바는 협찬으로 진행되었습니다
# -115
#
# ['편리_NNG', '한_XSA+ETM', '세상_NNG', '임_VCP+ETN', 'ㅋ_IC', '맛_NNG', '도_JX', '좋_VA', '네_EF', '아침_NNG', '모닝죽_NNG', '모닝죽_NNG', '단호박_NNG', '인테이크_NNG', '간편식_NNG']
# lee.ssolssol편리한 세상임..ㅋ 맛도 좋네♡
#  아침  모닝죽  모닝죽단호박  인테이크  간편식
# -116
#
# ['신림_NNG', '우리_NP', '집_NNG', '인테이크_NNG', '수퍼_NNP', '바_NNB', '견과_NNG', '류바_NNP', '마시_NNG', '쩡_MAG', '크리스피_NNP', '롤_JKB', '곡_NNBC', '방울토마토_NNG', '우유_NNG', '먹_NNG', '스타그램_NNG', '본_VV+ETM', '포스팅_NNP', '은_JX', '인테이크_NNG', '푸드_NNG', '로부터_JKB', '협찬_NNG', '을_JKO', '받_VV', '고_EC', '작성_NNG', '하_XSV', '였_EP', '습니다_EF']
# yeon__bb 신림  우리집
#  인테이크  수퍼바  견과류바 마시쩡..❤�
#  크리스피롤12곡
#  방울토마토  우유  먹스타그램 .
# * 본 포스팅은 인테이크푸드로부터 협찬을 받고 작성하였습니다.
# -117
#
# ['비_NNG', '가_JKS', '와서_VV+EC', '깊이_MAG', '잘_MAG', '잤_VV+EP', '나_EC', '콘_NNG', '디_NNG', '션_NNG', '이_JKS', '좋_VA', '으니_EC', '식욕_NNG', '도_JX', '뫅뫅_UNKNOWN', '상승_NNG', '하_XSV', '는_ETM', '군_NNG', '브런치_NNP', '홈_NNG', '메이드_NNP', '단호박_NNG', '죽_MAG', '수퍼_NNP', '바_NNB', '인테이크_NNG', '모닝커피_NNG', '호박죽_NNG', '그레_NNG', '인_VCP+ETM', '바_NNB', '인테이크_NNG', '푸드_NNG', '협찬_NNG']
# j_merry_j☔️
# 비가와서 깊이 잘 잤나�
# 콘디션이 좋으니 식욕도 뫅뫅 상승하는군�
# .
#  브런치 홈메이드 단호박죽 수퍼바 인테이크 모닝커피
# .
# -호박죽, 그레인바 : 인테이크푸드 협찬-
# -118
#
# ['게으름뱅이_NNG', '새댁_NNG', '에게_JKB', '할렐루야_NNG', '회사_NNG', '서_JKB', '밥_NNG', '나와도_VV+EC', '시간_NNG', '없_VA', '다고_EC', '빵_NNG', '먹_VV', '고_EC', '다니_VV', '는_ETM', '출근_NNG', '하_XSV', '는_ETM', '남편_NNG', '손_NNG', '에_JKB', '단팥죽_NNG', '살짝_MAG', '데워_VV+EC', '빈스_NNP', '바_NNB', '와_VV+EC', '안겨_VV+EC', '주_VX', '면_EC', '끝_NNG', '아침_NNG', '식사_NNG', '쪽쪽_MAG', '알_VV', '아서_EC', '빨_VV', '아_EC', '드시_VV', '겠_EP', '쥬_EF', 'ㅋㅋㅋ_IC', '혼자_NNG', '밥_NNG', '먹_VV', '기_ETN', '싫_VA', '은_ETM', '저_NP', '도_JX', '간단_XR', '하_XSA', '고_EC', '건강_NNG', '하_XSV', '게_EC', '한끼_NNG', '해결_NNG', '되_XSV', '어서_EC', '넘_MAG', '좋_VA', '아요_EF', '지금_MAG', '전_MM', '간식_NNG', '으로_JKB', 'ㅋㅋ_IC', '팥_NNG', '너무너무_MAG', '좋_VA', '아_EC', '하_VV', '는데_EC', '달_VX', '지_EC', '않_VX', '아_EC', '딱_MAG', '이_MM', '제품_NNG', '은_JX', '협찬_NNG', '을_JKO', '받_VV', '고_EC', '진행_NNG', '하_XSV', '였_EP', '습니다_EF', '인테이크_NNG', '모닝죽_NNG', '모닝죽_NNG', '단팥_NNG', '아침밥_NNG', '새댁_NNG', '일상_NNG', '새댁_NNG', '스타그램_NNG', '아침_NNG', '굿모닝_NNP', '은_JX', '아까_MAG', '간식_NNG', '죽_MAG', '든든_XR', '한_XSA+ETM', '한끼_NNG', '건강_NNG', '한_XSA+ETM', '한끼_NNG', '웰빙_NNP', '라이프_NNG', '건강_NNG', '한_XSA+ETM', '생활_NNG', '건강_NNG', '집_NNG', '밥_NNG', '동탄_NNP', '새댁_NNG']
# milarang게으름뱅이 새댁에게  할렐루야 !! �
# 회사서 밥나와도 시간없다고 빵먹고 다니는 출근하는 남편손에  단팥죽 살짝 데워  빈스바 와 안겨주면 끝 �  아침식사
# 쪽쪽 알아서 빨아드시겠쥬? ㅋㅋㅋ
# 혼자밥먹기 싫은 저도 간단하고 건강하게 한끼 해결되어서 넘 좋아요 지금 전 간식으로 ㅋㅋ�
# 팥 너무너무 좋아하는데 달지 않아 딱�
# <이제품은 협찬을 받고 진행하였습니다 >
# @intakefoods  인테이크  모닝죽  모닝죽단팥  아침밥  새댁일상  새댁스타그램  아침  굿모닝 은 아까..��  간식죽  든든한한끼  건강한한끼  웰빙라이프  건강한생활  건강집밥  동탄새댁 �
# -119
#
# ['자취_NNG', '선물_NNG', '인테이크_NNG', '조미_NNG', '향신료_NNG', '종_NNG', '요리_NNG', '보_VV', '다는_ETM', '장식_NNG', '소금_NNG', '하나_NR', '도_JX', '고급_NNG', '져_XSV+EF', '감사_NNG', '합니다_XSV+EF', '예_IC', '요리_NNG', '는_JX', '음_IC', '어쩌_VV', '지_EF']
# thesemipropig 자취선물  인테이크  조미향신료 18종.  요리 보다는  장식.  소금 하나도 고급져. 감사합니다! 예-! 요리는 음... 어쩌지...
# -120
# break
#
# ['신림_NNG', '우리_NP', '집_NNG', '아침_NNG', '딜리_NNP', '핏_NNG', '고르_VA', '곤_EC', '졸라_VV+EC', '닭_NNG', '가슴살_NNG', '닭_NNG', '가슴살_NNG', '지알_NNG', '엔_JKB+JX', '산야초_NNG', '인테이크_NNG', '단호박_NNG', '죽_MAG', '냠냠_MAG', '제주_NNP', '땡_NNG', '귤_NNG', '마멀레이드_NNG', '먹_NNG', '스타그램_NNG', '딜리_NNP', '핏_NNG', '협찬_NNG', '지알_NNG', '엔_JKB+JX', '협찬_NNG', '인테이크_NNG', '협찬_NNG']
# yeon__bb 신림  우리집  아침
#  딜리핏  고르곤졸라닭가슴살  닭가슴살
#  지알엔  산야초
#  인테이크  단호박죽
#  냠냠제주  땡귤마멀레이드
#  먹스타그램
# .
# �  딜리핏협찬
# �  지알엔협찬
# �  인테이크협찬
# -121
# break
# break

# %%
keyword_list
# Out:
# ['슈퍼바_NNG', '슈퍼바_NNG, 슈퍼바']

# %%
intake.raw_data[22,2]
# Out:
# '_eunjishin제가 먹어볼게요  인테이크 모닝죽 누룽지 무려  가마솥'

# %%
intake.morph_list[20]
# Out:
# ['제_NP',
#  '가_JKS',
#  '먹_VV',
#  '어_EC',
#  '볼게요_VX+EF',
#  '인테이크_NNG',
#  '모닝죽_NNG',
#  '누룽지_NNG',
#  '무려_MAG',
#  '가마솥_NNG']

# %% [markdown]
# ## m이 False인 경우에는 진짜 맛있다는 것.
# ## -> '없' 이라는 음절이 '있'이라는 음절 이후 4음절 내에 없다는 뜻이다.
# ## m이 True인 경우에는 애매한 상황이다. '없' 이라는 음절이 4음절 내에 존재한다는 것이다.

# %%
import re
m = re.search('맛.{0,5}있.{0,5}[없않]', '안녕하세요. 맛이 있진 않다.. 다만 아쉬운 것은 포장지가 없다.')
print(m)
print('맛있다는 뜻' if m == None else '맛 없다는 뜻\n원문: ' + m.group())

m = re.search('맛.{0,5}있.{0,5}[없않]', '안녕하세요. 맛이 있다. 다만 아쉬운 것은 포장지가 없다.')
print(m)
print('맛있다는 뜻' if m == None else '맛 없다는 뜻\n원문: ' + m.group())
# Out:
# <_sre.SRE_Match object; span=(7, 14), match='맛이 있진 않'>
# 맛 없다는 뜻
# 원문: 맛이 있진 않
# None
# 맛있다는 뜻
